# %%
## Scaffold for Michelangelo customers 
## authors: will.zou@uber.com dmantar@uber.com 
## Causal Models for real-time incentives 
## import libraries and modules 

import sys, os, pandas as pd, numpy as np, pickle as pkl, tensorflow as tf 
sys.path.append('../dataprep/') 
from QueryFunctions import *

# %%
### pull data either using queryrunner or using csv 
use_query = 0 ### turn this switch on (to 1.0/True vs 0.0/False) to run query using QueryRunner 
use_python3 = True 

if use_query: 
    from queryrunner_client import Client 
    qr = Client(user_email='will.zou@uber.com') 
    ##label_dates_weekly = "'2019-07-14', '2019-07-21', '2019-07-28', '2019-08-04'" 
    ##city_ids = '1,5,6,8,10,12,20,23,198' 
    #feature_dates="'2019-06-30'" 
    #proposal_start_date = '2019-07-08' 
    
    predFrame2 = qr.execute('presto', rt_data_presto_first()) 
    predFrame2 = pd.DataFrame(predFrame2.load_data()) 
else: 
    predFrame2 = pd.read_csv('../data/rt_query_result.csv')
# Out:
# /Users/will.zou/code/deeplearning_hscls/py3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3051: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
### Cross check on treatment and control cohort sizes 
cohort_column_name = 'treatment' 
treatment_indicator_value = True 
control_indicator_value = False 
print('size of dataset:') 
print(len(predFrame2)) 
print('size of control cohort:') 
print(sum(predFrame2[cohort_column_name] == control_indicator_value)) 
print('size of treatment cohort:') 
print(sum(predFrame2[cohort_column_name] == treatment_indicator_value))
# Out:
# size of dataset:
# 728056
# size of control cohort:
# 588443
# size of treatment cohort:
# 139613

# %%
### we should process the data such that route level cost and gains are per-session 
### so it's possible to rank the routes separately and it should be able to compare with results for 
### using rider information only 

### three data tables: 
### 1. with rider + route features and per route metrics 
### 2. with rider features and per rider metrics 
### 3. with route features and per route metrics 

### for table 1, we can have two algorithms 
### a. train a model on Table 2, score the riders as a feature for route-level model, then use route level model to evaluate 
### b. train a combined model on table 1

# %%
### preprocess the data 
### -- sample treatment to match control cohort 
### -- eliminate nulls, standard normalization 

D = predFrame2 
D = D.sample(frac=1.0) 

"""
feature_list = [ 
    'rating_2driver_min_avg_84d'
    , 'trip_incomplete_total_84d'
    , 'days_active_84d'
    , 'days_since_trip_first_lifetime'
    , 'days_since_last_hard_churn_lifetime'
    , 'days_since_last_soft_churn_lifetime'
    , 'fare_max_sd_84d'
    , 'churns_hard_lifetime'
    , 'trips_lifetime'
    , 'fare_max_p50_84d'
    , 'duration_session_pre_request_max_p50_84d'
    , 'trip_pool_per_x_84d'
    , 'fare_total_win7d_sd_84d'
    , 'trip_complete_win7d_sd_84d'
    , 'session_per_days_active_84d'
    , 'churns_soft_lifetime'
    , 'trip_complete_per_days_active_84d'
    , 'trip_pool_prc_84d'
    , 'session_background_pre_request_prc_84d'
    , 'session_lt_1m_prc_84d'
    , 'session_request_prc_84d'
    , 'duration_session_outside_total_prc_84d'
    , 'trip_x_prc_84d'
    , 'days_since_trip_last_lifetime'
    , 'promo_used_84d'
    , 'has_session_request_84d'
    , 'has_session_without_request_84d' 
    , 'fare_promo_total_avg_84d', 
    'fare_total_avg_84d', 
    'surge_trip_avg_84d', 
    'fare_total_win7d_potential_84d', 
    'fare_total_win28d_potential_84d', 
    'fare_lifetime', 
    'time_to_first_message_minutes_mean_lifetime', 
    'ata_trip_max_avg_84d', 
    'eta_trip_max_avg_84d', 
    'trip_pool_matched_avg_84d', 
    'payment_cash_trip_total_84d', 
    'duration_trip_total_p50_84d'
] 
"""
feature_list = [ 
    'rating_2driver_min_avg_84d'
    , 'days_active_84d'
    , 'days_since_trip_first_lifetime'
    , 'days_since_last_soft_churn_lifetime'
    , 'churns_hard_lifetime'
    , 'fare_max_p50_84d'
    , 'fare_total_win7d_sd_84d'
    , 'trip_complete_win7d_sd_84d'
    , 'trip_pool_prc_84d'
    , 'session_request_prc_84d'
    , 'days_since_trip_last_lifetime'
    , 'fare_promo_total_avg_84d'
    , 'fare_total_avg_84d'
    , 'surge_trip_avg_84d'
    , 'fare_total_win28d_potential_84d'
    , 'ata_trip_max_avg_84d'
    , 'duration_trip_total_p50_84d'
    , 'promo_used_84d'
    #, 'estimate_fare_distance_in_miles' 
    #, 'estimate_fare_duration_in_minutes' 
    #, 'origin_destination_haversine_miles' 
    #, 'origin_lat' 
    #, 'origin_lng'
    #, 'destination_lat'
    #, 'destination_lng'  
] 

label_list = [ 
    'gross_bookings_usd', 
    'variable_contribution_usd', 
    'num_sessions' 
] 

for l in feature_list: 
    print('number of nans: ' + str(sum(D[l] == '\\N'))) 
    D[l] = pd.to_numeric(D[l], errors='coerce') 
    D[l] = D[l] - D[l].mean() 
    D[l] = D[l] / D[l].std() 
    D[l][pd.isnull(D[l])] = 0.0 ## at zero mean due to standard normalization 

for l in label_list: 
    D[l] = pd.to_numeric(D[l], errors='coerce') 
    D[l][pd.isnull(D[l])] = 0.0 ## for zero gain/cost for financial data 

### -- compute simple statistics 
### compute cpit 
treated_entries = D[D[cohort_column_name] == treatment_indicator_value] 
untreated_entries = D[D[cohort_column_name] == control_indicator_value] 

rpu_treated = float(treated_entries[label_list[0]].sum()) / len(treated_entries) 
nipu_treated = float(treated_entries[label_list[1]].sum()) / len(treated_entries) 

rpu_untreated = float(untreated_entries[label_list[0]].sum()) / len(untreated_entries) 
nipu_untreated = float(untreated_entries[label_list[1]].sum()) / len(untreated_entries) 

cpit = -1.0 * (nipu_treated - nipu_untreated) / (rpu_treated - rpu_untreated) 

print('rpu_treated : ' + str(rpu_treated)) 
print('nipu_treated : ' + str(nipu_treated)) 
print('rpu_untreated : ' + str(rpu_untreated)) 
print('nipu_untreated : ' + str(nipu_untreated)) 
print('cpit : ' + str(cpit)) 

### split the data into 3/1/1 train/val/test 
len_tr = int(len(D) / 5 * 3) 
len_va = int(len(D) / 5) 

nX = D[feature_list].values 
w = D[cohort_column_name].apply(lambda x: 1.0 if x == treatment_indicator_value else 0.0) 
w = w.values 
values = D[label_list[0]] 
values = values.values 
negcost = D[label_list[1]] 
negcost = negcost.values * 1.0 
num_sessions = D[label_list[2]].values 
values = np.divide(values, num_sessions) 
negcost = np.divide(negcost, num_sessions) 

## split train/val/test sets 

nX_tr = nX[0:len_tr, :] 
nX_va = nX[len_tr:len_tr + len_va, :] 
nX_te = nX[len_tr + len_va:, :] 

w_tr = w[0:len_tr]
w_va = w[len_tr:len_tr + len_va] 
w_te = w[len_tr + len_va:] 

values_tr = values[0:len_tr] 
values_va = values[len_tr:len_tr + len_va] 
values_te = values[len_tr + len_va:] 

negcost_tr = negcost[0:len_tr] 

negcost_va = negcost[len_tr:len_tr + len_va] 

negcost_te = negcost[len_tr + len_va:] 

## saving data using cPickel and naming the dictionaries 
saveD = {'nX_tr':nX_tr, 
         'w_tr':w_tr, 
         'values_tr':values_tr, 
         'nX_va':nX_va, 
         'w_va':w_va, 
         'values_va':values_va, 
         'nX_te':nX_te, 
         'w_te':w_te, 
         'values_te':values_te, 
         'feature_list':feature_list, 
         #'avg_ni_usd_tr':avg_ni_usd_tr, 
         'negcost_tr': negcost_tr, 
         #'avg_ni_usd_va':avg_ni_usd_va, 
         'negcost_va': negcost_va, 
         #'avg_ni_usd_te':avg_ni_usd_te, 
         'negcost_te': negcost_te 
         } 

pkl.dump(saveD, open('../data/rxgy_ma_training_data_v5_2019_07_08_vc_tr_featuremod3', 'wb'))
# Out:
# number of nans: 98294
# /Users/will.zou/code/deeplearning_hscls/py3/lib/python3.6/site-packages/ipykernel_launcher.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# number of nans: 7933
# number of nans: 7933
# number of nans: 7945
# number of nans: 7945
# number of nans: 7933
# number of nans: 7933
# number of nans: 7933
# number of nans: 11614
# number of nans: 11614
# number of nans: 7933
# number of nans: 403240
# number of nans: 7933
# number of nans: 7933
# number of nans: 7984
# number of nans: 8080
# number of nans: 7933
# number of nans: 11614
# number of nans: 3
# number of nans: 3
# /Users/will.zou/code/deeplearning_hscls/py3/lib/python3.6/site-packages/pandas/core/ops/__init__.py:1115: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# number of nans: 0
# number of nans: 0
# number of nans: 0
# number of nans: 0
# number of nans: 0
# /Users/will.zou/code/deeplearning_hscls/py3/lib/python3.6/site-packages/ipykernel_launcher.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# rpu_treated : 137.9587917096474
# nipu_treated : -8.515010366084773
# rpu_untreated : 116.76778678196814
# nipu_untreated : 12.152768245155467
# cpit : 0.9753090371020783

# %%
negcost
# Out:
# array([ 2.42485255, -1.08694427,  1.87554114, ...,  2.1195274 ,
#         0.32181707,  3.20839833])

# %%
### code implements ranking model for treatment effect 
### for optimizing with respect to direct marketplace objectives 
### using tensorflow 

import numpy as np, tensorflow as tf, pandas as pd, pickle as pkl 
sys.path.append('../')  
from ModelDefinitions import * 
from DataProcFunctions import * 

### RxGy TQR setting: 
p_quantile = 0.4 ## percentage of quantile to aim for 
num_optimize_iterations = 2500 ## number of optimization iterations 
num_modeling_inits = 4 ## number of random initializations 
num_hidden = 0 ## number of hidden units in DNN 
use_schedule = True ## option to use a constraint annealing schedule 
temp = 0.5 ## initial temperature for constraints 
inc_temp = 0.1 ## increment of temperature per 100 iterations 
save_cf_data = False ### whether to save data for causal forest training 

## set a random seed to reproduce results 
seed = 1234; tf.compat.v2.random.set_seed(seed); np.random.seed(seed) 

sample_frac = 1.0 ## option to sample data by a fraction \in (0, 1) 
data_filename =  '../data/rxgy_ma_training_data_v5_2019_07_08_vc_tr_featuremod3' 
prefix = 'rxgy_v5_07_08_featuremod3_tr_iter100_run4' 

D_tre, D_unt, Dv_tre, Dv_unt, Dt_tre, Dt_unt, o_tre, o_unt, ov_tre, ov_unt, ot_tre, ot_unt, c_tre, c_unt, cv_tre, cv_unt, ct_tre, ct_unt, D, w, o, c, Dv, wv, ov, cv, Dt, wt, ot, ct = LoadDataFromPkl(data_filename, frac = sample_frac, use_python3=use_python3, save_cf_data=save_cf_data) 

print('### ----- start the training of deep learning models ------ ') 
gs_tqr = [] 
gs_drm = [] 
for i in range(num_modeling_inits): 
    gs_tqr.append(tf.Graph()) 
for i in range(num_modeling_inits): 
    gs_drm.append(tf.Graph()) 

print('------> Training TQR ranking model .... ') 
val_results = [] 
sess_list = [] 
for i in range(num_modeling_inits): 
    print('---> running cross validation, iteration: ' + str(i)) 
    obj, opt, dumh, dumhu, vtemp, p_quantile = TunableTQRankingModelDNN(gs_tqr[i], D_tre, D_unt, o_tre, o_unt, c_tre, c_unt, 'train-first', temp, p_quantile, num_hidden, use_schedule) 
    ### session definitions and variable initialization 
    sess = tf.Session(graph = gs_tqr[i]) 
    sess_list.append(sess) 
    
    ### initialize variables and run optimization 
    with gs_tqr[i].as_default() as g: 
        init = tf.global_variables_initializer() 
    sess.run(init) 
    cur_temp = temp 
    for step in range(num_optimize_iterations): 
        _, objres = sess.run([opt, obj]) 
        if step % 100 == 0: 
            cur_temp = cur_temp + inc_temp 
            print('opt. step : ' + str(step) + ' obj: ' + str(objres)) 
            if use_schedule: 
                sess.run(vtemp.assign(cur_temp))
                print('setting temperature to :' + str(sess.run(vtemp))) 
    
    print('---> optimization finished ... ') 
    tempvalue = sess.run(vtemp)
    p_quantilevalue = p_quantile
    print('temp:') 
    print(tempvalue)
    print('p_quantile:')
    print(p_quantilevalue) 
    
    ### evaluate CPIT metric on validation set 
    objv, dumo, dumh, dumhu, dvtemp, dp_quantile = TunableTQRankingModelDNN(gs_tqr[i], Dv_tre, Dv_unt, ov_tre, ov_unt, cv_tre, cv_unt, 'eval', temp, p_quantile, num_hidden, use_schedule) 
    
    val_result = sess.run(objv) 
    print('validation CPIT:') 
    print(val_result) 
    val_results.append(val_result) 

from operator import itemgetter 
best_index = min(enumerate(val_results), key=itemgetter(1))[0] 

print('best performing model: iteration ' + str(best_index)) 

### run scoring on whole test set 
with gs_tqr[best_index].as_default() as g: 
    if num_hidden > 0: 
        with tf.variable_scope("tqrhidden") as scope: 
            h1_test = tf.contrib.layers.fully_connected(Dt, num_hidden, activation_fn=tf.nn.tanh, reuse=tf.AUTO_REUSE, scope=scope, weights_initializer=tf.contrib.layers.xavier_initializer()) 
        with tf.variable_scope("tqranker") as scope: 
            h_test = tf.contrib.layers.fully_connected(h1_test, 1, activation_fn=None, reuse=tf.AUTO_REUSE, scope=scope) 
    else: 
        with tf.variable_scope("tqranker") as scope: 
            h_test = tf.contrib.layers.fully_connected(Dt, 1, activation_fn=None, reuse=tf.AUTO_REUSE, scope=scope) 
    tqrscore = sess_list[best_index].run(h_test) 

print('------> Training DRM ranking model .... ') 
sess_list = [] 
val_results = [] 
for i in range(num_modeling_inits): 
    print('---> running cross validation, iteration: ' + str(i)) 
    ### ---- train cpit ranking model for comparison --- 
    dobjc, doptc, ddumh, ddumu = DirectRankingModelDNN(gs_drm[i], D_tre, D_unt, o_tre, o_unt, c_tre, c_unt, 'train-first-drm', num_hidden) 
    
    dsess = tf.Session(graph = gs_drm[i]) 
    sess_list.append(dsess) 
    
    ### initialize variables and run optimization 
    with gs_drm[i].as_default() as g: 
        dinit = tf.global_variables_initializer() 
    dsess.run(dinit) 
    for step in range(num_optimize_iterations): 
        _, dobjres = dsess.run([doptc, dobjc]) 
        if step % 100 == 0: 
            print('opt. step : ' + str(step) + ' obj: ' + str(dobjres)) 
    
    print('---> optimization finished ... ') 
    
    ### evaluate CPIT metric on validation set 
    dobjv, ddumo, dumh, dumhu = DirectRankingModelDNN(gs_drm[i], Dv_tre, Dv_unt, ov_tre, ov_unt, cv_tre, cv_unt, 'eval', num_hidden)
    val_result = dsess.run(dobjv) 
    print('validation CPIT:') 
    print(val_result) 
    val_results.append(val_result) 

best_index = min(enumerate(val_results), key=itemgetter(1))[0] 

print('best performing model: iteration ' + str(best_index)) 

### run scoring on whole test set 
with gs_drm[best_index].as_default() as g: 
    if num_hidden > 0: 
        with tf.variable_scope("drmhidden") as scope: 
            h1_test = tf.contrib.layers.fully_connected(Dt, num_hidden, activation_fn=tf.nn.tanh, reuse=tf.AUTO_REUSE, scope=scope, weights_initializer=tf.contrib.layers.xavier_initializer()) 
        with tf.variable_scope("drmranker") as scope: 
            h_test = tf.contrib.layers.fully_connected(h1_test, 1, activation_fn=tf.nn.tanh, reuse=tf.AUTO_REUSE, scope=scope) 
    else: 
        with tf.variable_scope("drmranker") as scope: 
            h_test = tf.contrib.layers.fully_connected(Dt, 1, activation_fn=tf.nn.tanh, reuse=tf.AUTO_REUSE, scope=scope) 
    drmscore = sess_list[best_index].run(h_test) 

### ---- train hte model for comparison ---- 
### we could utimize the original HTE functions 
from LinearHTEModels import * 
from PromotionModels import PromotionModels 

pmodels = PromotionModels() 

## set-up RLearner 
rl_ridge_model_O, rl_ridge_model_C = pmodels.fit_rlearner(D, o, c, w) 

## one model for order lift and one model for cost drop 
pred_values_va_rlearner_O = rl_ridge_model_O.predict(Dt) 
pred_values_va_rlearner_C = rl_ridge_model_C.predict(Dt) 

#plt.imagesc(np.concatneate(rl_ridge_model_O.params, ...params), axis=1) 

#if ranking_model == 'effectiveness-ratio': ## if we use the effectiveness ratio model, compute effectiveness ratio 
pred_values_va_rlearner = np.divide(np.maximum(pred_values_va_rlearner_O, 0), pred_values_va_rlearner_C + 1e-7) 

lhmodels = LinearHTEModels() 
lambds = [0.1] 
rlearnerscores = [] 
rl_ridge_model_L_list = [] 
## set-up lagrangian rlearner 
for i in range(len(lambds)): 
    lambd = lambds[i] 
    rl_ridge_model_L = lhmodels.fit_rlearner_lagrangian(D, o, c, w, lambd) 
    rl_ridge_model_L_list.append(rl_ridge_model_L) 
    rlearnerscores.append(rl_ridge_model_L.predict(Dt)) 

""" 
### this section is to load the results trained by grf R code 
### 

ot_cf = pd.read_csv('../results/causal_forest_grf_test_set_results_O_finalsize_numtrees1002.csv') 
ct_cf = pd.read_csv('../results/causal_forest_grf_test_set_results_C_finalsize_numtrees1002.csv') 

ot_cf = ot_cf.values() 
Ocfscores = ot_cf[0] 

ct_cf = ct_cf.values() 
Ccfscores = ct_cf[0] 

cfscore = np.divide(Ocfscores, Ccfscores) 
""" 

### ---- experimentation and plotting cost-curves ----- 
from experimentation import * 
exp = Experimentation() 
ranscore = np.random.rand(ot.shape[0], ) 
colors = ['b', 'c', 'g', 'y'] 
plt.figure() 
rlearnerauccs = [] 
ranaucc = exp.AUC_cpit_cost_curve_deciles_cohort(ranscore, ot, wt, -1.0 * ct, 'k', plot_random=True) 
quasiaucc = exp.AUC_cpit_cost_curve_deciles_cohort(pred_values_va_rlearner_O, ot, wt, -1.0 * ct, 'c') 
for i in range(len(lambds)): 
    rlearnerauccs.append(exp.AUC_cpit_cost_curve_deciles_cohort(rlearnerscores[i], ot, wt, -1.0 * ct, colors[i] )) 
#cfaucc = exp.AUC_cpit_cost_curve_deciles_cohort(cfscore, ot, wt, -1.0 * ct, 'g') # causal forest aucc and plotting 
tqraucc = exp.AUC_cpit_cost_curve_deciles_cohort(tqrscore, ot, wt, -1.0 * ct, 'r' ) 
drmaucc = exp.AUC_cpit_cost_curve_deciles_cohort(drmscore, ot, wt, -1.0 * ct, 'm' ) 
plt.title('Causal learning cost curves using targeting models') 

print('temp:') 
print(tempvalue) 
print('p_quantile:') 
print(p_quantilevalue) 

### --- add legeneds to plot ---- 
leg_str = ['Random'] 
leg_str.append('R-learner on Incremental Gain') 
for i in range(len(lambds)): 
    leg_str.append('Duality R-learner') 
#leg_str.append('Causal Forest') # causal forest result 
leg_str.append('Top Quantile Ranking at ' + str(p_quantile*100) + '%') 
leg_str.append('Direct Ranking Model') 
plt.legend(leg_str) 

### --- print out aucc results for different models --- 
print('AUCC results: ') 
print('random: ' + str(ranaucc)) 
print('rlearner: ' + str(quasiaucc)) 
i = 0
for rlearneraucc in rlearnerauccs: 
    print('duality rlearner ' + str(i + 1) + ' with lambda = ' + str(lambds[i]) + ':' + str(rlearneraucc)) 
    i = i + 1
print('drm: ' + str(drmaucc)) 
print('tqr: ' + str(tqraucc)) 

plt.show() 

### --- saving data to results folder ---- 
save_filename = '../results/benchmarkwithcv_tqr_drm_hte_'+prefix+'_main_results.pkl' 
saveD = {'tqrscore':tqrscore, 'drmscore':drmscore, 'quasiscore':pred_values_va_rlearner, 'quasiscore_O':pred_values_va_rlearner_O, 'rlearnerscore':rlearnerscores, 'ot':ot, 'wt':wt, 'ct':ct, 'tempvalue':tempvalue, 'p_quantilevalue':p_quantilevalue, 
         'tqraucc':tqraucc, 'drmaucc':drmaucc, 'rlearnerauccs':rlearnerauccs, 'ranaucc':ranaucc, 'quasiaucc':quasiaucc} 
#'cfscore':cfscore, causal forest scores 
pkl.dump(saveD, open(save_filename, 'wb'))
# Out:
# load data from ../data/rxgy_ma_training_data_v5_2019_07_08_vc_tr_featuremod3
# printing averages of c_tr, c_unt, o_tre, o_unt ... :
# 0.9089009895912447
# -1.3459909906770622
# 13.505787105974703
# 12.320268002543962
# ### ----- start the training of deep learning models ------
# ------> Training TQR ranking model ....
# ---> running cross validation, iteration: 0
# WARNING:tensorflow:From ../ModelDefinitions.py:37: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From ../ModelDefinitions.py:37: The name tf.AUTO_REUSE is deprecated. Please use tf.compat.v1.AUTO_REUSE instead.
#
# WARNING:tensorflow:From ../ModelDefinitions.py:38: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /Users/will.zou/code/deeplearning_hscls/py3/lib/python3.6/site-packages/tensorflow_core/contrib/layers/python/layers/layers.py:1866: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From ../ModelDefinitions.py:74: The name tf.ceil is deprecated. Please use tf.math.ceil instead.
#
# WARNING:tensorflow:From ../ModelDefinitions.py:115: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# opt. step : 0 obj: 1.9696723434890837
# setting temperature to :0.6
# opt. step : 100 obj: 1.8741149413905969
# setting temperature to :0.7
# opt. step : 200 obj: 1.7560582348146263
# setting temperature to :0.7999999999999999
# opt. step : 300 obj: 1.6464557997131115
# setting temperature to :0.8999999999999999
# opt. step : 400 obj: 1.5756152279372568
# setting temperature to :0.9999999999999999
# opt. step : 500 obj: 1.523818596355517
# setting temperature to :1.0999999999999999
# opt. step : 600 obj: 1.4794340603230736
# setting temperature to :1.2
# opt. step : 700 obj: 1.4453140169343135
# setting temperature to :1.3
# opt. step : 800 obj: 1.4179437716736163
# setting temperature to :1.4000000000000001
# opt. step : 900 obj: 1.3959237216412042
# setting temperature to :1.5000000000000002
# opt. step : 1000 obj: 1.375680113048844
# setting temperature to :1.6000000000000003
# opt. step : 1100 obj: 1.357057269290999
# setting temperature to :1.7000000000000004
# opt. step : 1200 obj: 1.3407562136407822
# setting temperature to :1.8000000000000005
# opt. step : 1300 obj: 1.3265772273614305
# setting temperature to :1.9000000000000006
# opt. step : 1400 obj: 1.3124357226135632
# setting temperature to :2.0000000000000004
# opt. step : 1500 obj: 1.2998551041562882
# setting temperature to :2.1000000000000005
# opt. step : 1600 obj: 1.2895170817935704
# setting temperature to :2.2000000000000006
# opt. step : 1700 obj: 1.2798024356435471
# setting temperature to :2.3000000000000007
# opt. step : 1800 obj: 1.2716289213190637
# setting temperature to :2.400000000000001
# opt. step : 1900 obj: 1.2649220938581804
# setting temperature to :2.500000000000001
# opt. step : 2000 obj: 1.258857255683011
# setting temperature to :2.600000000000001
# opt. step : 2100 obj: 1.2535987317443615
# setting temperature to :2.700000000000001
# opt. step : 2200 obj: 1.249201557663349
# setting temperature to :2.800000000000001
# opt. step : 2300 obj: 1.245014138776498
# setting temperature to :2.9000000000000012
# opt. step : 2400 obj: 1.2412892663356325
# setting temperature to :3.0000000000000013
# ---> optimization finished ...
# temp:
# 3.0407469883364677
# p_quantile:
# 0.4
# validation CPIT:
# 1.36230283127792
# ---> running cross validation, iteration: 1
# opt. step : 0 obj: 1.975506543083159
# setting temperature to :0.6
# opt. step : 100 obj: 1.879363631694109
# setting temperature to :0.7
# opt. step : 200 obj: 1.7214420641620265
# setting temperature to :0.7999999999999999
# opt. step : 300 obj: 1.6020848653721054
# setting temperature to :0.8999999999999999
# opt. step : 400 obj: 1.534783274526927
# setting temperature to :0.9999999999999999
# opt. step : 500 obj: 1.4867336760391379
# setting temperature to :1.0999999999999999
# opt. step : 600 obj: 1.4515289986975173
# setting temperature to :1.2
# opt. step : 700 obj: 1.4246705102756436
# setting temperature to :1.3
# opt. step : 800 obj: 1.4034624368149005
# setting temperature to :1.4000000000000001
# opt. step : 900 obj: 1.386258326916548
# setting temperature to :1.5000000000000002
# opt. step : 1000 obj: 1.3726158968051723
# setting temperature to :1.6000000000000003
# opt. step : 1100 obj: 1.3605597102300044
# setting temperature to :1.7000000000000004
# opt. step : 1200 obj: 1.3475541658234407
# setting temperature to :1.8000000000000005
# opt. step : 1300 obj: 1.3357674636878507
# setting temperature to :1.9000000000000006
# opt. step : 1400 obj: 1.3269100050894256
# setting temperature to :2.0000000000000004
# opt. step : 1500 obj: 1.3192870033383965
# setting temperature to :2.1000000000000005
# opt. step : 1600 obj: 1.3120896928169998
# setting temperature to :2.2000000000000006
# opt. step : 1700 obj: 1.3042666784558279
# setting temperature to :2.3000000000000007
# opt. step : 1800 obj: 1.2944455580323584
# setting temperature to :2.400000000000001
# opt. step : 1900 obj: 1.2869097032493066
# setting temperature to :2.500000000000001
# opt. step : 2000 obj: 1.2804303452912542
# setting temperature to :2.600000000000001
# opt. step : 2100 obj: 1.2739363262914172
# setting temperature to :2.700000000000001
# opt. step : 2200 obj: 1.2669867028517896
# setting temperature to :2.800000000000001
# opt. step : 2300 obj: 1.2606979843558044
# setting temperature to :2.9000000000000012
# opt. step : 2400 obj: 1.2551317447542523
# setting temperature to :3.0000000000000013
# ---> optimization finished ...
# temp:
# 3.0341838744441554
# p_quantile:
# 0.4
# validation CPIT:
# 1.3648397320986587
# ---> running cross validation, iteration: 2
# opt. step : 0 obj: 1.943711236204674
# setting temperature to :0.6
# opt. step : 100 obj: 1.8455362880374222
# setting temperature to :0.7
# opt. step : 200 obj: 1.6981406539494424
# setting temperature to :0.7999999999999999
# opt. step : 300 obj: 1.5949890419693464
# setting temperature to :0.8999999999999999
# opt. step : 400 obj: 1.529348944676629
# setting temperature to :0.9999999999999999
# opt. step : 500 obj: 1.4854147126980561
# setting temperature to :1.0999999999999999
# opt. step : 600 obj: 1.4525028108852902
# setting temperature to :1.2
# opt. step : 700 obj: 1.4257893923847358
# setting temperature to :1.3
# opt. step : 800 obj: 1.4029177263155805
# setting temperature to :1.4000000000000001
# opt. step : 900 obj: 1.3817212659486506
# setting temperature to :1.5000000000000002
# opt. step : 1000 obj: 1.3593183684485113
# setting temperature to :1.6000000000000003
# opt. step : 1100 obj: 1.337932008913581
# setting temperature to :1.7000000000000004
# opt. step : 1200 obj: 1.3220580939403241
# setting temperature to :1.8000000000000005
# opt. step : 1300 obj: 1.3094318654184922
# setting temperature to :1.9000000000000006
# opt. step : 1400 obj: 1.298992005175866
# setting temperature to :2.0000000000000004
# opt. step : 1500 obj: 1.2903157005026176
# setting temperature to :2.1000000000000005
# opt. step : 1600 obj: 1.282860936951029
# setting temperature to :2.2000000000000006
# opt. step : 1700 obj: 1.2761557719578307
# setting temperature to :2.3000000000000007
# opt. step : 1800 obj: 1.2699358662997513
# setting temperature to :2.400000000000001
# opt. step : 1900 obj: 1.2642401485342105
# setting temperature to :2.500000000000001
# opt. step : 2000 obj: 1.2589458482653255
# setting temperature to :2.600000000000001
# opt. step : 2100 obj: 1.2537345350721283
# setting temperature to :2.700000000000001
# opt. step : 2200 obj: 1.2486981412813034
# setting temperature to :2.800000000000001
# opt. step : 2300 obj: 1.2436686733440279
# setting temperature to :2.9000000000000012
# opt. step : 2400 obj: 1.2388999364335358
# setting temperature to :3.0000000000000013
# ---> optimization finished ...
# temp:
# 3.034993328506461
# p_quantile:
# 0.4
# validation CPIT:
# 1.3861932920726903
# ---> running cross validation, iteration: 3
# opt. step : 0 obj: 1.9035717425575955
# setting temperature to :0.6
# opt. step : 100 obj: 1.787322814387285
# setting temperature to :0.7
# opt. step : 200 obj: 1.6862554804440981
# setting temperature to :0.7999999999999999
# opt. step : 300 obj: 1.613245384197245
# setting temperature to :0.8999999999999999
# opt. step : 400 obj: 1.5580944486771788
# setting temperature to :0.9999999999999999
# opt. step : 500 obj: 1.5143964562495824
# setting temperature to :1.0999999999999999
# opt. step : 600 obj: 1.4785643349940345
# setting temperature to :1.2
# opt. step : 700 obj: 1.4484559195126276
# setting temperature to :1.3
# opt. step : 800 obj: 1.4221947683525202
# setting temperature to :1.4000000000000001
# opt. step : 900 obj: 1.3988481516933804
# setting temperature to :1.5000000000000002
# opt. step : 1000 obj: 1.3774224594222324
# setting temperature to :1.6000000000000003
# opt. step : 1100 obj: 1.3569125568337996
# setting temperature to :1.7000000000000004
# opt. step : 1200 obj: 1.3393503913878106
# setting temperature to :1.8000000000000005
# opt. step : 1300 obj: 1.3260143890916238
# setting temperature to :1.9000000000000006
# opt. step : 1400 obj: 1.3135768252899729
# setting temperature to :2.0000000000000004
# opt. step : 1500 obj: 1.2992371473077446
# setting temperature to :2.1000000000000005
# opt. step : 1600 obj: 1.2895599103606956
# setting temperature to :2.2000000000000006
# opt. step : 1700 obj: 1.2819704935392278
# setting temperature to :2.3000000000000007
# opt. step : 1800 obj: 1.2752777533207595
# setting temperature to :2.400000000000001
# opt. step : 1900 obj: 1.2689035996639892
# setting temperature to :2.500000000000001
# opt. step : 2000 obj: 1.2606503275637142
# setting temperature to :2.600000000000001
# opt. step : 2100 obj: 1.2527351102885431
# setting temperature to :2.700000000000001
# opt. step : 2200 obj: 1.2458254195777763
# setting temperature to :2.800000000000001
# opt. step : 2300 obj: 1.2397153140587431
# setting temperature to :2.9000000000000012
# opt. step : 2400 obj: 1.2349163858032441
# setting temperature to :3.0000000000000013
# ---> optimization finished ...
# temp:
# 3.041762285521891
# p_quantile:
# 0.4
# validation CPIT:
# 1.3515115084690072
# best performing model: iteration 3
# ------> Training DRM ranking model ....
# ---> running cross validation, iteration: 0
# opt. step : 0 obj: 1.503485766050804
# opt. step : 100 obj: 1.2506380422491536
# opt. step : 200 obj: 1.1343061697057701
# opt. step : 300 obj: 1.0596787347926264
# opt. step : 400 obj: 1.013964273886445
# opt. step : 500 obj: 0.9833732230852971
# opt. step : 600 obj: 0.9615200309285934
# opt. step : 700 obj: 0.9445140919996018
# opt. step : 800 obj: 0.9307506022788856
# opt. step : 900 obj: 0.9193100981671273
# opt. step : 1000 obj: 0.909595648161598
# opt. step : 1100 obj: 0.9011962164420301
# opt. step : 1200 obj: 0.893819547220803
# opt. step : 1300 obj: 0.8872550698806291
# opt. step : 1400 obj: 0.8813477175880282
# opt. step : 1500 obj: 0.8759805712540697
# opt. step : 1600 obj: 0.8710634534052746
# opt. step : 1700 obj: 0.8665252110627479
# opt. step : 1800 obj: 0.8623082868712294
# opt. step : 1900 obj: 0.85836488241573
# opt. step : 2000 obj: 0.8546549595412937
# opt. step : 2100 obj: 0.8511467028694262
# opt. step : 2200 obj: 0.8478174815326683
# opt. step : 2300 obj: 0.844651702163432
# opt. step : 2400 obj: 0.8416368134067804
# ---> optimization finished ...
# validation CPIT:
# 0.9134588960756327
# ---> running cross validation, iteration: 1
# opt. step : 0 obj: 1.9557745341818715
# opt. step : 100 obj: 1.5659101037327097
# opt. step : 200 obj: 1.4468017030329015
# opt. step : 300 obj: 1.383751587197554
# opt. step : 400 obj: 1.3351057408257456
# opt. step : 500 obj: 1.292916842589104
# opt. step : 600 obj: 1.254759171872452
# opt. step : 700 obj: 1.22157656792849
# opt. step : 800 obj: 1.1949871124774356
# opt. step : 900 obj: 1.174339722095912
# opt. step : 1000 obj: 1.156511231929645
# opt. step : 1100 obj: 1.1366138324638422
# opt. step : 1200 obj: 1.1005762086938866
# opt. step : 1300 obj: 1.0323060188840332
# opt. step : 1400 obj: 0.9741811346064068
# opt. step : 1500 obj: 0.9506039213188767
# opt. step : 1600 obj: 0.9335167761624625
# opt. step : 1700 obj: 0.9208079750187401
# opt. step : 1800 obj: 0.9108941592798667
# opt. step : 1900 obj: 0.9024674265596065
# opt. step : 2000 obj: 0.8947794142826064
# opt. step : 2100 obj: 0.8877606189656021
# opt. step : 2200 obj: 0.8814889830869568
# opt. step : 2300 obj: 0.875704715682544
# opt. step : 2400 obj: 0.8701373716651889
# ---> optimization finished ...
# validation CPIT:
# 0.971761889188612
# ---> running cross validation, iteration: 2
# opt. step : 0 obj: 2.00842040162321
# opt. step : 100 obj: 1.6434345358240834
# opt. step : 200 obj: 1.4591465802415995
# opt. step : 300 obj: 1.3436477021159794
# opt. step : 400 obj: 1.2583821382263825
# opt. step : 500 obj: 1.190544575770722
# opt. step : 600 obj: 1.1371335634223545
# opt. step : 700 obj: 1.0933176731465877
# opt. step : 800 obj: 1.0589338367742946
# opt. step : 900 obj: 1.0331134696231346
# opt. step : 1000 obj: 1.0123917039430643
# opt. step : 1100 obj: 0.9947537417277557
# opt. step : 1200 obj: 0.9794214485382283
# opt. step : 1300 obj: 0.9661145923822336
# opt. step : 1400 obj: 0.9541569629055966
# opt. step : 1500 obj: 0.9436558514623815
# opt. step : 1600 obj: 0.9347464287545507
# opt. step : 1700 obj: 0.926847709171073
# opt. step : 1800 obj: 0.9197465080028886
# opt. step : 1900 obj: 0.9134005002657607
# opt. step : 2000 obj: 0.9076737436659382
# opt. step : 2100 obj: 0.9024448551586777
# opt. step : 2200 obj: 0.8976306420710768
# opt. step : 2300 obj: 0.8931700093283057
# opt. step : 2400 obj: 0.8890105522179401
# ---> optimization finished ...
# validation CPIT:
# 0.9736307422574821
# ---> running cross validation, iteration: 3
# opt. step : 0 obj: 1.48328522618246
# opt. step : 100 obj: 1.3347095395028485
# opt. step : 200 obj: 1.2209038920432944
# opt. step : 300 obj: 1.1449495037513926
# opt. step : 400 obj: 1.0944645509575102
# opt. step : 500 obj: 1.0539741224146348
# opt. step : 600 obj: 1.0267507617147014
# opt. step : 700 obj: 1.0002431549094255
# opt. step : 800 obj: 0.9716115063973902
# opt. step : 900 obj: 0.9508209970597291
# opt. step : 1000 obj: 0.9350774813382948
# opt. step : 1100 obj: 0.9225376990908524
# opt. step : 1200 obj: 0.9120524920080195
# opt. step : 1300 obj: 0.9030647453317625
# opt. step : 1400 obj: 0.8952915071831593
# opt. step : 1500 obj: 0.8885467446165977
# opt. step : 1600 obj: 0.8826361564234587
# opt. step : 1700 obj: 0.8774081770360793
# opt. step : 1800 obj: 0.8727339062130707
# opt. step : 1900 obj: 0.8685132844068125
# opt. step : 2000 obj: 0.8646689002035078
# opt. step : 2100 obj: 0.8611330323791972
# opt. step : 2200 obj: 0.8578772136019173
# opt. step : 2300 obj: 0.8548826654575117
# opt. step : 2400 obj: 0.8521036660495973
# ---> optimization finished ...
# validation CPIT:
# 0.9872118691112741
# best performing model: iteration 0
# rpu_control: 12.311494825154343
# nipu_control: 1.4018543060049007
# rpu_ft: 13.557862730571786
# nipu_ft: -0.899593703495978
# ---------------------------->>>>>>
# perc - target: 0.10
# treated_target_rpu: 13.82
# treated_target_nipu: -0.47
# nontreated_target_rpu: 12.18
# nontreated_target_nipu: 1.21
# treated_nontarget_rpu: 13.53
# treated_nontarget_nipu: -0.95
# nontreated_nontarget_rpu: 12.33
# nontreated_nontarget_nipu: 1.42
# --- with 9.999862648682802% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.0266854638109486
# --> in non-targeted users:
# cpit = 1.9723425358234168
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 12.48
# nipu_cohort: 1.23
# lift targeted cohort vs control: 0.01
# lift random vs control: 0.10
# cpit cohort vs control: 1.03
# lift targeted-treated vs control: 0.12
# cpit cohort: 1.027628
# ---------------------------->>>>>>
# perc - target: 0.20
# treated_target_rpu: 13.59
# treated_target_nipu: -0.51
# nontreated_target_rpu: 12.34
# nontreated_target_nipu: 1.22
# treated_nontarget_rpu: 13.55
# treated_nontarget_nipu: -1.00
# nontreated_nontarget_rpu: 12.30
# nontreated_nontarget_nipu: 1.45
# --- with 19.999725297365604% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.3916561138256545
# --> in non-targeted users:
# cpit = 1.9602135336237327
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 12.56
# nipu_cohort: 1.06
# lift targeted cohort vs control: 0.02
# lift random vs control: 0.10
# cpit cohort vs control: 1.39
# lift targeted-treated vs control: 0.10
# cpit cohort: 1.391826
# ---------------------------->>>>>>
# perc - target: 0.30
# treated_target_rpu: 13.41
# treated_target_nipu: -0.49
# nontreated_target_rpu: 12.33
# nontreated_target_nipu: 1.30
# treated_nontarget_rpu: 13.62
# treated_nontarget_nipu: -1.07
# nontreated_nontarget_rpu: 12.30
# nontreated_nontarget_nipu: 1.45
# --- with 29.9995879460484% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.6497947020438977
# --> in non-targeted users:
# cpit = 1.9162699661878213
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 12.64
# nipu_cohort: 0.86
# lift targeted cohort vs control: 0.03
# lift random vs control: 0.10
# cpit cohort vs control: 1.65
# lift targeted-treated vs control: 0.09
# cpit cohort: 1.649884
# ---------------------------->>>>>>
# perc - target: 0.40
# treated_target_rpu: 13.48
# treated_target_nipu: -0.48
# nontreated_target_rpu: 12.29
# nontreated_target_nipu: 1.33
# treated_nontarget_rpu: 13.61
# treated_nontarget_nipu: -1.18
# nontreated_nontarget_rpu: 12.33
# nontreated_nontarget_nipu: 1.45
# --- with 39.99945059473121% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.5235354295119634
# --> in non-targeted users:
# cpit = 2.0471747767511292
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 12.79
# nipu_cohort: 0.68
# lift targeted cohort vs control: 0.04
# lift random vs control: 0.10
# cpit cohort vs control: 1.52
# lift targeted-treated vs control: 0.09
# cpit cohort: 1.523752
# ---------------------------->>>>>>
# perc - target: 0.50
# treated_target_rpu: 13.51
# treated_target_nipu: -0.48
# nontreated_target_rpu: 12.31
# nontreated_target_nipu: 1.36
# treated_nontarget_rpu: 13.61
# treated_nontarget_nipu: -1.32
# nontreated_nontarget_rpu: 12.31
# nontreated_nontarget_nipu: 1.44
# --- with 49.99931324341401% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.5395237776949984
# --> in non-targeted users:
# cpit = 2.1327207231202827
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 12.91
# nipu_cohort: 0.48
# lift targeted cohort vs control: 0.05
# lift random vs control: 0.10
# cpit cohort vs control: 1.54
# lift targeted-treated vs control: 0.10
# cpit cohort: 1.539591
# ---------------------------->>>>>>
# perc - target: 0.60
# treated_target_rpu: 13.46
# treated_target_nipu: -0.47
# nontreated_target_rpu: 12.33
# nontreated_target_nipu: 1.39
# treated_nontarget_rpu: 13.71
# treated_nontarget_nipu: -1.56
# nontreated_nontarget_rpu: 12.29
# nontreated_nontarget_nipu: 1.43
# --- with 59.9991758920968% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.6370858723860124
# --> in non-targeted users:
# cpit = 2.09964920489435
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 12.99
# nipu_cohort: 0.29
# lift targeted cohort vs control: 0.06
# lift random vs control: 0.10
# cpit cohort vs control: 1.64
# lift targeted-treated vs control: 0.09
# cpit cohort: 1.637061
# ---------------------------->>>>>>
# perc - target: 0.70
# treated_target_rpu: 13.48
# treated_target_nipu: -0.46
# nontreated_target_rpu: 12.31
# nontreated_target_nipu: 1.39
# treated_nontarget_rpu: 13.74
# treated_nontarget_nipu: -1.93
# nontreated_nontarget_rpu: 12.32
# nontreated_nontarget_nipu: 1.42
# --- with 69.9990385407796% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.5814503942423705
# --> in non-targeted users:
# cpit = 2.360413172752859
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.13
# nipu_cohort: 0.10
# lift targeted cohort vs control: 0.07
# lift random vs control: 0.10
# cpit cohort vs control: 1.58
# lift targeted-treated vs control: 0.09
# cpit cohort: 1.581470
# ---------------------------->>>>>>
# perc - target: 0.80
# treated_target_rpu: 13.53
# treated_target_nipu: -0.69
# nontreated_target_rpu: 12.32
# nontreated_target_nipu: 1.40
# treated_nontarget_rpu: 13.67
# treated_nontarget_nipu: -1.74
# nontreated_nontarget_rpu: 12.28
# nontreated_nontarget_nipu: 1.42
# --- with 79.99890118946242% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.7283182567420796
# --> in non-targeted users:
# cpit = 2.2571484836626294
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.28
# nipu_cohort: -0.27
# lift targeted cohort vs control: 0.08
# lift random vs control: 0.10
# cpit cohort vs control: 1.73
# lift targeted-treated vs control: 0.10
# cpit cohort: 1.728308
# ---------------------------->>>>>>
# perc - target: 0.90
# treated_target_rpu: 13.57
# treated_target_nipu: -0.95
# nontreated_target_rpu: 12.33
# nontreated_target_nipu: 1.40
# treated_nontarget_rpu: 13.43
# treated_nontarget_nipu: -0.48
# nontreated_nontarget_rpu: 12.16
# nontreated_nontarget_nipu: 1.44
# --- with 89.99876383814521% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.8852759277004691
# --> in non-targeted users:
# cpit = 1.5056897092605532
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.43
# nipu_cohort: -0.71
# lift targeted cohort vs control: 0.09
# lift random vs control: 0.10
# cpit cohort vs control: 1.89
# lift targeted-treated vs control: 0.10
# cpit cohort: 1.885242
# ../experimentation.py:109: RuntimeWarning: invalid value encountered in long_scalars
#   treated_untarget_rpu = sum(1.0 * values[treated_untargeted_filter]) / sum(treated_untargeted_filter)
# rpu_cohort
# 13.43034810337717
# treated_target_rpu
# 13.557862730571985
# ---------------------------->>>>>>
# perc - target: 1.00
# treated_target_rpu: 13.56
# treated_target_nipu: -0.90
# nontreated_target_rpu: 12.31
# nontreated_target_nipu: 1.40
# treated_nontarget_rpu: nan
# treated_nontarget_nipu: nan
# nontreated_nontarget_rpu: 22.48
# nontreated_nontarget_nipu: 2.50
# --- with 99.99862648682802% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.8462525167007087
# --> in non-targeted users:
# cpit = nan
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.56
# nipu_cohort: -0.90
# lift targeted cohort vs control: 0.10
# lift random vs control: 0.10
# cpit cohort vs control: 1.85
# lift targeted-treated vs control: 0.10
# cpit cohort: 1.846524
# rpu_control: 12.311494825154343
# nipu_control: 1.4018543060049007
# rpu_ft: 13.557862730571786
# nipu_ft: -0.899593703495978
# ---------------------------->>>>>>
# perc - target: 0.10
# treated_target_rpu: 11.19
# treated_target_nipu: -1.00
# nontreated_target_rpu: 8.58
# nontreated_target_nipu: 0.21
# treated_nontarget_rpu: 13.82
# treated_nontarget_nipu: -0.89
# nontreated_nontarget_rpu: 12.73
# nontreated_nontarget_nipu: 1.53
# --- with 9.999862648682802% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 0.4647312790126087
# --> in non-targeted users:
# cpit = 2.2091389661037533
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 12.57
# nipu_cohort: 1.28
# lift targeted cohort vs control: 0.02
# lift random vs control: 0.10
# cpit cohort vs control: 0.47
# lift targeted-treated vs control: -0.09
# cpit cohort: 0.465870
# ---------------------------->>>>>>
# perc - target: 0.20
# treated_target_rpu: 11.35
# treated_target_nipu: -0.85
# nontreated_target_rpu: 8.85
# nontreated_target_nipu: 0.51
# treated_nontarget_rpu: 14.12
# treated_nontarget_nipu: -0.91
# nontreated_nontarget_rpu: 13.17
# nontreated_nontarget_nipu: 1.62
# --- with 19.999725297365604% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 0.5429229148162704
# --> in non-targeted users:
# cpit = 2.666330422372393
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 12.81
# nipu_cohort: 1.13
# lift targeted cohort vs control: 0.04
# lift random vs control: 0.10
# cpit cohort vs control: 0.55
# lift targeted-treated vs control: -0.08
# cpit cohort: 0.549641
# ---------------------------->>>>>>
# perc - target: 0.30
# treated_target_rpu: 11.59
# treated_target_nipu: -1.33
# nontreated_target_rpu: 9.31
# nontreated_target_nipu: 0.70
# treated_nontarget_rpu: 14.43
# treated_nontarget_nipu: -0.71
# nontreated_nontarget_rpu: 13.59
# nontreated_nontarget_nipu: 1.70
# --- with 29.9995879460484% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 0.8894153370576254
# --> in non-targeted users:
# cpit = 2.8654212101950467
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 12.99
# nipu_cohort: 0.79
# lift targeted cohort vs control: 0.06
# lift random vs control: 0.10
# cpit cohort vs control: 0.90
# lift targeted-treated vs control: -0.06
# cpit cohort: 0.901141
# ---------------------------->>>>>>
# perc - target: 0.40
# treated_target_rpu: 11.80
# treated_target_nipu: -1.38
# nontreated_target_rpu: 9.77
# nontreated_target_nipu: 0.82
# treated_nontarget_rpu: 14.76
# treated_nontarget_nipu: -0.57
# nontreated_nontarget_rpu: 13.99
# nontreated_nontarget_nipu: 1.79
# --- with 39.99945059473121% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.0806740610118097
# --> in non-targeted users:
# cpit = 3.063523450314519
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.12
# nipu_cohort: 0.52
# lift targeted cohort vs control: 0.07
# lift random vs control: 0.10
# cpit cohort vs control: 1.09
# lift targeted-treated vs control: -0.04
# cpit cohort: 1.092144
# ---------------------------->>>>>>
# perc - target: 0.50
# treated_target_rpu: 12.08
# treated_target_nipu: -1.20
# nontreated_target_rpu: 10.21
# nontreated_target_nipu: 0.87
# treated_nontarget_rpu: 15.07
# treated_nontarget_nipu: -0.60
# nontreated_nontarget_rpu: 14.40
# nontreated_nontarget_nipu: 1.93
# --- with 49.99931324341401% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.10081900258958
# --> in non-targeted users:
# cpit = 3.7510249431545013
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.24
# nipu_cohort: 0.37
# lift targeted cohort vs control: 0.08
# lift random vs control: 0.10
# cpit cohort vs control: 1.11
# lift targeted-treated vs control: -0.02
# cpit cohort: 1.111075
# ---------------------------->>>>>>
# perc - target: 0.60
# treated_target_rpu: 12.30
# treated_target_nipu: -1.08
# nontreated_target_rpu: 10.63
# nontreated_target_nipu: 0.99
# treated_nontarget_rpu: 15.50
# treated_nontarget_nipu: -0.62
# nontreated_nontarget_rpu: 14.81
# nontreated_nontarget_nipu: 2.01
# --- with 59.9991758920968% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.2427463548138618
# --> in non-targeted users:
# cpit = 3.83961724393553
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.30
# nipu_cohort: 0.16
# lift targeted cohort vs control: 0.08
# lift random vs control: 0.10
# cpit cohort vs control: 1.25
# lift targeted-treated vs control: -0.00
# cpit cohort: 1.252669
# ---------------------------->>>>>>
# perc - target: 0.70
# treated_target_rpu: 12.50
# treated_target_nipu: -0.98
# nontreated_target_rpu: 10.99
# nontreated_target_nipu: 1.09
# treated_nontarget_rpu: 16.06
# treated_nontarget_nipu: -0.71
# nontreated_nontarget_rpu: 15.39
# nontreated_nontarget_nipu: 2.14
# --- with 69.9990385407796% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.3643217228991298
# --> in non-targeted users:
# cpit = 4.208479749989335
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.37
# nipu_cohort: -0.04
# lift targeted cohort vs control: 0.09
# lift random vs control: 0.10
# cpit cohort vs control: 1.37
# lift targeted-treated vs control: 0.02
# cpit cohort: 1.369957
# ---------------------------->>>>>>
# perc - target: 0.80
# treated_target_rpu: 12.73
# treated_target_nipu: -0.90
# nontreated_target_rpu: 11.30
# nontreated_target_nipu: 1.17
# treated_nontarget_rpu: 16.99
# treated_nontarget_nipu: -0.90
# nontreated_nontarget_rpu: 16.31
# nontreated_nontarget_nipu: 2.31
# --- with 79.99890118946242% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.4547955847059917
# --> in non-targeted users:
# cpit = 4.741477503299028
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.44
# nipu_cohort: -0.26
# lift targeted cohort vs control: 0.09
# lift random vs control: 0.10
# cpit cohort vs control: 1.46
# lift targeted-treated vs control: 0.03
# cpit cohort: 1.464020
# ---------------------------->>>>>>
# perc - target: 0.90
# treated_target_rpu: 12.98
# treated_target_nipu: -1.04
# nontreated_target_rpu: 11.63
# nontreated_target_nipu: 1.26
# treated_nontarget_rpu: 18.93
# treated_nontarget_nipu: 0.40
# nontreated_nontarget_rpu: 18.43
# nontreated_nontarget_nipu: 2.63
# --- with 89.99876383814521% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.7022907310929971
# --> in non-targeted users:
# cpit = 4.40124913638078
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.52
# nipu_cohort: -0.67
# lift targeted cohort vs control: 0.10
# lift random vs control: 0.10
# cpit cohort vs control: 1.71
# lift targeted-treated vs control: 0.05
# cpit cohort: 1.709791
# rpu_cohort
# 13.524808477233227
# treated_target_rpu
# 13.557862730571985
# ---------------------------->>>>>>
# perc - target: 1.00
# treated_target_rpu: 13.56
# treated_target_nipu: -0.90
# nontreated_target_rpu: 12.31
# nontreated_target_nipu: 1.40
# treated_nontarget_rpu: nan
# treated_nontarget_nipu: nan
# nontreated_nontarget_rpu: 0.00
# nontreated_nontarget_nipu: 0.00
# --- with 99.99862648682802% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.846853311387234
# --> in non-targeted users:
# cpit = nan
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.56
# nipu_cohort: -0.90
# lift targeted cohort vs control: 0.10
# lift random vs control: 0.10
# cpit cohort vs control: 1.85
# lift targeted-treated vs control: 0.10
# cpit cohort: 1.846524
# rpu_control: 12.311494825154343
# nipu_control: 1.4018543060049007
# rpu_ft: 13.557862730571786
# nipu_ft: -0.899593703495978
# ---------------------------->>>>>>
# perc - target: 0.10
# treated_target_rpu: 10.89
# treated_target_nipu: -1.01
# nontreated_target_rpu: 8.49
# nontreated_target_nipu: 0.21
# treated_nontarget_rpu: 13.86
# treated_nontarget_nipu: -0.89
# nontreated_nontarget_rpu: 12.74
# nontreated_nontarget_nipu: 1.53
# --- with 9.999862648682802% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 0.5094888110039174
# --> in non-targeted users:
# cpit = 2.162545341595834
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 12.55
# nipu_cohort: 1.28
# lift targeted cohort vs control: 0.02
# lift random vs control: 0.10
# cpit cohort vs control: 0.51
# lift targeted-treated vs control: -0.12
# cpit cohort: 0.510324
# ---------------------------->>>>>>
# perc - target: 0.20
# treated_target_rpu: 11.26
# treated_target_nipu: -0.86
# nontreated_target_rpu: 8.86
# nontreated_target_nipu: 0.52
# treated_nontarget_rpu: 14.15
# treated_nontarget_nipu: -0.91
# nontreated_nontarget_rpu: 13.17
# nontreated_nontarget_nipu: 1.62
# --- with 19.999725297365604% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 0.5758117379793167
# --> in non-targeted users:
# cpit = 2.5791753370281887
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 12.79
# nipu_cohort: 1.12
# lift targeted cohort vs control: 0.04
# lift random vs control: 0.10
# cpit cohort vs control: 0.58
# lift targeted-treated vs control: -0.09
# cpit cohort: 0.584251
# ---------------------------->>>>>>
# perc - target: 0.30
# treated_target_rpu: 11.41
# treated_target_nipu: -1.35
# nontreated_target_rpu: 9.20
# nontreated_target_nipu: 0.68
# treated_nontarget_rpu: 14.51
# treated_nontarget_nipu: -0.70
# nontreated_nontarget_rpu: 13.64
# nontreated_nontarget_nipu: 1.71
# --- with 29.9995879460484% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 0.9172188335855582
# --> in non-targeted users:
# cpit = 2.763058482509968
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 12.97
# nipu_cohort: 0.79
# lift targeted cohort vs control: 0.05
# lift random vs control: 0.10
# cpit cohort vs control: 0.93
# lift targeted-treated vs control: -0.07
# cpit cohort: 0.929281
# ---------------------------->>>>>>
# perc - target: 0.40
# treated_target_rpu: 11.68
# treated_target_nipu: -1.17
# nontreated_target_rpu: 9.66
# nontreated_target_nipu: 0.78
# treated_nontarget_rpu: 14.85
# treated_nontarget_nipu: -0.72
# nontreated_nontarget_rpu: 14.07
# nontreated_nontarget_nipu: 1.81
# --- with 39.99945059473121% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 0.9627755289885305
# --> in non-targeted users:
# cpit = 3.2312092069846665
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.11
# nipu_cohort: 0.62
# lift targeted cohort vs control: 0.07
# lift random vs control: 0.10
# cpit cohort vs control: 0.97
# lift targeted-treated vs control: -0.05
# cpit cohort: 0.974814
# ---------------------------->>>>>>
# perc - target: 0.50
# treated_target_rpu: 11.96
# treated_target_nipu: -1.20
# nontreated_target_rpu: 10.13
# nontreated_target_nipu: 0.85
# treated_nontarget_rpu: 15.19
# treated_nontarget_nipu: -0.59
# nontreated_nontarget_rpu: 14.48
# nontreated_nontarget_nipu: 1.95
# --- with 49.99931324341401% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.1212295098048497
# --> in non-targeted users:
# cpit = 3.5617133341580804
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.22
# nipu_cohort: 0.37
# lift targeted cohort vs control: 0.07
# lift random vs control: 0.10
# cpit cohort vs control: 1.13
# lift targeted-treated vs control: -0.03
# cpit cohort: 1.130981
# ---------------------------->>>>>>
# perc - target: 0.60
# treated_target_rpu: 12.22
# treated_target_nipu: -1.08
# nontreated_target_rpu: 10.54
# nontreated_target_nipu: 0.97
# treated_nontarget_rpu: 15.61
# treated_nontarget_nipu: -0.62
# nontreated_nontarget_rpu: 14.95
# nontreated_nontarget_nipu: 2.04
# --- with 59.9991758920968% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.224128888138996
# --> in non-targeted users:
# cpit = 4.007763580680982
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.31
# nipu_cohort: 0.17
# lift targeted cohort vs control: 0.08
# lift random vs control: 0.10
# cpit cohort vs control: 1.23
# lift targeted-treated vs control: -0.01
# cpit cohort: 1.233225
# ---------------------------->>>>>>
# perc - target: 0.70
# treated_target_rpu: 12.39
# treated_target_nipu: -0.98
# nontreated_target_rpu: 10.88
# nontreated_target_nipu: 1.07
# treated_nontarget_rpu: 16.36
# treated_nontarget_nipu: -0.70
# nontreated_nontarget_rpu: 15.64
# nontreated_nontarget_nipu: 2.17
# --- with 69.9990385407796% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.3542920604483963
# --> in non-targeted users:
# cpit = 3.9680513145874783
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.37
# nipu_cohort: -0.04
# lift targeted cohort vs control: 0.09
# lift random vs control: 0.10
# cpit cohort vs control: 1.36
# lift targeted-treated vs control: 0.01
# cpit cohort: 1.364968
# ---------------------------->>>>>>
# perc - target: 0.80
# treated_target_rpu: 12.64
# treated_target_nipu: -0.90
# nontreated_target_rpu: 11.20
# nontreated_target_nipu: 1.16
# treated_nontarget_rpu: 17.38
# treated_nontarget_nipu: -0.90
# nontreated_nontarget_rpu: 16.72
# nontreated_nontarget_nipu: 2.37
# --- with 79.99890118946242% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.4233139185188175
# --> in non-targeted users:
# cpit = 4.956168705061372
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.46
# nipu_cohort: -0.25
# lift targeted cohort vs control: 0.09
# lift random vs control: 0.10
# cpit cohort vs control: 1.44
# lift targeted-treated vs control: 0.03
# cpit cohort: 1.436477
# ---------------------------->>>>>>
# perc - target: 0.90
# treated_target_rpu: 12.88
# treated_target_nipu: -0.84
# nontreated_target_rpu: 11.56
# nontreated_target_nipu: 1.25
# treated_nontarget_rpu: 19.75
# treated_nontarget_nipu: -1.49
# nontreated_nontarget_rpu: 19.05
# nontreated_nontarget_nipu: 2.73
# --- with 89.99876383814521% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.5784796478714174
# --> in non-targeted users:
# cpit = 6.030544469167508
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.50
# nipu_cohort: -0.48
# lift targeted cohort vs control: 0.10
# lift random vs control: 0.10
# cpit cohort vs control: 1.58
# lift targeted-treated vs control: 0.05
# cpit cohort: 1.583014
# rpu_cohort
# 13.499572173809074
# treated_target_rpu
# 13.557862730571985
# ---------------------------->>>>>>
# perc - target: 1.00
# treated_target_rpu: 13.56
# treated_target_nipu: -0.90
# nontreated_target_rpu: 12.31
# nontreated_target_nipu: 1.40
# treated_nontarget_rpu: nan
# treated_nontarget_nipu: nan
# nontreated_nontarget_rpu: 0.00
# nontreated_nontarget_nipu: 0.00
# --- with 99.99862648682802% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.846853311387234
# --> in non-targeted users:
# cpit = nan
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.56
# nipu_cohort: -0.90
# lift targeted cohort vs control: 0.10
# lift random vs control: 0.10
# cpit cohort vs control: 1.85
# lift targeted-treated vs control: 0.10
# cpit cohort: 1.846524
# rpu_control: 12.311494825154343
# nipu_control: 1.4018543060049007
# rpu_ft: 13.557862730571786
# nipu_ft: -0.899593703495978
# ---------------------------->>>>>>
# perc - target: 0.10
# treated_target_rpu: 10.73
# treated_target_nipu: -0.67
# nontreated_target_rpu: 8.49
# nontreated_target_nipu: 0.42
# treated_nontarget_rpu: 13.89
# treated_nontarget_nipu: -0.93
# nontreated_nontarget_rpu: 12.73
# nontreated_nontarget_nipu: 1.51
# --- with 9.999862648682802% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 0.48309043235203436
# --> in non-targeted users:
# cpit = 2.0954477259492132
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 12.53
# nipu_cohort: 1.29
# lift targeted cohort vs control: 0.02
# lift random vs control: 0.10
# cpit cohort vs control: 0.50
# lift targeted-treated vs control: -0.13
# cpit cohort: 0.503247
# ---------------------------->>>>>>
# perc - target: 0.20
# treated_target_rpu: 10.98
# treated_target_nipu: -0.63
# nontreated_target_rpu: 8.87
# nontreated_target_nipu: 0.64
# treated_nontarget_rpu: 14.22
# treated_nontarget_nipu: -0.97
# nontreated_nontarget_rpu: 13.17
# nontreated_nontarget_nipu: 1.59
# --- with 19.999725297365604% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 0.6020234535953887
# --> in non-targeted users:
# cpit = 2.428305843898345
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 12.73
# nipu_cohort: 1.15
# lift targeted cohort vs control: 0.03
# lift random vs control: 0.10
# cpit cohort vs control: 0.61
# lift targeted-treated vs control: -0.11
# cpit cohort: 0.610932
# ---------------------------->>>>>>
# perc - target: 0.30
# treated_target_rpu: 11.29
# treated_target_nipu: -0.63
# nontreated_target_rpu: 9.30
# nontreated_target_nipu: 0.68
# treated_nontarget_rpu: 14.55
# treated_nontarget_nipu: -1.02
# nontreated_nontarget_rpu: 13.60
# nontreated_nontarget_nipu: 1.71
# --- with 29.9995879460484% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 0.6564309823868317
# --> in non-targeted users:
# cpit = 2.870143139780184
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 12.90
# nipu_cohort: 1.01
# lift targeted cohort vs control: 0.05
# lift random vs control: 0.10
# cpit cohort vs control: 0.66
# lift targeted-treated vs control: -0.08
# cpit cohort: 0.662146
# ---------------------------->>>>>>
# perc - target: 0.40
# treated_target_rpu: 11.70
# treated_target_nipu: -0.61
# nontreated_target_rpu: 9.73
# nontreated_target_nipu: 0.81
# treated_nontarget_rpu: 14.82
# treated_nontarget_nipu: -1.10
# nontreated_nontarget_rpu: 14.02
# nontreated_nontarget_nipu: 1.80
# --- with 39.99945059473121% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 0.7178322216101899
# --> in non-targeted users:
# cpit = 3.6304435947817564
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.09
# nipu_cohort: 0.83
# lift targeted cohort vs control: 0.06
# lift random vs control: 0.10
# cpit cohort vs control: 0.72
# lift targeted-treated vs control: -0.05
# cpit cohort: 0.723884
# ---------------------------->>>>>>
# perc - target: 0.50
# treated_target_rpu: 11.89
# treated_target_nipu: -0.61
# nontreated_target_rpu: 10.14
# nontreated_target_nipu: 0.91
# treated_nontarget_rpu: 15.25
# treated_nontarget_nipu: -1.19
# nontreated_nontarget_rpu: 14.47
# nontreated_nontarget_nipu: 1.89
# --- with 49.99931324341401% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 0.8712419664205913
# --> in non-targeted users:
# cpit = 3.928331085235808
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.18
# nipu_cohort: 0.64
# lift targeted cohort vs control: 0.07
# lift random vs control: 0.10
# cpit cohort vs control: 0.88
# lift targeted-treated vs control: -0.03
# cpit cohort: 0.876991
# ---------------------------->>>>>>
# perc - target: 0.60
# treated_target_rpu: 12.13
# treated_target_nipu: -0.58
# nontreated_target_rpu: 10.54
# nontreated_target_nipu: 1.00
# treated_nontarget_rpu: 15.74
# treated_nontarget_nipu: -1.38
# nontreated_nontarget_rpu: 14.96
# nontreated_nontarget_nipu: 1.99
# --- with 59.9991758920968% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 0.9969136819615829
# --> in non-targeted users:
# cpit = 4.3314568331911785
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.26
# nipu_cohort: 0.45
# lift targeted cohort vs control: 0.08
# lift random vs control: 0.10
# cpit cohort vs control: 1.00
# lift targeted-treated vs control: -0.01
# cpit cohort: 1.003215
# ---------------------------->>>>>>
# perc - target: 0.70
# treated_target_rpu: 12.38
# treated_target_nipu: -0.79
# nontreated_target_rpu: 10.85
# nontreated_target_nipu: 1.09
# treated_nontarget_rpu: 16.37
# treated_nontarget_nipu: -1.15
# nontreated_nontarget_rpu: 15.70
# nontreated_nontarget_nipu: 2.12
# --- with 69.9990385407796% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.233994352468343
# --> in non-targeted users:
# cpit = 4.873638406279217
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.38
# nipu_cohort: 0.08
# lift targeted cohort vs control: 0.09
# lift random vs control: 0.10
# cpit cohort vs control: 1.24
# lift targeted-treated vs control: 0.01
# cpit cohort: 1.241572
# ---------------------------->>>>>>
# perc - target: 0.80
# treated_target_rpu: 12.70
# treated_target_nipu: -0.86
# nontreated_target_rpu: 11.25
# nontreated_target_nipu: 1.18
# treated_nontarget_rpu: 17.11
# treated_nontarget_nipu: -1.08
# nontreated_nontarget_rpu: 16.51
# nontreated_nontarget_nipu: 2.29
# --- with 79.99890118946242% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.3999456883853107
# --> in non-targeted users:
# cpit = 5.623976942691156
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.47
# nipu_cohort: -0.23
# lift targeted cohort vs control: 0.09
# lift random vs control: 0.10
# cpit cohort vs control: 1.41
# lift targeted-treated vs control: 0.03
# cpit cohort: 1.410933
# ---------------------------->>>>>>
# perc - target: 0.90
# treated_target_rpu: 13.03
# treated_target_nipu: -0.79
# nontreated_target_rpu: 11.67
# nontreated_target_nipu: 1.27
# treated_nontarget_rpu: 18.48
# treated_nontarget_nipu: -1.92
# nontreated_nontarget_rpu: 18.03
# nontreated_nontarget_nipu: 2.54
# --- with 89.99876383814521% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.5173019614336964
# --> in non-targeted users:
# cpit = 9.8297945808865
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.53
# nipu_cohort: -0.46
# lift targeted cohort vs control: 0.10
# lift random vs control: 0.10
# cpit cohort vs control: 1.52
# lift targeted-treated vs control: 0.06
# cpit cohort: 1.524583
# rpu_cohort
# 13.531088239481816
# treated_target_rpu
# 13.557862730571985
# ---------------------------->>>>>>
# perc - target: 1.00
# treated_target_rpu: 13.56
# treated_target_nipu: -0.90
# nontreated_target_rpu: 12.31
# nontreated_target_nipu: 1.40
# treated_nontarget_rpu: nan
# treated_nontarget_nipu: nan
# nontreated_nontarget_rpu: 3.55
# nontreated_nontarget_nipu: 0.10
# --- with 99.99862648682802% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.8467623531818131
# --> in non-targeted users:
# cpit = nan
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.56
# nipu_cohort: -0.90
# lift targeted cohort vs control: 0.10
# lift random vs control: 0.10
# cpit cohort vs control: 1.85
# lift targeted-treated vs control: 0.10
# cpit cohort: 1.846524
# rpu_control: 12.311494825154343
# nipu_control: 1.4018543060049007
# rpu_ft: 13.557862730571786
# nipu_ft: -0.899593703495978
# ---------------------------->>>>>>
# perc - target: 0.10
# treated_target_rpu: 9.30
# treated_target_nipu: -0.73
# nontreated_target_rpu: 7.15
# nontreated_target_nipu: 0.26
# treated_nontarget_rpu: 14.05
# treated_nontarget_nipu: -0.92
# nontreated_nontarget_rpu: 12.88
# nontreated_nontarget_nipu: 1.53
# --- with 9.999862648682802% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 0.4613888764303299
# --> in non-targeted users:
# cpit = 2.081382148171997
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 12.52
# nipu_cohort: 1.30
# lift targeted cohort vs control: 0.02
# lift random vs control: 0.10
# cpit cohort vs control: 0.48
# lift targeted-treated vs control: -0.24
# cpit cohort: 0.480741
# ---------------------------->>>>>>
# perc - target: 0.20
# treated_target_rpu: 10.01
# treated_target_nipu: -0.73
# nontreated_target_rpu: 7.85
# nontreated_target_nipu: 0.42
# treated_nontarget_rpu: 14.47
# treated_nontarget_nipu: -0.94
# nontreated_nontarget_rpu: 13.42
# nontreated_nontarget_nipu: 1.64
# --- with 19.999725297365604% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 0.5367911140489999
# --> in non-targeted users:
# cpit = 2.4691115553121095
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 12.74
# nipu_cohort: 1.17
# lift targeted cohort vs control: 0.03
# lift random vs control: 0.10
# cpit cohort vs control: 0.55
# lift targeted-treated vs control: -0.19
# cpit cohort: 0.546167
# ---------------------------->>>>>>
# perc - target: 0.30
# treated_target_rpu: 10.54
# treated_target_nipu: -0.75
# nontreated_target_rpu: 8.49
# nontreated_target_nipu: 0.61
# treated_nontarget_rpu: 14.87
# treated_nontarget_nipu: -0.96
# nontreated_nontarget_rpu: 13.94
# nontreated_nontarget_nipu: 1.74
# --- with 29.9995879460484% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 0.6628714014798105
# --> in non-targeted users:
# cpit = 2.926804691184458
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 12.92
# nipu_cohort: 0.99
# lift targeted cohort vs control: 0.05
# lift random vs control: 0.10
# cpit cohort vs control: 0.67
# lift targeted-treated vs control: -0.14
# cpit cohort: 0.668293
# ---------------------------->>>>>>
# perc - target: 0.40
# treated_target_rpu: 10.89
# treated_target_nipu: -0.70
# nontreated_target_rpu: 9.05
# nontreated_target_nipu: 0.74
# treated_nontarget_rpu: 15.38
# treated_nontarget_nipu: -1.03
# nontreated_nontarget_rpu: 14.48
# nontreated_nontarget_nipu: 1.84
# --- with 39.99945059473121% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 0.782361892606946
# --> in non-targeted users:
# cpit = 3.184908459587455
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.04
# nipu_cohort: 0.82
# lift targeted cohort vs control: 0.06
# lift random vs control: 0.10
# cpit cohort vs control: 0.79
# lift targeted-treated vs control: -0.12
# cpit cohort: 0.792094
# ---------------------------->>>>>>
# perc - target: 0.50
# treated_target_rpu: 11.26
# treated_target_nipu: -1.01
# nontreated_target_rpu: 9.54
# nontreated_target_nipu: 0.84
# treated_nontarget_rpu: 15.91
# treated_nontarget_nipu: -0.79
# nontreated_nontarget_rpu: 15.07
# nontreated_nontarget_nipu: 1.96
# --- with 49.99931324341401% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.0741859265223375
# --> in non-targeted users:
# cpit = 3.2313996591847447
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.17
# nipu_cohort: 0.47
# lift targeted cohort vs control: 0.07
# lift random vs control: 0.10
# cpit cohort vs control: 1.09
# lift targeted-treated vs control: -0.09
# cpit cohort: 1.087650
# ---------------------------->>>>>>
# perc - target: 0.60
# treated_target_rpu: 11.56
# treated_target_nipu: -0.92
# nontreated_target_rpu: 9.95
# nontreated_target_nipu: 0.93
# treated_nontarget_rpu: 16.68
# treated_nontarget_nipu: -0.87
# nontreated_nontarget_rpu: 15.81
# nontreated_nontarget_nipu: 2.10
# --- with 59.9991758920968% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.146906280378131
# --> in non-targeted users:
# cpit = 3.4262038197355897
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.26
# nipu_cohort: 0.29
# lift targeted cohort vs control: 0.08
# lift random vs control: 0.10
# cpit cohort vs control: 1.17
# lift targeted-treated vs control: -0.06
# cpit cohort: 1.167202
# ---------------------------->>>>>>
# perc - target: 0.70
# treated_target_rpu: 11.81
# treated_target_nipu: -0.87
# nontreated_target_rpu: 10.40
# nontreated_target_nipu: 1.03
# treated_nontarget_rpu: 17.88
# treated_nontarget_nipu: -0.98
# nontreated_nontarget_rpu: 16.72
# nontreated_nontarget_nipu: 2.25
# --- with 69.9990385407796% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.3395838662638286
# --> in non-targeted users:
# cpit = 2.785130644823494
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.28
# nipu_cohort: 0.07
# lift targeted cohort vs control: 0.08
# lift random vs control: 0.10
# cpit cohort vs control: 1.37
# lift targeted-treated vs control: -0.04
# cpit cohort: 1.368996
# ---------------------------->>>>>>
# perc - target: 0.80
# treated_target_rpu: 12.13
# treated_target_nipu: -0.81
# nontreated_target_rpu: 10.84
# nontreated_target_nipu: 1.13
# treated_nontarget_rpu: 19.46
# treated_nontarget_nipu: -1.26
# nontreated_nontarget_rpu: 18.15
# nontreated_nontarget_nipu: 2.48
# --- with 79.99890118946242% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.501794653882051
# --> in non-targeted users:
# cpit = 2.854285401066155
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.34
# nipu_cohort: -0.15
# lift targeted cohort vs control: 0.08
# lift random vs control: 0.10
# cpit cohort vs control: 1.52
# lift targeted-treated vs control: -0.01
# cpit cohort: 1.517833
# ---------------------------->>>>>>
# perc - target: 0.90
# treated_target_rpu: 12.52
# treated_target_nipu: -0.85
# nontreated_target_rpu: 11.33
# nontreated_target_nipu: 1.23
# treated_nontarget_rpu: 22.94
# treated_nontarget_nipu: -1.35
# nontreated_nontarget_rpu: 21.15
# nontreated_nontarget_nipu: 2.96
# --- with 89.99876383814521% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.7526876127091446
# --> in non-targeted users:
# cpit = 2.406150544950932
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.38
# nipu_cohort: -0.47
# lift targeted cohort vs control: 0.09
# lift random vs control: 0.10
# cpit cohort vs control: 1.75
# lift targeted-treated vs control: 0.02
# cpit cohort: 1.752634
# rpu_cohort
# 13.378325576329045
# treated_target_rpu
# 13.557862730571985
# ---------------------------->>>>>>
# perc - target: 1.00
# treated_target_rpu: 13.56
# treated_target_nipu: -0.90
# nontreated_target_rpu: 12.31
# nontreated_target_nipu: 1.40
# treated_nontarget_rpu: nan
# treated_nontarget_nipu: nan
# nontreated_nontarget_rpu: 85.06
# nontreated_nontarget_nipu: 11.65
# --- with 99.99862648682802% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.8445521331319974
# --> in non-targeted users:
# cpit = nan
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.56
# nipu_cohort: -0.90
# lift targeted cohort vs control: 0.10
# lift random vs control: 0.10
# cpit cohort vs control: 1.85
# lift targeted-treated vs control: 0.10
# cpit cohort: 1.846524
# temp:
# 3.041762285521891
# p_quantile:
# 0.4
# AUCC results:
# random: [0.5]
# rlearner: [0.70191681]
# duality rlearner 1 with lambda = 0.1:[0.70262239]
# drm: [0.68452456]
# tqr: [0.73674421]
# ../experimentation.py:110: RuntimeWarning: invalid value encountered in long_scalars
#   treated_untarget_nipu = sum(1.0 * n9d_ni_usd[treated_untargeted_filter]) / sum(treated_untargeted_filter)

# %%
### ---- experimentation and plotting cost-curves ----- 
from experimentation import * 
exp = Experimentation() 
ranscore = np.random.rand(ot.shape[0], ) 
colors = ['b', 'c', 'g', 'y'] 
plt.figure() 
rlearnerauccs = [] 
ranaucc = exp.AUC_cpit_cost_curve_deciles_cohort(ranscore, ot, wt, -1.0 * ct, 'k', plot_random=True) 
quasiaucc = exp.AUC_cpit_cost_curve_deciles_cohort(pred_values_va_rlearner_O, ot, wt, -1.0 * ct, 'c') 
for i in range(len(lambds)): 
    rlearnerauccs.append(exp.AUC_cpit_cost_curve_deciles_cohort(rlearnerscores[i], ot, wt, -1.0 * ct, colors[i] )) 
#cfaucc = exp.AUC_cpit_cost_curve_deciles_cohort(cfscore, ot, wt, -1.0 * ct, 'g') # causal forest aucc and plotting 
tqraucc = exp.AUC_cpit_cost_curve_deciles_cohort(tqrscore, ot, wt, -1.0 * ct, 'r' ) 
drmaucc = exp.AUC_cpit_cost_curve_deciles_cohort(drmscore, ot, wt, -1.0 * ct, 'm' ) 
plt.title('Causal learning cost curves using targeting models') 

print('temp:') 
print(tempvalue) 
print('p_quantile:') 
print(p_quantilevalue) 

### --- add legeneds to plot ---- 
leg_str = ['Random'] 
leg_str.append('R-learner on Incremental Gain') 
for i in range(len(lambds)): 
    leg_str.append('Duality R-learner') 
#leg_str.append('Causal Forest') # causal forest result 
leg_str.append('Top Quantile Ranking at ' + str(p_quantile*100) + '%') 
leg_str.append('Direct Ranking Model') 
plt.legend(leg_str) 

### --- print out aucc results for different models --- 
print('AUCC results: ') 
print('random: ' + str(ranaucc)) 
print('rlearner: ' + str(quasiaucc)) 
i = 0
for rlearneraucc in rlearnerauccs: 
    print('duality rlearner ' + str(i + 1) + ' with lambda = ' + str(lambds[i]) + ':' + str(rlearneraucc)) 
    i = i + 1
print('drm: ' + str(drmaucc)) 
print('tqr: ' + str(tqraucc)) 

plt.show() 

### --- saving data to results folder ---- 
save_filename = '../results/benchmarkwithcv_tqr_drm_hte_'+prefix+'_main_results.pkl' 
saveD = {'tqrscore':tqrscore, 'drmscore':drmscore, 'quasiscore':pred_values_va_rlearner, 'quasiscore_O':pred_values_va_rlearner_O, 'rlearnerscore':rlearnerscores, 'ot':ot, 'wt':wt, 'ct':ct, 'tempvalue':tempvalue, 'p_quantilevalue':p_quantilevalue, 
         'tqraucc':tqraucc, 'drmaucc':drmaucc, 'rlearnerauccs':rlearnerauccs, 'ranaucc':ranaucc, 'quasiaucc':quasiaucc} 
#'cfscore':cfscore, causal forest scores 
pkl.dump(saveD, open(save_filename, 'wb'))
# Out:
# rpu_control: 12.311494825154343
# nipu_control: 1.4018543060049007
# rpu_ft: 13.557862730571786
# nipu_ft: -0.899593703495978
# ---------------------------->>>>>>
# perc - target: 0.10
# treated_target_rpu: 13.35
# treated_target_nipu: -0.47
# nontreated_target_rpu: 12.37
# nontreated_target_nipu: 1.28
# treated_nontarget_rpu: 13.58
# treated_nontarget_nipu: -0.95
# nontreated_nontarget_rpu: 12.30
# nontreated_nontarget_nipu: 1.42
# --- with 9.999862648682802% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.7901091578978183
# --> in non-targeted users:
# cpit = 1.8512752980136982
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 12.41
# nipu_cohort: 1.23
# lift targeted cohort vs control: 0.01
# lift random vs control: 0.10
# cpit cohort vs control: 1.79
# lift targeted-treated vs control: 0.08
# cpit cohort: 1.790090
# ---------------------------->>>>>>
# perc - target: 0.20
# treated_target_rpu: 13.58
# treated_target_nipu: -0.44
# nontreated_target_rpu: 12.27
# nontreated_target_nipu: 1.37
# treated_nontarget_rpu: 13.55
# treated_nontarget_nipu: -1.01
# nontreated_nontarget_rpu: 12.32
# nontreated_nontarget_nipu: 1.41
# --- with 19.999725297365604% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.3748503154190754
# --> in non-targeted users:
# cpit = 1.9720371402123489
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 12.57
# nipu_cohort: 1.04
# lift targeted cohort vs control: 0.02
# lift random vs control: 0.10
# cpit cohort vs control: 1.37
# lift targeted-treated vs control: 0.10
# cpit cohort: 1.374771
# ---------------------------->>>>>>
# perc - target: 0.30
# treated_target_rpu: 13.53
# treated_target_nipu: -0.75
# nontreated_target_rpu: 12.27
# nontreated_target_nipu: 1.41
# treated_nontarget_rpu: 13.57
# treated_nontarget_nipu: -0.96
# nontreated_nontarget_rpu: 12.33
# nontreated_nontarget_nipu: 1.40
# --- with 29.9995879460484% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.720654670051093
# --> in non-targeted users:
# cpit = 1.900826474682742
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 12.69
# nipu_cohort: 0.75
# lift targeted cohort vs control: 0.03
# lift random vs control: 0.10
# cpit cohort vs control: 1.72
# lift targeted-treated vs control: 0.10
# cpit cohort: 1.720577
# ---------------------------->>>>>>
# perc - target: 0.40
# treated_target_rpu: 13.56
# treated_target_nipu: -0.68
# nontreated_target_rpu: 12.22
# nontreated_target_nipu: 1.41
# treated_nontarget_rpu: 13.56
# treated_nontarget_nipu: -1.04
# nontreated_nontarget_rpu: 12.37
# nontreated_nontarget_nipu: 1.40
# --- with 39.99945059473121% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.5627297960451607
# --> in non-targeted users:
# cpit = 2.059293479174561
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 12.85
# nipu_cohort: 0.57
# lift targeted cohort vs control: 0.04
# lift random vs control: 0.10
# cpit cohort vs control: 1.56
# lift targeted-treated vs control: 0.10
# cpit cohort: 1.562510
# ---------------------------->>>>>>
# perc - target: 0.50
# treated_target_rpu: 13.52
# treated_target_nipu: -1.01
# nontreated_target_rpu: 12.27
# nontreated_target_nipu: 1.42
# treated_nontarget_rpu: 13.60
# treated_nontarget_nipu: -0.79
# nontreated_nontarget_rpu: 12.35
# nontreated_nontarget_nipu: 1.38
# --- with 49.99931324341401% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.9460097570058223
# --> in non-targeted users:
# cpit = 1.747372351982875
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 12.94
# nipu_cohort: 0.18
# lift targeted cohort vs control: 0.05
# lift random vs control: 0.10
# cpit cohort vs control: 1.95
# lift targeted-treated vs control: 0.10
# cpit cohort: 1.945913
# ---------------------------->>>>>>
# perc - target: 0.60
# treated_target_rpu: 13.44
# treated_target_nipu: -0.92
# nontreated_target_rpu: 12.29
# nontreated_target_nipu: 1.42
# treated_nontarget_rpu: 13.73
# treated_nontarget_nipu: -0.86
# nontreated_nontarget_rpu: 12.35
# nontreated_nontarget_nipu: 1.38
# --- with 59.9991758920968% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 2.0250776009104143
# --> in non-targeted users:
# cpit = 1.6263270689377918
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.01
# nipu_cohort: -0.00
# lift targeted cohort vs control: 0.06
# lift random vs control: 0.10
# cpit cohort vs control: 2.02
# lift targeted-treated vs control: 0.09
# cpit cohort: 2.024947
# ---------------------------->>>>>>
# perc - target: 0.70
# treated_target_rpu: 13.49
# treated_target_nipu: -1.08
# nontreated_target_rpu: 12.31
# nontreated_target_nipu: 1.43
# treated_nontarget_rpu: 13.72
# treated_nontarget_nipu: -0.48
# nontreated_nontarget_rpu: 12.32
# nontreated_nontarget_nipu: 1.35
# --- with 69.9990385407796% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 2.1252319481977433
# --> in non-targeted users:
# cpit = 1.3022063822888903
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.14
# nipu_cohort: -0.35
# lift targeted cohort vs control: 0.07
# lift random vs control: 0.10
# cpit cohort vs control: 2.13
# lift targeted-treated vs control: 0.10
# cpit cohort: 2.125249
# ---------------------------->>>>>>
# perc - target: 0.80
# treated_target_rpu: 13.49
# treated_target_nipu: -1.01
# nontreated_target_rpu: 12.29
# nontreated_target_nipu: 1.42
# treated_nontarget_rpu: 13.83
# treated_nontarget_nipu: -0.44
# nontreated_nontarget_rpu: 12.40
# nontreated_nontarget_nipu: 1.33
# --- with 79.99890118946242% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 2.0325209134235647
# --> in non-targeted users:
# cpit = 1.231612341621539
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.27
# nipu_cohort: -0.55
# lift targeted cohort vs control: 0.08
# lift random vs control: 0.10
# cpit cohort vs control: 2.03
# lift targeted-treated vs control: 0.10
# cpit cohort: 2.032481
# ---------------------------->>>>>>
# perc - target: 0.90
# treated_target_rpu: 13.49
# treated_target_nipu: -0.95
# nontreated_target_rpu: 12.32
# nontreated_target_nipu: 1.43
# treated_nontarget_rpu: 14.18
# treated_nontarget_nipu: -0.40
# nontreated_nontarget_rpu: 12.26
# nontreated_nontarget_nipu: 1.16
# --- with 89.99876383814521% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 2.0316026787078365
# --> in non-targeted users:
# cpit = 0.8158934845483651
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.37
# nipu_cohort: -0.74
# lift targeted cohort vs control: 0.09
# lift random vs control: 0.10
# cpit cohort vs control: 2.03
# lift targeted-treated vs control: 0.10
# cpit cohort: 2.031524
# rpu_cohort
# 13.367348706836745
# treated_target_rpu
# 13.557974018991013
# ---------------------------->>>>>>
# perc - target: 1.00
# treated_target_rpu: 13.56
# treated_target_nipu: -0.90
# nontreated_target_rpu: 12.31
# nontreated_target_nipu: 1.40
# treated_nontarget_rpu: 10.44
# treated_nontarget_nipu: -0.45
# nontreated_nontarget_rpu: 17.52
# nontreated_nontarget_nipu: 2.54
# --- with 99.99862648682802% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.8462983765731753
# --> in non-targeted users:
# cpit = -0.4223045927442123
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.56
# nipu_cohort: -0.90
# lift targeted cohort vs control: 0.10
# lift random vs control: 0.10
# cpit cohort vs control: 1.85
# lift targeted-treated vs control: 0.10
# cpit cohort: 1.846372
# rpu_control: 12.311494825154343
# nipu_control: 1.4018543060049007
# rpu_ft: 13.557862730571786
# nipu_ft: -0.899593703495978
# ---------------------------->>>>>>
# perc - target: 0.10
# treated_target_rpu: 11.19
# treated_target_nipu: -1.00
# nontreated_target_rpu: 8.58
# nontreated_target_nipu: 0.21
# treated_nontarget_rpu: 13.82
# treated_nontarget_nipu: -0.89
# nontreated_nontarget_rpu: 12.73
# nontreated_nontarget_nipu: 1.53
# --- with 9.999862648682802% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 0.4647312790126087
# --> in non-targeted users:
# cpit = 2.2091389661037533
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 12.57
# nipu_cohort: 1.28
# lift targeted cohort vs control: 0.02
# lift random vs control: 0.10
# cpit cohort vs control: 0.47
# lift targeted-treated vs control: -0.09
# cpit cohort: 0.465870
# ---------------------------->>>>>>
# perc - target: 0.20
# treated_target_rpu: 11.35
# treated_target_nipu: -0.85
# nontreated_target_rpu: 8.85
# nontreated_target_nipu: 0.51
# treated_nontarget_rpu: 14.12
# treated_nontarget_nipu: -0.91
# nontreated_nontarget_rpu: 13.17
# nontreated_nontarget_nipu: 1.62
# --- with 19.999725297365604% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 0.5429229148162704
# --> in non-targeted users:
# cpit = 2.666330422372393
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 12.81
# nipu_cohort: 1.13
# lift targeted cohort vs control: 0.04
# lift random vs control: 0.10
# cpit cohort vs control: 0.55
# lift targeted-treated vs control: -0.08
# cpit cohort: 0.549641
# ---------------------------->>>>>>
# perc - target: 0.30
# treated_target_rpu: 11.59
# treated_target_nipu: -1.33
# nontreated_target_rpu: 9.31
# nontreated_target_nipu: 0.70
# treated_nontarget_rpu: 14.43
# treated_nontarget_nipu: -0.71
# nontreated_nontarget_rpu: 13.59
# nontreated_nontarget_nipu: 1.70
# --- with 29.9995879460484% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 0.8894153370576254
# --> in non-targeted users:
# cpit = 2.8654212101950467
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 12.99
# nipu_cohort: 0.79
# lift targeted cohort vs control: 0.06
# lift random vs control: 0.10
# cpit cohort vs control: 0.90
# lift targeted-treated vs control: -0.06
# cpit cohort: 0.901141
# ---------------------------->>>>>>
# perc - target: 0.40
# treated_target_rpu: 11.80
# treated_target_nipu: -1.38
# nontreated_target_rpu: 9.77
# nontreated_target_nipu: 0.82
# treated_nontarget_rpu: 14.76
# treated_nontarget_nipu: -0.57
# nontreated_nontarget_rpu: 13.99
# nontreated_nontarget_nipu: 1.79
# --- with 39.99945059473121% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.0806740610118097
# --> in non-targeted users:
# cpit = 3.063523450314519
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.12
# nipu_cohort: 0.52
# lift targeted cohort vs control: 0.07
# lift random vs control: 0.10
# cpit cohort vs control: 1.09
# lift targeted-treated vs control: -0.04
# cpit cohort: 1.092144
# ---------------------------->>>>>>
# perc - target: 0.50
# treated_target_rpu: 12.08
# treated_target_nipu: -1.20
# nontreated_target_rpu: 10.21
# nontreated_target_nipu: 0.87
# treated_nontarget_rpu: 15.07
# treated_nontarget_nipu: -0.60
# nontreated_nontarget_rpu: 14.40
# nontreated_nontarget_nipu: 1.93
# --- with 49.99931324341401% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.10081900258958
# --> in non-targeted users:
# cpit = 3.7510249431545013
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.24
# nipu_cohort: 0.37
# lift targeted cohort vs control: 0.08
# lift random vs control: 0.10
# cpit cohort vs control: 1.11
# lift targeted-treated vs control: -0.02
# cpit cohort: 1.111075
# ---------------------------->>>>>>
# perc - target: 0.60
# treated_target_rpu: 12.30
# treated_target_nipu: -1.08
# nontreated_target_rpu: 10.63
# nontreated_target_nipu: 0.99
# treated_nontarget_rpu: 15.50
# treated_nontarget_nipu: -0.62
# nontreated_nontarget_rpu: 14.81
# nontreated_nontarget_nipu: 2.01
# --- with 59.9991758920968% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.2427463548138618
# --> in non-targeted users:
# cpit = 3.83961724393553
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.30
# nipu_cohort: 0.16
# lift targeted cohort vs control: 0.08
# lift random vs control: 0.10
# cpit cohort vs control: 1.25
# lift targeted-treated vs control: -0.00
# cpit cohort: 1.252669
# ---------------------------->>>>>>
# perc - target: 0.70
# treated_target_rpu: 12.50
# treated_target_nipu: -0.98
# nontreated_target_rpu: 10.99
# nontreated_target_nipu: 1.09
# treated_nontarget_rpu: 16.06
# treated_nontarget_nipu: -0.71
# nontreated_nontarget_rpu: 15.39
# nontreated_nontarget_nipu: 2.14
# --- with 69.9990385407796% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.3643217228991298
# --> in non-targeted users:
# cpit = 4.208479749989335
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.37
# nipu_cohort: -0.04
# lift targeted cohort vs control: 0.09
# lift random vs control: 0.10
# cpit cohort vs control: 1.37
# lift targeted-treated vs control: 0.02
# cpit cohort: 1.369957
# ---------------------------->>>>>>
# perc - target: 0.80
# treated_target_rpu: 12.73
# treated_target_nipu: -0.90
# nontreated_target_rpu: 11.30
# nontreated_target_nipu: 1.17
# treated_nontarget_rpu: 16.99
# treated_nontarget_nipu: -0.90
# nontreated_nontarget_rpu: 16.31
# nontreated_nontarget_nipu: 2.31
# --- with 79.99890118946242% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.4547955847059917
# --> in non-targeted users:
# cpit = 4.741477503299028
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.44
# nipu_cohort: -0.26
# lift targeted cohort vs control: 0.09
# lift random vs control: 0.10
# cpit cohort vs control: 1.46
# lift targeted-treated vs control: 0.03
# cpit cohort: 1.464020
# ---------------------------->>>>>>
# perc - target: 0.90
# treated_target_rpu: 12.98
# treated_target_nipu: -1.04
# nontreated_target_rpu: 11.63
# nontreated_target_nipu: 1.26
# treated_nontarget_rpu: 18.93
# treated_nontarget_nipu: 0.40
# nontreated_nontarget_rpu: 18.43
# nontreated_nontarget_nipu: 2.63
# --- with 89.99876383814521% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.7022907310929971
# --> in non-targeted users:
# cpit = 4.40124913638078
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.52
# nipu_cohort: -0.67
# lift targeted cohort vs control: 0.10
# lift random vs control: 0.10
# cpit cohort vs control: 1.71
# lift targeted-treated vs control: 0.05
# cpit cohort: 1.709791
# rpu_cohort
# 13.524808477233227
# treated_target_rpu
# 13.557862730571985
# ---------------------------->>>>>>
# perc - target: 1.00
# treated_target_rpu: 13.56
# treated_target_nipu: -0.90
# nontreated_target_rpu: 12.31
# nontreated_target_nipu: 1.40
# treated_nontarget_rpu: nan
# treated_nontarget_nipu: nan
# nontreated_nontarget_rpu: 0.00
# nontreated_nontarget_nipu: 0.00
# --- with 99.99862648682802% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.846853311387234
# --> in non-targeted users:
# cpit = nan
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.56
# nipu_cohort: -0.90
# lift targeted cohort vs control: 0.10
# lift random vs control: 0.10
# cpit cohort vs control: 1.85
# lift targeted-treated vs control: 0.10
# cpit cohort: 1.846524
# rpu_control: 12.311494825154343
# nipu_control: 1.4018543060049007
# rpu_ft: 13.557862730571786
# nipu_ft: -0.899593703495978
# ---------------------------->>>>>>
# perc - target: 0.10
# treated_target_rpu: 10.89
# treated_target_nipu: -1.01
# nontreated_target_rpu: 8.49
# nontreated_target_nipu: 0.21
# treated_nontarget_rpu: 13.86
# treated_nontarget_nipu: -0.89
# nontreated_nontarget_rpu: 12.74
# nontreated_nontarget_nipu: 1.53
# --- with 9.999862648682802% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 0.5094888110039174
# --> in non-targeted users:
# cpit = 2.162545341595834
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 12.55
# nipu_cohort: 1.28
# lift targeted cohort vs control: 0.02
# lift random vs control: 0.10
# cpit cohort vs control: 0.51
# lift targeted-treated vs control: -0.12
# cpit cohort: 0.510324
# ---------------------------->>>>>>
# perc - target: 0.20
# treated_target_rpu: 11.26
# treated_target_nipu: -0.86
# nontreated_target_rpu: 8.86
# nontreated_target_nipu: 0.52
# treated_nontarget_rpu: 14.15
# treated_nontarget_nipu: -0.91
# nontreated_nontarget_rpu: 13.17
# nontreated_nontarget_nipu: 1.62
# --- with 19.999725297365604% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 0.5758117379793167
# --> in non-targeted users:
# cpit = 2.5791753370281887
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 12.79
# nipu_cohort: 1.12
# lift targeted cohort vs control: 0.04
# lift random vs control: 0.10
# cpit cohort vs control: 0.58
# lift targeted-treated vs control: -0.09
# cpit cohort: 0.584251
# ---------------------------->>>>>>
# perc - target: 0.30
# treated_target_rpu: 11.41
# treated_target_nipu: -1.35
# nontreated_target_rpu: 9.20
# nontreated_target_nipu: 0.68
# treated_nontarget_rpu: 14.51
# treated_nontarget_nipu: -0.70
# nontreated_nontarget_rpu: 13.64
# nontreated_nontarget_nipu: 1.71
# --- with 29.9995879460484% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 0.9172188335855582
# --> in non-targeted users:
# cpit = 2.763058482509968
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 12.97
# nipu_cohort: 0.79
# lift targeted cohort vs control: 0.05
# lift random vs control: 0.10
# cpit cohort vs control: 0.93
# lift targeted-treated vs control: -0.07
# cpit cohort: 0.929281
# ---------------------------->>>>>>
# perc - target: 0.40
# treated_target_rpu: 11.68
# treated_target_nipu: -1.17
# nontreated_target_rpu: 9.66
# nontreated_target_nipu: 0.78
# treated_nontarget_rpu: 14.85
# treated_nontarget_nipu: -0.72
# nontreated_nontarget_rpu: 14.07
# nontreated_nontarget_nipu: 1.81
# --- with 39.99945059473121% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 0.9627755289885305
# --> in non-targeted users:
# cpit = 3.2312092069846665
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.11
# nipu_cohort: 0.62
# lift targeted cohort vs control: 0.07
# lift random vs control: 0.10
# cpit cohort vs control: 0.97
# lift targeted-treated vs control: -0.05
# cpit cohort: 0.974814
# ---------------------------->>>>>>
# perc - target: 0.50
# treated_target_rpu: 11.96
# treated_target_nipu: -1.20
# nontreated_target_rpu: 10.13
# nontreated_target_nipu: 0.85
# treated_nontarget_rpu: 15.19
# treated_nontarget_nipu: -0.59
# nontreated_nontarget_rpu: 14.48
# nontreated_nontarget_nipu: 1.95
# --- with 49.99931324341401% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.1212295098048497
# --> in non-targeted users:
# cpit = 3.5617133341580804
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.22
# nipu_cohort: 0.37
# lift targeted cohort vs control: 0.07
# lift random vs control: 0.10
# cpit cohort vs control: 1.13
# lift targeted-treated vs control: -0.03
# cpit cohort: 1.130981
# ---------------------------->>>>>>
# perc - target: 0.60
# treated_target_rpu: 12.22
# treated_target_nipu: -1.08
# nontreated_target_rpu: 10.54
# nontreated_target_nipu: 0.97
# treated_nontarget_rpu: 15.61
# treated_nontarget_nipu: -0.62
# nontreated_nontarget_rpu: 14.95
# nontreated_nontarget_nipu: 2.04
# --- with 59.9991758920968% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.224128888138996
# --> in non-targeted users:
# cpit = 4.007763580680982
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.31
# nipu_cohort: 0.17
# lift targeted cohort vs control: 0.08
# lift random vs control: 0.10
# cpit cohort vs control: 1.23
# lift targeted-treated vs control: -0.01
# cpit cohort: 1.233225
# ---------------------------->>>>>>
# perc - target: 0.70
# treated_target_rpu: 12.39
# treated_target_nipu: -0.98
# nontreated_target_rpu: 10.88
# nontreated_target_nipu: 1.07
# treated_nontarget_rpu: 16.36
# treated_nontarget_nipu: -0.70
# nontreated_nontarget_rpu: 15.64
# nontreated_nontarget_nipu: 2.17
# --- with 69.9990385407796% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.3542920604483963
# --> in non-targeted users:
# cpit = 3.9680513145874783
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.37
# nipu_cohort: -0.04
# lift targeted cohort vs control: 0.09
# lift random vs control: 0.10
# cpit cohort vs control: 1.36
# lift targeted-treated vs control: 0.01
# cpit cohort: 1.364968
# ---------------------------->>>>>>
# perc - target: 0.80
# treated_target_rpu: 12.64
# treated_target_nipu: -0.90
# nontreated_target_rpu: 11.20
# nontreated_target_nipu: 1.16
# treated_nontarget_rpu: 17.38
# treated_nontarget_nipu: -0.90
# nontreated_nontarget_rpu: 16.72
# nontreated_nontarget_nipu: 2.37
# --- with 79.99890118946242% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.4233139185188175
# --> in non-targeted users:
# cpit = 4.956168705061372
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.46
# nipu_cohort: -0.25
# lift targeted cohort vs control: 0.09
# lift random vs control: 0.10
# cpit cohort vs control: 1.44
# lift targeted-treated vs control: 0.03
# cpit cohort: 1.436477
# ---------------------------->>>>>>
# perc - target: 0.90
# treated_target_rpu: 12.88
# treated_target_nipu: -0.84
# nontreated_target_rpu: 11.56
# nontreated_target_nipu: 1.25
# treated_nontarget_rpu: 19.75
# treated_nontarget_nipu: -1.49
# nontreated_nontarget_rpu: 19.05
# nontreated_nontarget_nipu: 2.73
# --- with 89.99876383814521% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.5784796478714174
# --> in non-targeted users:
# cpit = 6.030544469167508
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.50
# nipu_cohort: -0.48
# lift targeted cohort vs control: 0.10
# lift random vs control: 0.10
# cpit cohort vs control: 1.58
# lift targeted-treated vs control: 0.05
# cpit cohort: 1.583014
# rpu_cohort
# 13.499572173809074
# treated_target_rpu
# 13.557862730571985
# ---------------------------->>>>>>
# perc - target: 1.00
# treated_target_rpu: 13.56
# treated_target_nipu: -0.90
# nontreated_target_rpu: 12.31
# nontreated_target_nipu: 1.40
# treated_nontarget_rpu: nan
# treated_nontarget_nipu: nan
# nontreated_nontarget_rpu: 0.00
# nontreated_nontarget_nipu: 0.00
# --- with 99.99862648682802% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.846853311387234
# --> in non-targeted users:
# cpit = nan
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.56
# nipu_cohort: -0.90
# lift targeted cohort vs control: 0.10
# lift random vs control: 0.10
# cpit cohort vs control: 1.85
# lift targeted-treated vs control: 0.10
# cpit cohort: 1.846524
# rpu_control: 12.311494825154343
# nipu_control: 1.4018543060049007
# rpu_ft: 13.557862730571786
# nipu_ft: -0.899593703495978
# ---------------------------->>>>>>
# perc - target: 0.10
# treated_target_rpu: 10.73
# treated_target_nipu: -0.67
# nontreated_target_rpu: 8.49
# nontreated_target_nipu: 0.42
# treated_nontarget_rpu: 13.89
# treated_nontarget_nipu: -0.93
# nontreated_nontarget_rpu: 12.73
# nontreated_nontarget_nipu: 1.51
# --- with 9.999862648682802% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 0.48309043235203436
# --> in non-targeted users:
# cpit = 2.0954477259492132
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 12.53
# nipu_cohort: 1.29
# lift targeted cohort vs control: 0.02
# lift random vs control: 0.10
# cpit cohort vs control: 0.50
# lift targeted-treated vs control: -0.13
# cpit cohort: 0.503247
# ---------------------------->>>>>>
# perc - target: 0.20
# treated_target_rpu: 10.98
# treated_target_nipu: -0.63
# nontreated_target_rpu: 8.87
# nontreated_target_nipu: 0.64
# treated_nontarget_rpu: 14.22
# treated_nontarget_nipu: -0.97
# nontreated_nontarget_rpu: 13.17
# nontreated_nontarget_nipu: 1.59
# --- with 19.999725297365604% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 0.6020234535953887
# --> in non-targeted users:
# cpit = 2.428305843898345
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 12.73
# nipu_cohort: 1.15
# lift targeted cohort vs control: 0.03
# lift random vs control: 0.10
# cpit cohort vs control: 0.61
# lift targeted-treated vs control: -0.11
# cpit cohort: 0.610932
# ---------------------------->>>>>>
# perc - target: 0.30
# treated_target_rpu: 11.29
# treated_target_nipu: -0.63
# nontreated_target_rpu: 9.30
# nontreated_target_nipu: 0.68
# treated_nontarget_rpu: 14.55
# treated_nontarget_nipu: -1.02
# nontreated_nontarget_rpu: 13.60
# nontreated_nontarget_nipu: 1.71
# --- with 29.9995879460484% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 0.6564309823868317
# --> in non-targeted users:
# cpit = 2.870143139780184
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 12.90
# nipu_cohort: 1.01
# lift targeted cohort vs control: 0.05
# lift random vs control: 0.10
# cpit cohort vs control: 0.66
# lift targeted-treated vs control: -0.08
# cpit cohort: 0.662146
# ---------------------------->>>>>>
# perc - target: 0.40
# treated_target_rpu: 11.70
# treated_target_nipu: -0.61
# nontreated_target_rpu: 9.73
# nontreated_target_nipu: 0.81
# treated_nontarget_rpu: 14.82
# treated_nontarget_nipu: -1.10
# nontreated_nontarget_rpu: 14.02
# nontreated_nontarget_nipu: 1.80
# --- with 39.99945059473121% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 0.7178322216101899
# --> in non-targeted users:
# cpit = 3.6304435947817564
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.09
# nipu_cohort: 0.83
# lift targeted cohort vs control: 0.06
# lift random vs control: 0.10
# cpit cohort vs control: 0.72
# lift targeted-treated vs control: -0.05
# cpit cohort: 0.723884
# ---------------------------->>>>>>
# perc - target: 0.50
# treated_target_rpu: 11.89
# treated_target_nipu: -0.61
# nontreated_target_rpu: 10.14
# nontreated_target_nipu: 0.91
# treated_nontarget_rpu: 15.25
# treated_nontarget_nipu: -1.19
# nontreated_nontarget_rpu: 14.47
# nontreated_nontarget_nipu: 1.89
# --- with 49.99931324341401% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 0.8712419664205913
# --> in non-targeted users:
# cpit = 3.928331085235808
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.18
# nipu_cohort: 0.64
# lift targeted cohort vs control: 0.07
# lift random vs control: 0.10
# cpit cohort vs control: 0.88
# lift targeted-treated vs control: -0.03
# cpit cohort: 0.876991
# ---------------------------->>>>>>
# perc - target: 0.60
# treated_target_rpu: 12.13
# treated_target_nipu: -0.58
# nontreated_target_rpu: 10.54
# nontreated_target_nipu: 1.00
# treated_nontarget_rpu: 15.74
# treated_nontarget_nipu: -1.38
# nontreated_nontarget_rpu: 14.96
# nontreated_nontarget_nipu: 1.99
# --- with 59.9991758920968% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 0.9969136819615829
# --> in non-targeted users:
# cpit = 4.3314568331911785
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.26
# nipu_cohort: 0.45
# lift targeted cohort vs control: 0.08
# lift random vs control: 0.10
# cpit cohort vs control: 1.00
# lift targeted-treated vs control: -0.01
# cpit cohort: 1.003215
# ---------------------------->>>>>>
# perc - target: 0.70
# treated_target_rpu: 12.38
# treated_target_nipu: -0.79
# nontreated_target_rpu: 10.85
# nontreated_target_nipu: 1.09
# treated_nontarget_rpu: 16.37
# treated_nontarget_nipu: -1.15
# nontreated_nontarget_rpu: 15.70
# nontreated_nontarget_nipu: 2.12
# --- with 69.9990385407796% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.233994352468343
# --> in non-targeted users:
# cpit = 4.873638406279217
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.38
# nipu_cohort: 0.08
# lift targeted cohort vs control: 0.09
# lift random vs control: 0.10
# cpit cohort vs control: 1.24
# lift targeted-treated vs control: 0.01
# cpit cohort: 1.241572
# ---------------------------->>>>>>
# perc - target: 0.80
# treated_target_rpu: 12.70
# treated_target_nipu: -0.86
# nontreated_target_rpu: 11.25
# nontreated_target_nipu: 1.18
# treated_nontarget_rpu: 17.11
# treated_nontarget_nipu: -1.08
# nontreated_nontarget_rpu: 16.51
# nontreated_nontarget_nipu: 2.29
# --- with 79.99890118946242% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.3999456883853107
# --> in non-targeted users:
# cpit = 5.623976942691156
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.47
# nipu_cohort: -0.23
# lift targeted cohort vs control: 0.09
# lift random vs control: 0.10
# cpit cohort vs control: 1.41
# lift targeted-treated vs control: 0.03
# cpit cohort: 1.410933
# ---------------------------->>>>>>
# perc - target: 0.90
# treated_target_rpu: 13.03
# treated_target_nipu: -0.79
# nontreated_target_rpu: 11.67
# nontreated_target_nipu: 1.27
# treated_nontarget_rpu: 18.48
# treated_nontarget_nipu: -1.92
# nontreated_nontarget_rpu: 18.03
# nontreated_nontarget_nipu: 2.54
# --- with 89.99876383814521% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.5173019614336964
# --> in non-targeted users:
# cpit = 9.8297945808865
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.53
# nipu_cohort: -0.46
# lift targeted cohort vs control: 0.10
# lift random vs control: 0.10
# cpit cohort vs control: 1.52
# lift targeted-treated vs control: 0.06
# cpit cohort: 1.524583
# rpu_cohort
# 13.531088239481816
# treated_target_rpu
# 13.557862730571985
# ---------------------------->>>>>>
# perc - target: 1.00
# treated_target_rpu: 13.56
# treated_target_nipu: -0.90
# nontreated_target_rpu: 12.31
# nontreated_target_nipu: 1.40
# treated_nontarget_rpu: nan
# treated_nontarget_nipu: nan
# nontreated_nontarget_rpu: 3.55
# nontreated_nontarget_nipu: 0.10
# --- with 99.99862648682802% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.8467623531818131
# --> in non-targeted users:
# cpit = nan
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.56
# nipu_cohort: -0.90
# lift targeted cohort vs control: 0.10
# lift random vs control: 0.10
# cpit cohort vs control: 1.85
# lift targeted-treated vs control: 0.10
# cpit cohort: 1.846524
# rpu_control: 12.311494825154343
# nipu_control: 1.4018543060049007
# rpu_ft: 13.557862730571786
# nipu_ft: -0.899593703495978
# ---------------------------->>>>>>
# perc - target: 0.10
# treated_target_rpu: 9.30
# treated_target_nipu: -0.73
# nontreated_target_rpu: 7.15
# nontreated_target_nipu: 0.26
# treated_nontarget_rpu: 14.05
# treated_nontarget_nipu: -0.92
# nontreated_nontarget_rpu: 12.88
# nontreated_nontarget_nipu: 1.53
# --- with 9.999862648682802% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 0.4613888764303299
# --> in non-targeted users:
# cpit = 2.081382148171997
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 12.52
# nipu_cohort: 1.30
# lift targeted cohort vs control: 0.02
# lift random vs control: 0.10
# cpit cohort vs control: 0.48
# lift targeted-treated vs control: -0.24
# cpit cohort: 0.480741
# ---------------------------->>>>>>
# perc - target: 0.20
# treated_target_rpu: 10.01
# treated_target_nipu: -0.73
# nontreated_target_rpu: 7.85
# nontreated_target_nipu: 0.42
# treated_nontarget_rpu: 14.47
# treated_nontarget_nipu: -0.94
# nontreated_nontarget_rpu: 13.42
# nontreated_nontarget_nipu: 1.64
# --- with 19.999725297365604% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 0.5367911140489999
# --> in non-targeted users:
# cpit = 2.4691115553121095
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 12.74
# nipu_cohort: 1.17
# lift targeted cohort vs control: 0.03
# lift random vs control: 0.10
# cpit cohort vs control: 0.55
# lift targeted-treated vs control: -0.19
# cpit cohort: 0.546167
# ---------------------------->>>>>>
# perc - target: 0.30
# treated_target_rpu: 10.54
# treated_target_nipu: -0.75
# nontreated_target_rpu: 8.49
# nontreated_target_nipu: 0.61
# treated_nontarget_rpu: 14.87
# treated_nontarget_nipu: -0.96
# nontreated_nontarget_rpu: 13.94
# nontreated_nontarget_nipu: 1.74
# --- with 29.9995879460484% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 0.6628714014798105
# --> in non-targeted users:
# cpit = 2.926804691184458
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 12.92
# nipu_cohort: 0.99
# lift targeted cohort vs control: 0.05
# lift random vs control: 0.10
# cpit cohort vs control: 0.67
# lift targeted-treated vs control: -0.14
# cpit cohort: 0.668293
# ---------------------------->>>>>>
# perc - target: 0.40
# treated_target_rpu: 10.89
# treated_target_nipu: -0.70
# nontreated_target_rpu: 9.05
# nontreated_target_nipu: 0.74
# treated_nontarget_rpu: 15.38
# treated_nontarget_nipu: -1.03
# nontreated_nontarget_rpu: 14.48
# nontreated_nontarget_nipu: 1.84
# --- with 39.99945059473121% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 0.782361892606946
# --> in non-targeted users:
# cpit = 3.184908459587455
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.04
# nipu_cohort: 0.82
# lift targeted cohort vs control: 0.06
# lift random vs control: 0.10
# cpit cohort vs control: 0.79
# lift targeted-treated vs control: -0.12
# cpit cohort: 0.792094
# ---------------------------->>>>>>
# perc - target: 0.50
# treated_target_rpu: 11.26
# treated_target_nipu: -1.01
# nontreated_target_rpu: 9.54
# nontreated_target_nipu: 0.84
# treated_nontarget_rpu: 15.91
# treated_nontarget_nipu: -0.79
# nontreated_nontarget_rpu: 15.07
# nontreated_nontarget_nipu: 1.96
# --- with 49.99931324341401% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.0741859265223375
# --> in non-targeted users:
# cpit = 3.2313996591847447
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.17
# nipu_cohort: 0.47
# lift targeted cohort vs control: 0.07
# lift random vs control: 0.10
# cpit cohort vs control: 1.09
# lift targeted-treated vs control: -0.09
# cpit cohort: 1.087650
# ---------------------------->>>>>>
# perc - target: 0.60
# treated_target_rpu: 11.56
# treated_target_nipu: -0.92
# nontreated_target_rpu: 9.95
# nontreated_target_nipu: 0.93
# treated_nontarget_rpu: 16.68
# treated_nontarget_nipu: -0.87
# nontreated_nontarget_rpu: 15.81
# nontreated_nontarget_nipu: 2.10
# --- with 59.9991758920968% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.146906280378131
# --> in non-targeted users:
# cpit = 3.4262038197355897
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.26
# nipu_cohort: 0.29
# lift targeted cohort vs control: 0.08
# lift random vs control: 0.10
# cpit cohort vs control: 1.17
# lift targeted-treated vs control: -0.06
# cpit cohort: 1.167202
# ---------------------------->>>>>>
# perc - target: 0.70
# treated_target_rpu: 11.81
# treated_target_nipu: -0.87
# nontreated_target_rpu: 10.40
# nontreated_target_nipu: 1.03
# treated_nontarget_rpu: 17.88
# treated_nontarget_nipu: -0.98
# nontreated_nontarget_rpu: 16.72
# nontreated_nontarget_nipu: 2.25
# --- with 69.9990385407796% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.3395838662638286
# --> in non-targeted users:
# cpit = 2.785130644823494
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.28
# nipu_cohort: 0.07
# lift targeted cohort vs control: 0.08
# lift random vs control: 0.10
# cpit cohort vs control: 1.37
# lift targeted-treated vs control: -0.04
# cpit cohort: 1.368996
# ---------------------------->>>>>>
# perc - target: 0.80
# treated_target_rpu: 12.13
# treated_target_nipu: -0.81
# nontreated_target_rpu: 10.84
# nontreated_target_nipu: 1.13
# treated_nontarget_rpu: 19.46
# treated_nontarget_nipu: -1.26
# nontreated_nontarget_rpu: 18.15
# nontreated_nontarget_nipu: 2.48
# --- with 79.99890118946242% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.501794653882051
# --> in non-targeted users:
# cpit = 2.854285401066155
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.34
# nipu_cohort: -0.15
# lift targeted cohort vs control: 0.08
# lift random vs control: 0.10
# cpit cohort vs control: 1.52
# lift targeted-treated vs control: -0.01
# cpit cohort: 1.517833
# ---------------------------->>>>>>
# perc - target: 0.90
# treated_target_rpu: 12.52
# treated_target_nipu: -0.85
# nontreated_target_rpu: 11.33
# nontreated_target_nipu: 1.23
# treated_nontarget_rpu: 22.94
# treated_nontarget_nipu: -1.35
# nontreated_nontarget_rpu: 21.15
# nontreated_nontarget_nipu: 2.96
# --- with 89.99876383814521% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.7526876127091446
# --> in non-targeted users:
# cpit = 2.406150544950932
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.38
# nipu_cohort: -0.47
# lift targeted cohort vs control: 0.09
# lift random vs control: 0.10
# cpit cohort vs control: 1.75
# lift targeted-treated vs control: 0.02
# cpit cohort: 1.752634
# rpu_cohort
# 13.378325576329045
# treated_target_rpu
# 13.557862730571985
# ---------------------------->>>>>>
# perc - target: 1.00
# treated_target_rpu: 13.56
# treated_target_nipu: -0.90
# nontreated_target_rpu: 12.31
# nontreated_target_nipu: 1.40
# treated_nontarget_rpu: nan
# treated_nontarget_nipu: nan
# nontreated_nontarget_rpu: 85.06
# nontreated_nontarget_nipu: 11.65
# --- with 99.99862648682802% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.8445521331319974
# --> in non-targeted users:
# cpit = nan
# rpu_control: 12.31
# nipu_control: 1.40
# rpu_ft: 13.56
# nipu_ft: -0.90
# rpu_cohort: 13.56
# nipu_cohort: -0.90
# lift targeted cohort vs control: 0.10
# lift random vs control: 0.10
# cpit cohort vs control: 1.85
# lift targeted-treated vs control: 0.10
# cpit cohort: 1.846524
# temp:
# 3.041762285521891
# p_quantile:
# 0.4
# AUCC results:
# random: [0.5]
# rlearner: [0.70191681]
# duality rlearner 1 with lambda = 0.1:[0.70262239]
# drm: [0.68452456]
# tqr: [0.73674421]
