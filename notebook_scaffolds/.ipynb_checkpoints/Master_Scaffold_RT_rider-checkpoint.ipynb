# %%
## Scaffold for Michelangelo customers 
## authors: will.zou@uber.com dmantar@uber.com 
## Causal Models for real-time incentives 
## import libraries and modules 

import sys, os, pandas as pd, numpy as np, pickle as pkl, tensorflow as tf 
sys.path.append('../dataprep/') 
from QueryFunctions import *

# %%
### pull data either using queryrunner or using csv 
use_query = 0 ### turn this switch on (to 1.0/True vs 0.0/False) to run query using QueryRunner 
use_python3 = True 

if use_query: 
    from queryrunner_client import Client 
    qr = Client(user_email='will.zou@uber.com') 
    ##label_dates_weekly = "'2019-07-14', '2019-07-21', '2019-07-28', '2019-08-04'" 
    ##city_ids = '1,5,6,8,10,12,20,23,198' 
    #feature_dates="'2019-06-30'" 
    #proposal_start_date = '2019-07-08' 
    
    predFrame2 = qr.execute('presto', rt_data_presto_first()) 
    predFrame2 = pd.DataFrame(predFrame2.load_data()) 
else: 
    predFrame2 = pd.read_csv('../data/rt_query_result_rider.csv')

# %%
### Cross check on treatment and control cohort sizes 
cohort_column_name = 'treatment' 
treatment_indicator_value = True 
control_indicator_value = False 
print('size of dataset:') 
print(len(predFrame2)) 
print('size of control cohort:') 
print(sum(predFrame2[cohort_column_name] == control_indicator_value)) 
print('size of treatment cohort:') 
print(sum(predFrame2[cohort_column_name] == treatment_indicator_value))
# Out:
# size of dataset:
# 385189
# size of control cohort:
# 315156
# size of treatment cohort:
# 70033

# %%
### we should process the data such that route level cost and gains are per-session 
### so it's possible to rank the routes separately and it should be able to compare with results for 
### using rider information only 

### three data tables: 
### 1. with rider + route features and per route metrics 
### 2. with rider features and per rider metrics 
### 3. with route features and per route metrics 

### for table 1, we can have two algorithms 
### a. train a model on Table 2, score the riders as a feature for route-level model, then use route level model to evaluate 
### b. train a combined model on table 1

# %%
### preprocess the data 
### -- sample treatment to match control cohort 
### -- eliminate nulls, standard normalization 

D = predFrame2 
D = D.sample(frac=1.0) 

"""
feature_list = [ 
    'rating_2driver_min_avg_84d'
    , 'trip_incomplete_total_84d'
    , 'days_active_84d'
    , 'days_since_trip_first_lifetime'
    , 'days_since_last_hard_churn_lifetime'
    , 'days_since_last_soft_churn_lifetime'
    , 'fare_max_sd_84d'
    , 'churns_hard_lifetime'
    , 'trips_lifetime'
    , 'fare_max_p50_84d'
    , 'duration_session_pre_request_max_p50_84d'
    , 'trip_pool_per_x_84d'
    , 'fare_total_win7d_sd_84d'
    , 'trip_complete_win7d_sd_84d'
    , 'session_per_days_active_84d'
    , 'churns_soft_lifetime'
    , 'trip_complete_per_days_active_84d'
    , 'trip_pool_prc_84d'
    , 'session_background_pre_request_prc_84d'
    , 'session_lt_1m_prc_84d'
    , 'session_request_prc_84d'
    , 'duration_session_outside_total_prc_84d'
    , 'trip_x_prc_84d'
    , 'days_since_trip_last_lifetime'
    , 'promo_used_84d'
    , 'has_session_request_84d'
    , 'has_session_without_request_84d' 
    , 'fare_promo_total_avg_84d', 
    'fare_total_avg_84d', 
    'surge_trip_avg_84d', 
    'fare_total_win7d_potential_84d', 
    'fare_total_win28d_potential_84d', 
    'fare_lifetime', 
    'time_to_first_message_minutes_mean_lifetime', 
    'ata_trip_max_avg_84d', 
    'eta_trip_max_avg_84d', 
    'trip_pool_matched_avg_84d', 
    'payment_cash_trip_total_84d', 
    'duration_trip_total_p50_84d'
] 
"""
feature_list = [ 
    'rating_2driver_min_avg_84d'
    , 'days_active_84d'
    , 'days_since_trip_first_lifetime'
    , 'days_since_last_soft_churn_lifetime'
    , 'churns_hard_lifetime'
    , 'fare_max_p50_84d'
    , 'fare_total_win7d_sd_84d'
    , 'trip_complete_win7d_sd_84d'
    , 'trip_pool_prc_84d'
    , 'session_request_prc_84d'
    , 'days_since_trip_last_lifetime'
    , 'fare_promo_total_avg_84d'
    , 'fare_total_avg_84d'
    , 'surge_trip_avg_84d'
    , 'fare_total_win28d_potential_84d'
    , 'ata_trip_max_avg_84d'
    , 'duration_trip_total_p50_84d'
    , 'promo_used_84d'
#    , 'estimate_fare_distance_in_miles' 
#    , 'estimate_fare_duration_in_minutes' 
#    , 'origin_destination_haversine_miles' 
#    , 'origin_lat' 
#    , 'origin_lng'
#    , 'destination_lat'
#    , 'destination_lng'  
] 

label_list = [ 
    'gross_bookings_usd', 
    'variable_contribution_usd', 
    'num_sessions' 
] 

for l in feature_list: 
    print('number of nans: ' + str(sum(D[l] == '\\N'))) 
    D[l] = pd.to_numeric(D[l], errors='coerce') 
    D[l] = D[l] - D[l].mean() 
    D[l] = D[l] / D[l].std() 
    D[l][pd.isnull(D[l])] = 0.0 ## at zero mean due to standard normalization 

for l in label_list: 
    D[l] = pd.to_numeric(D[l], errors='coerce') 
    D[l][pd.isnull(D[l])] = 0.0 ## for zero gain/cost for financial data 

### -- compute simple statistics 
### compute cpit 
treated_entries = D[D[cohort_column_name] == treatment_indicator_value] 
untreated_entries = D[D[cohort_column_name] == control_indicator_value] 

rpu_treated = float(treated_entries[label_list[0]].sum()) / len(treated_entries) 
nipu_treated = float(treated_entries[label_list[1]].sum()) / len(treated_entries) 

rpu_untreated = float(untreated_entries[label_list[0]].sum()) / len(untreated_entries) 
nipu_untreated = float(untreated_entries[label_list[1]].sum()) / len(untreated_entries) 

cpit = -1.0 * (nipu_treated - nipu_untreated) / (rpu_treated - rpu_untreated) 

print('rpu_treated : ' + str(rpu_treated)) 
print('nipu_treated : ' + str(nipu_treated)) 
print('rpu_untreated : ' + str(rpu_untreated)) 
print('nipu_untreated : ' + str(nipu_untreated)) 
print('cpit : ' + str(cpit)) 

### split the data into 3/1/1 train/val/test 
len_tr = int(len(D) / 6 * 4) 
len_va = int(len(D) / 10 * 1) 

nX = D[feature_list].values 
w = D[cohort_column_name].apply(lambda x: 1.0 if x == treatment_indicator_value else 0.0) 
w = w.values 
values = D[label_list[0]] 
values = values.values * 1.0 
negcost = D[label_list[1]] 
negcost = negcost.values * 1.0 
num_sessions = D[label_list[2]].values 
#values = np.divide(values, num_sessions) 
#negcost = np.divide(negcost, num_sessions) 

## split train/val/test sets 

nX_tr = nX[0:len_tr, :] 
nX_va = nX[len_tr:len_tr + len_va, :] 
nX_te = nX[len_tr + len_va:, :] 

w_tr = w[0:len_tr]
w_va = w[len_tr:len_tr + len_va] 
w_te = w[len_tr + len_va:] 

values_tr = values[0:len_tr] 
values_va = values[len_tr:len_tr + len_va] 
values_te = values[len_tr + len_va:] 

negcost_tr = negcost[0:len_tr] 

negcost_va = negcost[len_tr:len_tr + len_va] 

negcost_te = negcost[len_tr + len_va:] 

## saving data using cPickel and naming the dictionaries 
saveD = {'nX_tr':nX_tr, 
         'w_tr':w_tr, 
         'values_tr':values_tr, 
         'nX_va':nX_va, 
         'w_va':w_va, 
         'values_va':values_va, 
         'nX_te':nX_te, 
         'w_te':w_te, 
         'values_te':values_te, 
         'feature_list':feature_list, 
         #'avg_ni_usd_tr':avg_ni_usd_tr, 
         'negcost_tr': negcost_tr, 
         #'avg_ni_usd_va':avg_ni_usd_va, 
         'negcost_va': negcost_va, 
         #'avg_ni_usd_te':avg_ni_usd_te, 
         'negcost_te': negcost_te 
         } 

pkl.dump(saveD, open('../data/rt_ma_training_data_v5_2019_07_08_vc_tr_featuremod3_rider', 'wb'))
# Out:
# number of nans: 109681
# /Users/will.zou/code/deeplearning_hscls/py3/lib/python3.6/site-packages/ipykernel_launcher.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# number of nans: 25718
# number of nans: 25718
# number of nans: 25858
# number of nans: 25858
# number of nans: 25718
# number of nans: 25718
# number of nans: 25718
# number of nans: 32510
# number of nans: 32510
# number of nans: 25718
# number of nans: 307680
# number of nans: 25718
# number of nans: 25718
# number of nans: 25816
# number of nans: 26481
# number of nans: 25718
# number of nans: 32510
# /Users/will.zou/code/deeplearning_hscls/py3/lib/python3.6/site-packages/ipykernel_launcher.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# rpu_treated : 30.42951102440421
# nipu_treated : -1.7710747558683853
# rpu_untreated : 26.59551281548783
# nipu_untreated : 2.7295478825906874
# cpit : 1.1738718677521507

# %%
sum(negcost == 0)
# Out:
# 231525

# %%
### code implements ranking model for treatment effect 
### for optimizing with respect to direct marketplace objectives 
### using tensorflow 

import numpy as np, tensorflow as tf, pandas as pd, pickle as pkl 
sys.path.append('../')  
from ModelDefinitions import * 
from DataProcFunctions import * 

### RxGy TQR setting: 
p_quantile = 0.4 ## percentage of quantile to aim for 
num_optimize_iterations = 600 ## number of optimization iterations 
num_modeling_inits = 2 ## number of random initializations 
num_hidden = 0 ## number of hidden units in DNN 
use_schedule = True ## option to use a constraint annealing schedule 
temp = 0.5 ## initial temperature for constraints 
inc_temp = 0.1 ## increment of temperature per 100 iterations 
save_cf_data = False ### whether to save data for causal forest training 

## set a random seed to reproduce results 
seed = 1234; tf.compat.v2.random.set_seed(seed); np.random.seed(seed) 

sample_frac = 1.0 ## option to sample data by a fraction \in (0, 1) 
data_filename =  '../data/rt_ma_training_data_v5_2019_07_08_vc_tr_featuremod3_rider' 
prefix = 'rt_v5_07_08_featuremod3_tr_iter100_run4_rider' 

D_tre, D_unt, Dv_tre, Dv_unt, Dt_tre, Dt_unt, o_tre, o_unt, ov_tre, ov_unt, ot_tre, ot_unt, c_tre, c_unt, cv_tre, cv_unt, ct_tre, ct_unt, D, w, o, c, Dv, wv, ov, cv, Dt, wt, ot, ct = LoadDataFromPkl(data_filename, frac = sample_frac, use_python3=use_python3, save_cf_data=save_cf_data) 

print('### ----- start the training of deep learning models ------ ') 
gs_tqr = [] 
gs_drm = [] 
for i in range(num_modeling_inits): 
    gs_tqr.append(tf.Graph()) 
for i in range(num_modeling_inits): 
    gs_drm.append(tf.Graph()) 

print('------> Training TQR ranking model .... ') 
val_results = [] 
sess_list = [] 
for i in range(num_modeling_inits): 
    print('---> running cross validation, iteration: ' + str(i)) 
    obj, opt, dumh, dumhu, vtemp, p_quantile = TunableTQRankingModelDNN(gs_tqr[i], D_tre, D_unt, o_tre, o_unt, c_tre, c_unt, 'train-first', temp, p_quantile, num_hidden, use_schedule) 
    ### session definitions and variable initialization 
    sess = tf.Session(graph = gs_tqr[i]) 
    sess_list.append(sess) 
    
    ### initialize variables and run optimization 
    with gs_tqr[i].as_default() as g: 
        init = tf.global_variables_initializer() 
    sess.run(init) 
    cur_temp = temp 
    for step in range(num_optimize_iterations): 
        _, objres = sess.run([opt, obj]) 
        if step % 100 == 0: 
            cur_temp = cur_temp + inc_temp 
            print('opt. step : ' + str(step) + ' obj: ' + str(objres)) 
            if use_schedule: 
                sess.run(vtemp.assign(cur_temp))
                print('setting temperature to :' + str(sess.run(vtemp))) 
    
    print('---> optimization finished ... ') 
    tempvalue = sess.run(vtemp)
    p_quantilevalue = p_quantile
    print('temp:') 
    print(tempvalue)
    print('p_quantile:')
    print(p_quantilevalue) 
    
    ### evaluate CPIT metric on validation set 
    objv, dumo, dumh, dumhu, dvtemp, dp_quantile = TunableTQRankingModelDNN(gs_tqr[i], Dv_tre, Dv_unt, ov_tre, ov_unt, cv_tre, cv_unt, 'eval', temp, p_quantile, num_hidden, use_schedule) 
    
    val_result = sess.run(objv) 
    print('validation CPIT:') 
    print(val_result) 
    val_results.append(val_result) 

from operator import itemgetter 
best_index = min(enumerate(val_results), key=itemgetter(1))[0] 

print('best performing model: iteration ' + str(best_index)) 

### run scoring on whole test set 
with gs_tqr[best_index].as_default() as g: 
    if num_hidden > 0: 
        with tf.variable_scope("tqrhidden") as scope: 
            h1_test = tf.contrib.layers.fully_connected(Dt, num_hidden, activation_fn=tf.nn.tanh, reuse=tf.AUTO_REUSE, scope=scope, weights_initializer=tf.contrib.layers.xavier_initializer()) 
        with tf.variable_scope("tqranker") as scope: 
            h_test = tf.contrib.layers.fully_connected(h1_test, 1, activation_fn=None, reuse=tf.AUTO_REUSE, scope=scope) 
    else: 
        with tf.variable_scope("tqranker") as scope: 
            h_test = tf.contrib.layers.fully_connected(Dt, 1, activation_fn=None, reuse=tf.AUTO_REUSE, scope=scope) 
    tqrscore = sess_list[best_index].run(h_test) 

print('------> Training DRM ranking model .... ') 
sess_list = [] 
val_results = [] 
for i in range(num_modeling_inits): 
    print('---> running cross validation, iteration: ' + str(i)) 
    ### ---- train cpit ranking model for comparison --- 
    dobjc, doptc, ddumh, ddumu = DirectRankingModelDNN(gs_drm[i], D_tre, D_unt, o_tre, o_unt, c_tre, c_unt, 'train-first-drm', num_hidden) 
    
    dsess = tf.Session(graph = gs_drm[i]) 
    sess_list.append(dsess) 
    
    ### initialize variables and run optimization 
    with gs_drm[i].as_default() as g: 
        dinit = tf.global_variables_initializer() 
    dsess.run(dinit) 
    for step in range(num_optimize_iterations): 
        _, dobjres = dsess.run([doptc, dobjc]) 
        if step % 100 == 0: 
            print('opt. step : ' + str(step) + ' obj: ' + str(dobjres)) 
    
    print('---> optimization finished ... ') 
    
    ### evaluate CPIT metric on validation set 
    dobjv, ddumo, dumh, dumhu = DirectRankingModelDNN(gs_drm[i], Dv_tre, Dv_unt, ov_tre, ov_unt, cv_tre, cv_unt, 'eval', num_hidden)
    val_result = dsess.run(dobjv) 
    print('validation CPIT:') 
    print(val_result) 
    val_results.append(val_result) 

best_index = min(enumerate(val_results), key=itemgetter(1))[0] 

print('best performing model: iteration ' + str(best_index)) 

### run scoring on whole test set 
with gs_drm[best_index].as_default() as g: 
    if num_hidden > 0: 
        with tf.variable_scope("drmhidden") as scope: 
            h1_test = tf.contrib.layers.fully_connected(Dt, num_hidden, activation_fn=tf.nn.tanh, reuse=tf.AUTO_REUSE, scope=scope, weights_initializer=tf.contrib.layers.xavier_initializer()) 
        with tf.variable_scope("drmranker") as scope: 
            h_test = tf.contrib.layers.fully_connected(h1_test, 1, activation_fn=tf.nn.tanh, reuse=tf.AUTO_REUSE, scope=scope) 
    else: 
        with tf.variable_scope("drmranker") as scope: 
            h_test = tf.contrib.layers.fully_connected(Dt, 1, activation_fn=tf.nn.tanh, reuse=tf.AUTO_REUSE, scope=scope) 
    drmscore = sess_list[best_index].run(h_test) 

### ---- train hte model for comparison ---- 
### we could utimize the original HTE functions 
from LinearHTEModels import * 
from PromotionModels import PromotionModels 

pmodels = PromotionModels() 

## set-up RLearner 
rl_ridge_model_O, rl_ridge_model_C = pmodels.fit_rlearner(D, o, c, w) 

## one model for order lift and one model for cost drop 
pred_values_va_rlearner_O = rl_ridge_model_O.predict(Dt) 
pred_values_va_rlearner_C = rl_ridge_model_C.predict(Dt) 

#plt.imagesc(np.concatneate(rl_ridge_model_O.params, ...params), axis=1) 

#if ranking_model == 'effectiveness-ratio': ## if we use the effectiveness ratio model, compute effectiveness ratio 
pred_values_va_rlearner = np.divide(np.maximum(pred_values_va_rlearner_O, 0), pred_values_va_rlearner_C + 1e-7) 

lhmodels = LinearHTEModels() 
lambds = [0.1] 
rlearnerscores = [] 
rl_ridge_model_L_list = [] 
## set-up lagrangian rlearner 
for i in range(len(lambds)): 
    lambd = lambds[i] 
    rl_ridge_model_L = lhmodels.fit_rlearner_lagrangian(D, o, c, w, lambd) 
    rl_ridge_model_L_list.append(rl_ridge_model_L) 
    rlearnerscores.append(rl_ridge_model_L.predict(Dt)) 

""" 
### this section is to load the results trained by grf R code 
### 

ot_cf = pd.read_csv('../results/causal_forest_grf_test_set_results_O_finalsize_numtrees1002.csv') 
ct_cf = pd.read_csv('../results/causal_forest_grf_test_set_results_C_finalsize_numtrees1002.csv') 

ot_cf = ot_cf.values() 
Ocfscores = ot_cf[0] 

ct_cf = ct_cf.values() 
Ccfscores = ct_cf[0] 

cfscore = np.divide(Ocfscores, Ccfscores) 
""" 

### ---- experimentation and plotting cost-curves ----- 
from experimentation import * 
exp = Experimentation() 
ranscore = np.random.rand(ot.shape[0], ) 
colors = ['b', 'c', 'g', 'y'] 
plt.figure() 
rlearnerauccs = [] 
ranaucc = exp.AUC_cpit_cost_curve_deciles_cohort(ranscore, ot, wt, -1.0 * ct, 'k', plot_random=True) 
quasiaucc = exp.AUC_cpit_cost_curve_deciles_cohort(pred_values_va_rlearner_O, ot, wt, -1.0 * ct, 'c') 
for i in range(len(lambds)): 
    rlearnerauccs.append(exp.AUC_cpit_cost_curve_deciles_cohort(rlearnerscores[i], ot, wt, -1.0 * ct, colors[i] )) 
#cfaucc = exp.AUC_cpit_cost_curve_deciles_cohort(cfscore, ot, wt, -1.0 * ct, 'g') # causal forest aucc and plotting 
tqraucc = exp.AUC_cpit_cost_curve_deciles_cohort(tqrscore, ot, wt, -1.0 * ct, 'r' ) 
drmaucc = exp.AUC_cpit_cost_curve_deciles_cohort(drmscore, ot, wt, -1.0 * ct, 'm' ) 
plt.title('Causal learning cost curves using targeting models') 

print('temp:') 
print(tempvalue) 
print('p_quantile:') 
print(p_quantilevalue) 

### --- add legeneds to plot ---- 
leg_str = ['Random'] 
leg_str.append('R-learner on Incremental Gain') 
for i in range(len(lambds)): 
    leg_str.append('Duality R-learner') 
leg_str.append('Causal Forest') # causal forest result 
leg_str.append('Top Quantile Ranking at ' + str(p_quantile*100) + '%') 
leg_str.append('Direct Ranking Model') 
plt.legend(leg_str) 

### --- print out aucc results for different models --- 
print('AUCC results: ') 
print('random: ' + str(ranaucc)) 
print('rlearner: ' + str(quasiaucc)) 
i = 0
for rlearneraucc in rlearnerauccs: 
    print('duality rlearner ' + str(i + 1) + ' with lambda = ' + str(lambds[i]) + ':' + str(rlearneraucc)) 
    i = i + 1
print('drm: ' + str(drmaucc)) 
print('tqr: ' + str(tqraucc)) 

plt.show() 

### --- saving data to results folder ---- 
save_filename = '../results/benchmarkwithcv_tqr_drm_hte_'+prefix+'_main_results.pkl' 
saveD = {'tqrscore':tqrscore, 'drmscore':drmscore, 'quasiscore':pred_values_va_rlearner, 'quasiscore_O':pred_values_va_rlearner_O, 'rlearnerscore':rlearnerscores, 'ot':ot, 'wt':wt, 'ct':ct, 'tempvalue':tempvalue, 'p_quantilevalue':p_quantilevalue, 
         'tqraucc':tqraucc, 'drmaucc':drmaucc, 'rlearnerauccs':rlearnerauccs, 'ranaucc':ranaucc, 'quasiaucc':quasiaucc} 
#'cfscore':cfscore, causal forest scores 
pkl.dump(saveD, open(save_filename, 'wb'))
# Out:
# load data from ../data/rxgy_ma_training_data_v5_2019_07_08_vc_tr_featuremod3
# printing averages of c_tr, c_unt, o_tre, o_unt ... :
# 1.9937143861001316
# -2.5929838328628616
# 30.586337611304618
# 26.528533194235884
# ### ----- start the training of deep learning models ------
# ------> Training TQR ranking model ....
# ---> running cross validation, iteration: 0
# opt. step : 0 obj: 1.0472083798985778
# setting temperature to :0.6
# opt. step : 100 obj: 0.9800942419563784
# setting temperature to :0.7
# opt. step : 200 obj: 0.9193862696950648
# setting temperature to :0.7999999999999999
# opt. step : 300 obj: 0.8732044051083845
# setting temperature to :0.8999999999999999
# opt. step : 400 obj: 0.8382954510091132
# setting temperature to :0.9999999999999999
# opt. step : 500 obj: 0.8121650099327039
# setting temperature to :1.0999999999999999
# opt. step : 600 obj: 0.7921215562173306
# setting temperature to :1.2
# opt. step : 700 obj: 0.776619036650182
# setting temperature to :1.3
# opt. step : 800 obj: 0.7641590582968573
# setting temperature to :1.4000000000000001
# opt. step : 900 obj: 0.7537377186844738
# setting temperature to :1.5000000000000002
# opt. step : 1000 obj: 0.7455274944970066
# setting temperature to :1.6000000000000003
# opt. step : 1100 obj: 0.7376728350868998
# setting temperature to :1.7000000000000004
# opt. step : 1200 obj: 0.7309838166210385
# setting temperature to :1.8000000000000005
# opt. step : 1300 obj: 0.7252819764782362
# setting temperature to :1.9000000000000006
# opt. step : 1400 obj: 0.7205575087015565
# setting temperature to :2.0000000000000004
# opt. step : 1500 obj: 0.7156724838871938
# setting temperature to :2.1000000000000005
# opt. step : 1600 obj: 0.7116639762480486
# setting temperature to :2.2000000000000006
# opt. step : 1700 obj: 0.7076670872087386
# setting temperature to :2.3000000000000007
# opt. step : 1800 obj: 0.7036108489334806
# setting temperature to :2.400000000000001
# opt. step : 1900 obj: 0.6994780506716416
# setting temperature to :2.500000000000001
# ---> optimization finished ...
# temp:
# 2.5257403912954253
# p_quantile:
# 0.4
# validation CPIT:
# 1.005097185156218
# ---> running cross validation, iteration: 1
# opt. step : 0 obj: 1.0646432210744674
# setting temperature to :0.6
# opt. step : 100 obj: 1.0025505486849902
# setting temperature to :0.7
# opt. step : 200 obj: 0.9511674311660662
# setting temperature to :0.7999999999999999
# opt. step : 300 obj: 0.905702942669651
# setting temperature to :0.8999999999999999
# opt. step : 400 obj: 0.8717961205361966
# setting temperature to :0.9999999999999999
# opt. step : 500 obj: 0.84478915997986
# setting temperature to :1.0999999999999999
# opt. step : 600 obj: 0.8220050236484302
# setting temperature to :1.2
# opt. step : 700 obj: 0.8031966582006005
# setting temperature to :1.3
# opt. step : 800 obj: 0.7864706194237726
# setting temperature to :1.4000000000000001
# opt. step : 900 obj: 0.774011227912559
# setting temperature to :1.5000000000000002
# opt. step : 1000 obj: 0.7627650420894214
# setting temperature to :1.6000000000000003
# opt. step : 1100 obj: 0.7533030993446556
# setting temperature to :1.7000000000000004
# opt. step : 1200 obj: 0.7455812295535839
# setting temperature to :1.8000000000000005
# opt. step : 1300 obj: 0.7384017255762196
# setting temperature to :1.9000000000000006
# opt. step : 1400 obj: 0.7319696313457754
# setting temperature to :2.0000000000000004
# opt. step : 1500 obj: 0.7262473047266571
# setting temperature to :2.1000000000000005
# opt. step : 1600 obj: 0.7221410901695556
# setting temperature to :2.2000000000000006
# opt. step : 1700 obj: 0.7185495600194379
# setting temperature to :2.3000000000000007
# opt. step : 1800 obj: 0.715157613306859
# setting temperature to :2.400000000000001
# opt. step : 1900 obj: 0.7124454079554126
# setting temperature to :2.500000000000001
# ---> optimization finished ...
# temp:
# 2.530116884855698
# p_quantile:
# 0.4
# validation CPIT:
# 1.0554394790331199
# best performing model: iteration 0
# ------> Training DRM ranking model ....
# ---> running cross validation, iteration: 0
# opt. step : 0 obj: 0.9782332282121539
# opt. step : 100 obj: 0.8272223612878873
# opt. step : 200 obj: 0.7312029212929532
# opt. step : 300 obj: 0.6752689756109109
# opt. step : 400 obj: 0.6316874467985724
# opt. step : 500 obj: 0.6030876239596016
# opt. step : 600 obj: 0.5842553485156382
# opt. step : 700 obj: 0.5692962711361056
# opt. step : 800 obj: 0.5563865449778722
# opt. step : 900 obj: 0.5449136826350968
# opt. step : 1000 obj: 0.5345010369521407
# opt. step : 1100 obj: 0.5248697568938705
# opt. step : 1200 obj: 0.5158075335310169
# opt. step : 1300 obj: 0.5071804491136984
# opt. step : 1400 obj: 0.49897267816821284
# opt. step : 1500 obj: 0.4912109687635101
# opt. step : 1600 obj: 0.4836333763544147
# opt. step : 1700 obj: 0.47420458663120346
# opt. step : 1800 obj: 0.4671818519826399
# opt. step : 1900 obj: 0.4607215989086916
# ---> optimization finished ...
# validation CPIT:
# 0.8973986424631547
# ---> running cross validation, iteration: 1
# opt. step : 0 obj: 1.0970909503076776
# opt. step : 100 obj: 0.9518307526537008
# opt. step : 200 obj: 0.8811818572164548
# opt. step : 300 obj: 0.7737504821137142
# opt. step : 400 obj: 0.710316487057416
# opt. step : 500 obj: 0.6781297660315762
# opt. step : 600 obj: 0.6577081992508508
# opt. step : 700 obj: 0.6429391327979521
# opt. step : 800 obj: 0.6302696347572551
# opt. step : 900 obj: 0.61742252658293
# opt. step : 1000 obj: 0.6034421954053021
# opt. step : 1100 obj: 0.5872881644964274
# opt. step : 1200 obj: 0.5593174344509543
# opt. step : 1300 obj: 0.532415858961869
# opt. step : 1400 obj: 0.5183251545567585
# opt. step : 1500 obj: 0.5063499467244001
# opt. step : 1600 obj: 0.4939849534767888
# opt. step : 1700 obj: 0.48186390970388393
# opt. step : 1800 obj: 0.4724744470407036
# opt. step : 1900 obj: 0.4648991390874241
# ---> optimization finished ...
# validation CPIT:
# 0.9840589493609204
# best performing model: iteration 0
# rpu_control: 26.61023324389618
# nipu_control: 2.885016801184031
# rpu_ft: 30.33242297850836
# nipu_ft: -2.2406735439480148
# ---------------------------->>>>>>
# perc - target: 0.10
# treated_target_rpu: 29.71
# treated_target_nipu: -0.50
# nontreated_target_rpu: 27.05
# nontreated_target_nipu: 2.88
# treated_nontarget_rpu: 30.40
# treated_nontarget_nipu: -2.44
# nontreated_nontarget_rpu: 26.56
# nontreated_nontarget_nipu: 2.89
# --- with 9.99883176053687% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.2702630988059547
# --> in non-targeted users:
# cpit = 1.3859298505416942
# rpu_control: 26.61
# nipu_control: 2.89
# rpu_ft: 30.33
# nipu_ft: -2.24
# rpu_cohort: 26.88
# nipu_cohort: 2.55
# lift targeted cohort vs control: 0.01
# lift random vs control: 0.14
# cpit cohort vs control: 1.27
# lift targeted-treated vs control: 0.12
# cpit cohort: 1.269264
# ---------------------------->>>>>>
# perc - target: 0.20
# treated_target_rpu: 31.28
# treated_target_nipu: -9.37
# nontreated_target_rpu: 26.01
# nontreated_target_nipu: 2.30
# treated_nontarget_rpu: 30.10
# treated_nontarget_nipu: -0.49
# nontreated_nontarget_rpu: 26.76
# nontreated_nontarget_nipu: 3.03
# --- with 19.99766352107374% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 2.214203822714981
# --> in non-targeted users:
# cpit = 1.0548475159037118
# rpu_control: 26.61
# nipu_control: 2.89
# rpu_ft: 30.33
# nipu_ft: -2.24
# rpu_cohort: 27.66
# nipu_cohort: 0.55
# lift targeted cohort vs control: 0.04
# lift random vs control: 0.14
# cpit cohort vs control: 2.21
# lift targeted-treated vs control: 0.18
# cpit cohort: 2.212801
# ---------------------------->>>>>>
# perc - target: 0.30
# treated_target_rpu: 30.89
# treated_target_nipu: -6.30
# nontreated_target_rpu: 26.24
# nontreated_target_nipu: 2.65
# treated_nontarget_rpu: 30.09
# treated_nontarget_nipu: -0.52
# nontreated_nontarget_rpu: 26.77
# nontreated_nontarget_nipu: 2.98
# --- with 29.996495281610613% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.922868594608684
# --> in non-targeted users:
# cpit = 1.0537046879628973
# rpu_control: 26.61
# nipu_control: 2.89
# rpu_ft: 30.33
# nipu_ft: -2.24
# rpu_cohort: 28.01
# nipu_cohort: 0.20
# lift targeted cohort vs control: 0.05
# lift random vs control: 0.14
# cpit cohort vs control: 1.92
# lift targeted-treated vs control: 0.16
# cpit cohort: 1.922426
# ---------------------------->>>>>>
# perc - target: 0.40
# treated_target_rpu: 30.93
# treated_target_nipu: -4.81
# nontreated_target_rpu: 26.59
# nontreated_target_nipu: 2.73
# treated_nontarget_rpu: 29.94
# treated_nontarget_nipu: -0.56
# nontreated_nontarget_rpu: 26.62
# nontreated_nontarget_nipu: 2.99
# --- with 39.99532704214748% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.7370742448653447
# --> in non-targeted users:
# cpit = 1.0695512701544851
# rpu_control: 26.61
# nipu_control: 2.89
# rpu_ft: 30.33
# nipu_ft: -2.24
# rpu_cohort: 28.35
# nipu_cohort: -0.13
# lift targeted cohort vs control: 0.07
# lift random vs control: 0.14
# cpit cohort vs control: 1.74
# lift targeted-treated vs control: 0.16
# cpit cohort: 1.736899
# ---------------------------->>>>>>
# perc - target: 0.50
# treated_target_rpu: 30.45
# treated_target_nipu: -3.96
# nontreated_target_rpu: 26.71
# nontreated_target_nipu: 2.81
# treated_nontarget_rpu: 30.22
# treated_nontarget_nipu: -0.55
# nontreated_nontarget_rpu: 26.51
# nontreated_nontarget_nipu: 2.96
# --- with 49.99415880268435% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.811427707611938
# --> in non-targeted users:
# cpit = 0.9450478075930127
# rpu_control: 26.61
# nipu_control: 2.89
# rpu_ft: 30.33
# nipu_ft: -2.24
# rpu_cohort: 28.48
# nipu_cohort: -0.50
# lift targeted cohort vs control: 0.07
# lift random vs control: 0.14
# cpit cohort vs control: 1.81
# lift targeted-treated vs control: 0.14
# cpit cohort: 1.811521
# ---------------------------->>>>>>
# perc - target: 0.60
# treated_target_rpu: 30.76
# treated_target_nipu: -3.39
# nontreated_target_rpu: 26.57
# nontreated_target_nipu: 2.88
# treated_nontarget_rpu: 29.71
# treated_nontarget_nipu: -0.55
# nontreated_nontarget_rpu: 26.67
# nontreated_nontarget_nipu: 2.89
# --- with 59.99299056322123% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.497983173570164
# --> in non-targeted users:
# cpit = 1.131450941403341
# rpu_control: 26.61
# nipu_control: 2.89
# rpu_ft: 30.33
# nipu_ft: -2.24
# rpu_cohort: 29.12
# nipu_cohort: -0.88
# lift targeted cohort vs control: 0.09
# lift random vs control: 0.14
# cpit cohort vs control: 1.50
# lift targeted-treated vs control: 0.16
# cpit cohort: 1.497936
# ---------------------------->>>>>>
# perc - target: 0.70
# treated_target_rpu: 30.29
# treated_target_nipu: -3.01
# nontreated_target_rpu: 26.65
# nontreated_target_nipu: 2.93
# treated_nontarget_rpu: 30.43
# treated_nontarget_nipu: -0.48
# nontreated_nontarget_rpu: 26.53
# nontreated_nontarget_nipu: 2.77
# --- with 69.9918223237581% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.6296455352154855
# --> in non-targeted users:
# cpit = 0.8337628492007031
# rpu_control: 26.61
# nipu_control: 2.89
# rpu_ft: 30.33
# nipu_ft: -2.24
# rpu_cohort: 29.16
# nipu_cohort: -1.27
# lift targeted cohort vs control: 0.10
# lift random vs control: 0.14
# cpit cohort vs control: 1.63
# lift targeted-treated vs control: 0.14
# cpit cohort: 1.629737
# ---------------------------->>>>>>
# perc - target: 0.80
# treated_target_rpu: 30.27
# treated_target_nipu: -2.67
# nontreated_target_rpu: 26.59
# nontreated_target_nipu: 2.93
# treated_nontarget_rpu: 30.59
# treated_nontarget_nipu: -0.51
# nontreated_nontarget_rpu: 26.70
# nontreated_nontarget_nipu: 2.69
# --- with 79.99065408429496% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.523922971181942
# --> in non-targeted users:
# cpit = 0.8218029102474927
# rpu_control: 26.61
# nipu_control: 2.89
# rpu_ft: 30.33
# nipu_ft: -2.24
# rpu_cohort: 29.55
# nipu_cohort: -1.60
# lift targeted cohort vs control: 0.11
# lift random vs control: 0.14
# cpit cohort vs control: 1.52
# lift targeted-treated vs control: 0.14
# cpit cohort: 1.523924
# ---------------------------->>>>>>
# perc - target: 0.90
# treated_target_rpu: 30.15
# treated_target_nipu: -2.43
# nontreated_target_rpu: 26.62
# nontreated_target_nipu: 2.85
# treated_nontarget_rpu: 32.05
# treated_nontarget_nipu: -0.49
# nontreated_nontarget_rpu: 26.56
# nontreated_nontarget_nipu: 3.15
# --- with 89.98948584483185% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.4971040371641036
# --> in non-targeted users:
# cpit = 0.6641196973542189
# rpu_control: 26.61
# nipu_control: 2.89
# rpu_ft: 30.33
# nipu_ft: -2.24
# rpu_cohort: 29.79
# nipu_cohort: -1.87
# lift targeted cohort vs control: 0.12
# lift random vs control: 0.14
# cpit cohort vs control: 1.50
# lift targeted-treated vs control: 0.13
# cpit cohort: 1.497137
# rpu_cohort
# 29.787459455211447
# treated_target_rpu
# 30.331441099181568
# ---------------------------->>>>>>
# perc - target: 1.00
# treated_target_rpu: 30.33
# treated_target_nipu: -2.24
# nontreated_target_rpu: 26.61
# nontreated_target_nipu: 2.89
# treated_nontarget_rpu: 44.01
# treated_nontarget_nipu: 0.43
# nontreated_nontarget_rpu: 19.76
# nontreated_nontarget_nipu: 2.26
# --- with 99.9883176053687% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.3778211547448558
# --> in non-targeted users:
# cpit = 0.07537620893732559
# rpu_control: 26.61
# nipu_control: 2.89
# rpu_ft: 30.33
# nipu_ft: -2.24
# rpu_cohort: 30.33
# nipu_cohort: -2.24
# lift targeted cohort vs control: 0.14
# lift random vs control: 0.14
# cpit cohort vs control: 1.38
# lift targeted-treated vs control: 0.14
# cpit cohort: 1.377478
# rpu_control: 26.61023324389618
# nipu_control: 2.885016801184031
# rpu_ft: 30.33242297850836
# nipu_ft: -2.2406735439480148
# ---------------------------->>>>>>
# perc - target: 0.10
# treated_target_rpu: 123.23
# treated_target_nipu: -23.47
# nontreated_target_rpu: 101.84
# nontreated_target_nipu: 10.68
# treated_nontarget_rpu: 19.99
# treated_nontarget_nipu: 0.12
# nontreated_nontarget_rpu: 18.26
# nontreated_nontarget_nipu: 2.02
# --- with 9.99883176053687% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.5968516359429905
# --> in non-targeted users:
# cpit = 1.0956751784754548
# rpu_control: 26.61
# nipu_control: 2.89
# rpu_ft: 30.33
# nipu_ft: -2.24
# rpu_cohort: 28.75
# nipu_cohort: -0.53
# lift targeted cohort vs control: 0.08
# lift random vs control: 0.14
# cpit cohort vs control: 1.59
# lift targeted-treated vs control: 3.63
# cpit cohort: 1.593633
# ---------------------------->>>>>>
# perc - target: 0.20
# treated_target_rpu: 84.95
# treated_target_nipu: -12.45
# nontreated_target_rpu: 72.02
# nontreated_target_nipu: 7.72
# treated_nontarget_rpu: 16.58
# treated_nontarget_nipu: 0.33
# nontreated_nontarget_rpu: 15.28
# nontreated_nontarget_nipu: 1.68
# --- with 19.99766352107374% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.560405247356305
# --> in non-targeted users:
# cpit = 1.033496338403412
# rpu_control: 26.61
# nipu_control: 2.89
# rpu_ft: 30.33
# nipu_ft: -2.24
# rpu_cohort: 29.21
# nipu_cohort: -1.15
# lift targeted cohort vs control: 0.10
# lift random vs control: 0.14
# cpit cohort vs control: 1.55
# lift targeted-treated vs control: 2.19
# cpit cohort: 1.551110
# ---------------------------->>>>>>
# perc - target: 0.30
# treated_target_rpu: 67.03
# treated_target_nipu: -8.44
# nontreated_target_rpu: 57.75
# nontreated_target_nipu: 6.03
# treated_nontarget_rpu: 14.29
# treated_nontarget_nipu: 0.47
# nontreated_nontarget_rpu: 13.33
# nontreated_nontarget_nipu: 1.54
# --- with 29.996495281610613% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.559054796328874
# --> in non-targeted users:
# cpit = 1.1179428239930838
# rpu_control: 26.61
# nipu_control: 2.89
# rpu_ft: 30.33
# nipu_ft: -2.24
# rpu_cohort: 29.44
# nipu_cohort: -1.45
# lift targeted cohort vs control: 0.11
# lift random vs control: 0.14
# cpit cohort vs control: 1.53
# lift targeted-treated vs control: 1.52
# cpit cohort: 1.534575
# ---------------------------->>>>>>
# perc - target: 0.40
# treated_target_rpu: 54.02
# treated_target_nipu: -6.32
# nontreated_target_rpu: 46.88
# nontreated_target_nipu: 4.97
# treated_nontarget_rpu: 14.15
# treated_nontarget_nipu: 0.54
# nontreated_nontarget_rpu: 13.17
# nontreated_nontarget_nipu: 1.51
# --- with 39.99532704214748% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.5806095507636213
# --> in non-targeted users:
# cpit = 0.9867162295393519
# rpu_control: 26.61
# nipu_control: 2.89
# rpu_ft: 30.33
# nipu_ft: -2.24
# rpu_cohort: 29.51
# nipu_cohort: -1.62
# lift targeted cohort vs control: 0.11
# lift random vs control: 0.14
# cpit cohort vs control: 1.55
# lift targeted-treated vs control: 1.03
# cpit cohort: 1.554792
# ---------------------------->>>>>>
# perc - target: 0.50
# treated_target_rpu: 47.27
# treated_target_nipu: -4.96
# nontreated_target_rpu: 40.89
# nontreated_target_nipu: 4.41
# treated_nontarget_rpu: 12.90
# treated_nontarget_nipu: 0.56
# nontreated_nontarget_rpu: 12.43
# nontreated_nontarget_nipu: 1.37
# --- with 49.99415880268435% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.4681984754721988
# --> in non-targeted users:
# cpit = 1.7006743034818586
# rpu_control: 26.61
# nipu_control: 2.89
# rpu_ft: 30.33
# nipu_ft: -2.24
# rpu_cohort: 29.85
# nipu_cohort: -1.79
# lift targeted cohort vs control: 0.12
# lift random vs control: 0.14
# cpit cohort vs control: 1.45
# lift targeted-treated vs control: 0.78
# cpit cohort: 1.446175
# ---------------------------->>>>>>
# perc - target: 0.60
# treated_target_rpu: 42.09
# treated_target_nipu: -4.15
# nontreated_target_rpu: 36.62
# nontreated_target_nipu: 4.00
# treated_nontarget_rpu: 12.22
# treated_nontarget_nipu: 0.70
# nontreated_nontarget_rpu: 11.70
# nontreated_nontarget_nipu: 1.23
# --- with 59.99299056322123% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.489099542118805
# --> in non-targeted users:
# cpit = 1.0034612948106356
# rpu_control: 26.61
# nipu_control: 2.89
# rpu_ft: 30.33
# nipu_ft: -2.24
# rpu_cohort: 29.93
# nipu_cohort: -2.00
# lift targeted cohort vs control: 0.12
# lift random vs control: 0.14
# cpit cohort vs control: 1.47
# lift targeted-treated vs control: 0.58
# cpit cohort: 1.471880
# ---------------------------->>>>>>
# perc - target: 0.70
# treated_target_rpu: 38.15
# treated_target_nipu: -3.52
# nontreated_target_rpu: 33.26
# nontreated_target_nipu: 3.48
# treated_nontarget_rpu: 11.86
# treated_nontarget_nipu: 0.78
# nontreated_nontarget_rpu: 11.14
# nontreated_nontarget_nipu: 1.49
# --- with 69.9918223237581% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.4323355486377505
# --> in non-targeted users:
# cpit = 0.9870046984951385
# rpu_control: 26.61
# nipu_control: 2.89
# rpu_ft: 30.33
# nipu_ft: -2.24
# rpu_cohort: 30.05
# nipu_cohort: -2.02
# lift targeted cohort vs control: 0.13
# lift random vs control: 0.14
# cpit cohort vs control: 1.43
# lift targeted-treated vs control: 0.43
# cpit cohort: 1.426520
# ---------------------------->>>>>>
# perc - target: 0.80
# treated_target_rpu: 34.89
# treated_target_nipu: -3.03
# nontreated_target_rpu: 30.59
# nontreated_target_nipu: 3.26
# treated_nontarget_rpu: 12.23
# treated_nontarget_nipu: 0.89
# nontreated_nontarget_rpu: 10.67
# nontreated_nontarget_nipu: 1.40
# --- with 79.99065408429496% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.462077724818133
# --> in non-targeted users:
# cpit = 0.32448096642897184
# rpu_control: 26.61
# nipu_control: 2.89
# rpu_ft: 30.33
# nipu_ft: -2.24
# rpu_cohort: 30.04
# nipu_cohort: -2.14
# lift targeted cohort vs control: 0.13
# lift random vs control: 0.14
# cpit cohort vs control: 1.46
# lift targeted-treated vs control: 0.31
# cpit cohort: 1.464294
# ---------------------------->>>>>>
# perc - target: 0.90
# treated_target_rpu: 32.35
# treated_target_nipu: -2.62
# nontreated_target_rpu: 28.46
# nontreated_target_nipu: 3.07
# treated_nontarget_rpu: 12.45
# treated_nontarget_nipu: 1.13
# nontreated_nontarget_rpu: 9.93
# nontreated_nontarget_nipu: 1.20
# --- with 89.98948584483185% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.4655327219642187
# --> in non-targeted users:
# cpit = 0.0257539638159702
# rpu_control: 26.61
# nipu_control: 2.89
# rpu_ft: 30.33
# nipu_ft: -2.24
# rpu_cohort: 30.10
# nipu_cohort: -2.24
# lift targeted cohort vs control: 0.13
# lift random vs control: 0.14
# cpit cohort vs control: 1.47
# lift targeted-treated vs control: 0.22
# cpit cohort: 1.467435
# ../experimentation.py:109: RuntimeWarning: invalid value encountered in long_scalars
#   treated_untarget_rpu = sum(1.0 * values[treated_untargeted_filter]) / sum(treated_untargeted_filter)
# ../experimentation.py:110: RuntimeWarning: invalid value encountered in long_scalars
#   treated_untarget_nipu = sum(1.0 * n9d_ni_usd[treated_untargeted_filter]) / sum(treated_untargeted_filter)
# rpu_cohort
# 30.101427001496333
# treated_target_rpu
# 30.33242297850831
# ---------------------------->>>>>>
# perc - target: 1.00
# treated_target_rpu: 30.33
# treated_target_nipu: -2.24
# nontreated_target_rpu: 26.61
# nontreated_target_nipu: 2.88
# treated_nontarget_rpu: nan
# treated_nontarget_nipu: nan
# nontreated_nontarget_rpu: 59.84
# nontreated_nontarget_nipu: 9.19
# --- with 99.9883176053687% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.3750703763763326
# --> in non-targeted users:
# cpit = nan
# rpu_control: 26.61
# nipu_control: 2.89
# rpu_ft: 30.33
# nipu_ft: -2.24
# rpu_cohort: 30.33
# nipu_cohort: -2.24
# lift targeted cohort vs control: 0.14
# lift random vs control: 0.14
# cpit cohort vs control: 1.38
# lift targeted-treated vs control: 0.14
# cpit cohort: 1.377063
# rpu_control: 26.61023324389618
# nipu_control: 2.885016801184031
# rpu_ft: 30.33242297850836
# nipu_ft: -2.2406735439480148
# ---------------------------->>>>>>
# perc - target: 0.10
# treated_target_rpu: 119.79
# treated_target_nipu: -23.47
# nontreated_target_rpu: 99.43
# nontreated_target_nipu: 10.31
# treated_nontarget_rpu: 20.33
# treated_nontarget_nipu: 0.13
# nontreated_nontarget_rpu: 18.53
# nontreated_nontarget_nipu: 2.06
# --- with 9.99883176053687% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.659351534515468
# --> in non-targeted users:
# cpit = 1.0721273316315414
# rpu_control: 26.61
# nipu_control: 2.89
# rpu_ft: 30.33
# nipu_ft: -2.24
# rpu_cohort: 28.66
# nipu_cohort: -0.49
# lift targeted cohort vs control: 0.08
# lift random vs control: 0.14
# cpit cohort vs control: 1.65
# lift targeted-treated vs control: 3.50
# cpit cohort: 1.650452
# ---------------------------->>>>>>
# perc - target: 0.20
# treated_target_rpu: 82.20
# treated_target_nipu: -12.27
# nontreated_target_rpu: 70.23
# nontreated_target_nipu: 7.35
# treated_nontarget_rpu: 17.11
# treated_nontarget_nipu: 0.31
# nontreated_nontarget_rpu: 15.76
# nontreated_nontarget_nipu: 1.77
# --- with 19.99766352107374% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.6382071728133967
# --> in non-targeted users:
# cpit = 1.0771562359827376
# rpu_control: 26.61
# nipu_control: 2.89
# rpu_ft: 30.33
# nipu_ft: -2.24
# rpu_cohort: 29.04
# nipu_cohort: -1.03
# lift targeted cohort vs control: 0.09
# lift random vs control: 0.14
# cpit cohort vs control: 1.61
# lift targeted-treated vs control: 2.09
# cpit cohort: 1.610955
# ---------------------------->>>>>>
# perc - target: 0.30
# treated_target_rpu: 65.89
# treated_target_nipu: -8.28
# nontreated_target_rpu: 56.62
# nontreated_target_nipu: 5.91
# treated_nontarget_rpu: 14.83
# treated_nontarget_nipu: 0.39
# nontreated_nontarget_rpu: 13.80
# nontreated_nontarget_nipu: 1.59
# --- with 29.996495281610613% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.5295455261384077
# --> in non-targeted users:
# cpit = 1.166682384888043
# rpu_control: 26.61
# nipu_control: 2.89
# rpu_ft: 30.33
# nipu_ft: -2.24
# rpu_cohort: 29.43
# nipu_cohort: -1.37
# lift targeted cohort vs control: 0.11
# lift random vs control: 0.14
# cpit cohort vs control: 1.51
# lift targeted-treated vs control: 1.48
# cpit cohort: 1.509834
# ---------------------------->>>>>>
# perc - target: 0.40
# treated_target_rpu: 53.75
# treated_target_nipu: -6.38
# nontreated_target_rpu: 46.12
# nontreated_target_nipu: 4.87
# treated_nontarget_rpu: 14.61
# treated_nontarget_nipu: 0.54
# nontreated_nontarget_rpu: 13.63
# nontreated_nontarget_nipu: 1.56
# --- with 39.99532704214748% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.473400726841592
# --> in non-targeted users:
# cpit = 1.0408396428355293
# rpu_control: 26.61
# nipu_control: 2.89
# rpu_ft: 30.33
# nipu_ft: -2.24
# rpu_cohort: 29.68
# nipu_cohort: -1.62
# lift targeted cohort vs control: 0.12
# lift random vs control: 0.14
# cpit cohort vs control: 1.47
# lift targeted-treated vs control: 1.02
# cpit cohort: 1.467253
# ---------------------------->>>>>>
# perc - target: 0.50
# treated_target_rpu: 46.59
# treated_target_nipu: -5.00
# nontreated_target_rpu: 40.34
# nontreated_target_nipu: 4.33
# treated_nontarget_rpu: 13.64
# treated_nontarget_nipu: 0.59
# nontreated_nontarget_rpu: 12.97
# nontreated_nontarget_nipu: 1.45
# --- with 49.99415880268435% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.4923340862205874
# --> in non-targeted users:
# cpit = 1.2756154758199874
# rpu_control: 26.61
# nipu_control: 2.89
# rpu_ft: 30.33
# nipu_ft: -2.24
# rpu_cohort: 29.78
# nipu_cohort: -1.78
# lift targeted cohort vs control: 0.12
# lift random vs control: 0.14
# cpit cohort vs control: 1.47
# lift targeted-treated vs control: 0.75
# cpit cohort: 1.471919
# ---------------------------->>>>>>
# perc - target: 0.60
# treated_target_rpu: 41.43
# treated_target_nipu: -4.17
# nontreated_target_rpu: 36.26
# nontreated_target_nipu: 3.95
# treated_nontarget_rpu: 13.23
# treated_nontarget_nipu: 0.73
# nontreated_nontarget_rpu: 12.23
# nontreated_nontarget_nipu: 1.30
# --- with 59.99299056322123% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.5686871209898652
# --> in non-targeted users:
# cpit = 0.5721107072357263
# rpu_control: 26.61
# nipu_control: 2.89
# rpu_ft: 30.33
# nipu_ft: -2.24
# rpu_cohort: 29.75
# nipu_cohort: -1.98
# lift targeted cohort vs control: 0.12
# lift random vs control: 0.14
# cpit cohort vs control: 1.55
# lift targeted-treated vs control: 0.56
# cpit cohort: 1.550274
# ---------------------------->>>>>>
# perc - target: 0.70
# treated_target_rpu: 37.88
# treated_target_nipu: -3.54
# nontreated_target_rpu: 32.95
# nontreated_target_nipu: 3.43
# treated_nontarget_rpu: 12.60
# treated_nontarget_nipu: 0.83
# nontreated_nontarget_rpu: 11.86
# nontreated_nontarget_nipu: 1.61
# --- with 69.9918223237581% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.4156815127971576
# --> in non-targeted users:
# cpit = 1.0497917141079625
# rpu_control: 26.61
# nipu_control: 2.89
# rpu_ft: 30.33
# nipu_ft: -2.24
# rpu_cohort: 30.07
# nipu_cohort: -2.00
# lift targeted cohort vs control: 0.13
# lift random vs control: 0.14
# cpit cohort vs control: 1.41
# lift targeted-treated vs control: 0.42
# cpit cohort: 1.412424
# ---------------------------->>>>>>
# perc - target: 0.80
# treated_target_rpu: 34.80
# treated_target_nipu: -3.04
# nontreated_target_rpu: 30.47
# nontreated_target_nipu: 3.23
# treated_nontarget_rpu: 12.47
# treated_nontarget_nipu: 0.94
# nontreated_nontarget_rpu: 11.19
# nontreated_nontarget_nipu: 1.51
# --- with 79.99065408429496% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.4451541039888196
# --> in non-targeted users:
# cpit = 0.4427646306011264
# rpu_control: 26.61
# nipu_control: 2.89
# rpu_ft: 30.33
# nipu_ft: -2.24
# rpu_cohort: 30.08
# nipu_cohort: -2.13
# lift targeted cohort vs control: 0.13
# lift random vs control: 0.14
# cpit cohort vs control: 1.45
# lift targeted-treated vs control: 0.31
# cpit cohort: 1.445357
# ---------------------------->>>>>>
# perc - target: 0.90
# treated_target_rpu: 32.38
# treated_target_nipu: -2.62
# nontreated_target_rpu: 28.42
# nontreated_target_nipu: 3.06
# treated_nontarget_rpu: 12.28
# treated_nontarget_nipu: 1.10
# nontreated_nontarget_rpu: 10.28
# nontreated_nontarget_nipu: 1.27
# --- with 89.98948584483185% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.4343585197520003
# --> in non-targeted users:
# cpit = 0.08624678892156051
# rpu_control: 26.61
# nipu_control: 2.89
# rpu_ft: 30.33
# nipu_ft: -2.24
# rpu_cohort: 30.17
# nipu_cohort: -2.23
# lift targeted cohort vs control: 0.13
# lift random vs control: 0.14
# cpit cohort vs control: 1.44
# lift targeted-treated vs control: 0.22
# cpit cohort: 1.437509
# rpu_cohort
# 30.16859636719816
# treated_target_rpu
# 30.334600467595063
# ---------------------------->>>>>>
# perc - target: 1.00
# treated_target_rpu: 30.33
# treated_target_nipu: -2.24
# nontreated_target_rpu: 26.61
# nontreated_target_nipu: 2.89
# treated_nontarget_rpu: 0.00
# treated_nontarget_nipu: 0.00
# nontreated_nontarget_rpu: 39.11
# nontreated_nontarget_nipu: 2.21
# --- with 99.9883176053687% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.3757386268759435
# --> in non-targeted users:
# cpit = -0.05657769794200351
# rpu_control: 26.61
# nipu_control: 2.89
# rpu_ft: 30.33
# nipu_ft: -2.24
# rpu_cohort: 30.33
# nipu_cohort: -2.24
# lift targeted cohort vs control: 0.14
# lift random vs control: 0.14
# cpit cohort vs control: 1.38
# lift targeted-treated vs control: 0.14
# cpit cohort: 1.376301
# rpu_control: 26.61023324389618
# nipu_control: 2.885016801184031
# rpu_ft: 30.33242297850836
# nipu_ft: -2.2406735439480148
# ---------------------------->>>>>>
# perc - target: 0.10
# treated_target_rpu: 33.22
# treated_target_nipu: -19.45
# nontreated_target_rpu: 24.93
# nontreated_target_nipu: 2.07
# treated_nontarget_rpu: 30.01
# treated_nontarget_nipu: -0.33
# nontreated_nontarget_rpu: 26.80
# nontreated_nontarget_nipu: 2.98
# --- with 9.99883176053687% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 2.5969658296203937
# --> in non-targeted users:
# cpit = 1.0285089831613092
# rpu_control: 26.61
# nipu_control: 2.89
# rpu_ft: 30.33
# nipu_ft: -2.24
# rpu_cohort: 27.44
# nipu_cohort: 0.73
# lift targeted cohort vs control: 0.03
# lift random vs control: 0.14
# cpit cohort vs control: 2.60
# lift targeted-treated vs control: 0.25
# cpit cohort: 2.596753
# ---------------------------->>>>>>
# perc - target: 0.20
# treated_target_rpu: 32.34
# treated_target_nipu: -10.42
# nontreated_target_rpu: 24.45
# nontreated_target_nipu: 2.27
# treated_nontarget_rpu: 29.84
# treated_nontarget_nipu: -0.22
# nontreated_nontarget_rpu: 27.15
# nontreated_nontarget_nipu: 3.04
# --- with 19.99766352107374% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.607332892554822
# --> in non-targeted users:
# cpit = 1.2148055971190732
# rpu_control: 26.61
# nipu_control: 2.89
# rpu_ft: 30.33
# nipu_ft: -2.24
# rpu_cohort: 28.19
# nipu_cohort: 0.35
# lift targeted cohort vs control: 0.06
# lift random vs control: 0.14
# cpit cohort vs control: 1.61
# lift targeted-treated vs control: 0.22
# cpit cohort: 1.605954
# ---------------------------->>>>>>
# perc - target: 0.30
# treated_target_rpu: 31.14
# treated_target_nipu: -7.22
# nontreated_target_rpu: 24.60
# nontreated_target_nipu: 2.43
# treated_nontarget_rpu: 29.99
# treated_nontarget_nipu: -0.12
# nontreated_nontarget_rpu: 27.47
# nontreated_nontarget_nipu: 3.08
# --- with 29.996495281610613% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.4737139059572972
# --> in non-targeted users:
# cpit = 1.272633251670431
# rpu_control: 26.61
# nipu_control: 2.89
# rpu_ft: 30.33
# nipu_ft: -2.24
# rpu_cohort: 28.57
# nipu_cohort: -0.01
# lift targeted cohort vs control: 0.07
# lift random vs control: 0.14
# cpit cohort vs control: 1.47
# lift targeted-treated vs control: 0.17
# cpit cohort: 1.473208
# ---------------------------->>>>>>
# perc - target: 0.40
# treated_target_rpu: 30.70
# treated_target_nipu: -5.52
# nontreated_target_rpu: 24.69
# nontreated_target_nipu: 2.53
# treated_nontarget_rpu: 30.09
# treated_nontarget_nipu: -0.08
# nontreated_nontarget_rpu: 27.89
# nontreated_nontarget_nipu: 3.12
# --- with 39.99532704214748% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.3393614275690853
# --> in non-targeted users:
# cpit = 1.4570300751677163
# rpu_control: 26.61
# nipu_control: 2.89
# rpu_ft: 30.33
# nipu_ft: -2.24
# rpu_cohort: 29.02
# nipu_cohort: -0.34
# lift targeted cohort vs control: 0.09
# lift random vs control: 0.14
# cpit cohort vs control: 1.34
# lift targeted-treated vs control: 0.15
# cpit cohort: 1.338214
# ---------------------------->>>>>>
# perc - target: 0.50
# treated_target_rpu: 27.21
# treated_target_nipu: -4.37
# nontreated_target_rpu: 22.25
# nontreated_target_nipu: 2.24
# treated_nontarget_rpu: 33.46
# treated_nontarget_nipu: -0.11
# nontreated_nontarget_rpu: 30.97
# nontreated_nontarget_nipu: 3.53
# --- with 49.99415880268435% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.3320317651786782
# --> in non-targeted users:
# cpit = 1.4610384727041614
# rpu_control: 26.61
# nipu_control: 2.89
# rpu_ft: 30.33
# nipu_ft: -2.24
# rpu_cohort: 29.09
# nipu_cohort: -0.42
# lift targeted cohort vs control: 0.09
# lift random vs control: 0.14
# cpit cohort vs control: 1.33
# lift targeted-treated vs control: 0.02
# cpit cohort: 1.332552
# ---------------------------->>>>>>
# perc - target: 0.60
# treated_target_rpu: 27.37
# treated_target_nipu: -3.61
# nontreated_target_rpu: 22.84
# nontreated_target_nipu: 2.29
# treated_nontarget_rpu: 34.79
# treated_nontarget_nipu: -0.18
# nontreated_nontarget_rpu: 32.26
# nontreated_nontarget_nipu: 3.77
# --- with 59.99299056322123% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.3050293752004272
# --> in non-targeted users:
# cpit = 1.5562322088712126
# rpu_control: 26.61
# nipu_control: 2.89
# rpu_ft: 30.33
# nipu_ft: -2.24
# rpu_cohort: 29.32
# nipu_cohort: -0.66
# lift targeted cohort vs control: 0.10
# lift random vs control: 0.14
# cpit cohort vs control: 1.31
# lift targeted-treated vs control: 0.03
# cpit cohort: 1.305944
# ---------------------------->>>>>>
# perc - target: 0.70
# treated_target_rpu: 28.07
# treated_target_nipu: -3.09
# nontreated_target_rpu: 23.43
# nontreated_target_nipu: 2.25
# treated_nontarget_rpu: 35.63
# treated_nontarget_nipu: -0.26
# nontreated_nontarget_rpu: 34.03
# nontreated_nontarget_nipu: 4.37
# --- with 69.9918223237581% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.151488834942349
# --> in non-targeted users:
# cpit = 2.8828632338543114
# rpu_control: 26.61
# nipu_control: 2.89
# rpu_ft: 30.33
# nipu_ft: -2.24
# rpu_cohort: 29.85
# nipu_cohort: -0.85
# lift targeted cohort vs control: 0.12
# lift random vs control: 0.14
# cpit cohort vs control: 1.15
# lift targeted-treated vs control: 0.05
# cpit cohort: 1.151939
# ---------------------------->>>>>>
# perc - target: 0.80
# treated_target_rpu: 28.63
# treated_target_nipu: -2.71
# nontreated_target_rpu: 24.17
# nontreated_target_nipu: 2.46
# treated_nontarget_rpu: 37.05
# treated_nontarget_nipu: -0.38
# nontreated_nontarget_rpu: 36.41
# nontreated_nontarget_nipu: 4.59
# --- with 79.99065408429496% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.1571450193391393
# --> in non-targeted users:
# cpit = 7.765924226797814
# rpu_control: 26.61
# nipu_control: 2.89
# rpu_ft: 30.33
# nipu_ft: -2.24
# rpu_cohort: 30.19
# nipu_cohort: -1.25
# lift targeted cohort vs control: 0.13
# lift random vs control: 0.14
# cpit cohort vs control: 1.16
# lift targeted-treated vs control: 0.08
# cpit cohort: 1.155378
# ---------------------------->>>>>>
# perc - target: 0.90
# treated_target_rpu: 29.34
# treated_target_nipu: -2.44
# nontreated_target_rpu: 25.01
# nontreated_target_nipu: 2.63
# treated_nontarget_rpu: 39.23
# treated_nontarget_nipu: -0.44
# nontreated_nontarget_rpu: 41.02
# nontreated_nontarget_nipu: 5.17
# --- with 89.98948584483185% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.170535170704776
# --> in non-targeted users:
# cpit = -3.1302485054787583
# rpu_control: 26.61
# nipu_control: 2.89
# rpu_ft: 30.33
# nipu_ft: -2.24
# rpu_cohort: 30.51
# nipu_cohort: -1.68
# lift targeted cohort vs control: 0.15
# lift random vs control: 0.14
# cpit cohort vs control: 1.17
# lift targeted-treated vs control: 0.10
# cpit cohort: 1.170325
# rpu_cohort
# 30.51018018488046
# treated_target_rpu
# 30.3367782693373
# ---------------------------->>>>>>
# perc - target: 1.00
# treated_target_rpu: 30.34
# treated_target_nipu: -2.24
# nontreated_target_rpu: 26.61
# nontreated_target_nipu: 2.89
# treated_nontarget_rpu: 0.00
# treated_nontarget_nipu: 0.00
# nontreated_nontarget_rpu: 0.00
# nontreated_nontarget_nipu: 0.00
# --- with 99.9883176053687% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.3767165281806446
# --> in non-targeted users:
# cpit = nan
# rpu_control: 26.61
# nipu_control: 2.89
# rpu_ft: 30.33
# nipu_ft: -2.24
# rpu_cohort: 30.34
# nipu_cohort: -2.24
# lift targeted cohort vs control: 0.14
# lift random vs control: 0.14
# cpit cohort vs control: 1.38
# lift targeted-treated vs control: 0.14
# cpit cohort: 1.375540
# rpu_control: 26.61023324389618
# nipu_control: 2.885016801184031
# rpu_ft: 30.33242297850836
# nipu_ft: -2.2406735439480148
# ../experimentation.py:154: RuntimeWarning: invalid value encountered in double_scalars
#   cpit_nontargeted = -1.0 * (treated_untarget_nipu - untreated_untarget_nipu) / (treated_untarget_rpu - untreated_untarget_rpu)
# ---------------------------->>>>>>
# perc - target: 0.10
# treated_target_rpu: 44.72
# treated_target_nipu: -19.06
# nontreated_target_rpu: 34.08
# nontreated_target_nipu: 3.33
# treated_nontarget_rpu: 28.73
# treated_nontarget_nipu: -0.36
# nontreated_nontarget_rpu: 25.78
# nontreated_nontarget_nipu: 2.84
# --- with 9.99883176053687% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 2.105451205657852
# --> in non-targeted users:
# cpit = 1.0858225994081574
# rpu_control: 26.61
# nipu_control: 2.89
# rpu_ft: 30.33
# nipu_ft: -2.24
# rpu_cohort: 27.67
# nipu_cohort: 0.65
# lift targeted cohort vs control: 0.04
# lift random vs control: 0.14
# cpit cohort vs control: 2.10
# lift targeted-treated vs control: 0.68
# cpit cohort: 2.103828
# ---------------------------->>>>>>
# perc - target: 0.20
# treated_target_rpu: 39.16
# treated_target_nipu: -9.94
# nontreated_target_rpu: 31.45
# nontreated_target_nipu: 3.20
# treated_nontarget_rpu: 28.15
# treated_nontarget_nipu: -0.34
# nontreated_nontarget_rpu: 25.40
# nontreated_nontarget_nipu: 2.81
# --- with 19.99766352107374% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.7033269445415193
# --> in non-targeted users:
# cpit = 1.142851717371936
# rpu_control: 26.61
# nipu_control: 2.89
# rpu_ft: 30.33
# nipu_ft: -2.24
# rpu_cohort: 28.15
# nipu_cohort: 0.26
# lift targeted cohort vs control: 0.06
# lift random vs control: 0.14
# cpit cohort vs control: 1.71
# lift targeted-treated vs control: 0.47
# cpit cohort: 1.705846
# ---------------------------->>>>>>
# perc - target: 0.30
# treated_target_rpu: 36.44
# treated_target_nipu: -6.75
# nontreated_target_rpu: 29.44
# nontreated_target_nipu: 2.91
# treated_nontarget_rpu: 27.75
# treated_nontarget_nipu: -0.33
# nontreated_nontarget_rpu: 25.39
# nontreated_nontarget_nipu: 2.87
# --- with 29.996495281610613% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.380508630236875
# --> in non-targeted users:
# cpit = 1.3614879096251105
# rpu_control: 26.61
# nipu_control: 2.89
# rpu_ft: 30.33
# nipu_ft: -2.24
# rpu_cohort: 28.71
# nipu_cohort: -0.01
# lift targeted cohort vs control: 0.08
# lift random vs control: 0.14
# cpit cohort vs control: 1.38
# lift targeted-treated vs control: 0.37
# cpit cohort: 1.382119
# ---------------------------->>>>>>
# perc - target: 0.40
# treated_target_rpu: 34.24
# treated_target_nipu: -5.23
# nontreated_target_rpu: 28.23
# nontreated_target_nipu: 2.93
# treated_nontarget_rpu: 27.78
# treated_nontarget_nipu: -0.29
# nontreated_nontarget_rpu: 25.53
# nontreated_nontarget_nipu: 2.85
# --- with 39.99532704214748% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.3571727368748883
# --> in non-targeted users:
# cpit = 1.3954845624956336
# rpu_control: 26.61
# nipu_control: 2.89
# rpu_ft: 30.33
# nipu_ft: -2.24
# rpu_cohort: 29.01
# nipu_cohort: -0.38
# lift targeted cohort vs control: 0.09
# lift random vs control: 0.14
# cpit cohort vs control: 1.36
# lift targeted-treated vs control: 0.29
# cpit cohort: 1.358820
# ---------------------------->>>>>>
# perc - target: 0.50
# treated_target_rpu: 31.30
# treated_target_nipu: -4.15
# nontreated_target_rpu: 26.05
# nontreated_target_nipu: 2.77
# treated_nontarget_rpu: 29.39
# treated_nontarget_nipu: -0.39
# nontreated_nontarget_rpu: 27.17
# nontreated_nontarget_nipu: 3.00
# --- with 49.99415880268435% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.3182927615709175
# --> in non-targeted users:
# cpit = 1.5254092941772002
# rpu_control: 26.61
# nipu_control: 2.89
# rpu_ft: 30.33
# nipu_ft: -2.24
# rpu_cohort: 29.24
# nipu_cohort: -0.57
# lift targeted cohort vs control: 0.10
# lift random vs control: 0.14
# cpit cohort vs control: 1.32
# lift targeted-treated vs control: 0.18
# cpit cohort: 1.317331
# ---------------------------->>>>>>
# perc - target: 0.60
# treated_target_rpu: 30.25
# treated_target_nipu: -3.47
# nontreated_target_rpu: 25.40
# nontreated_target_nipu: 2.73
# treated_nontarget_rpu: 30.46
# treated_nontarget_nipu: -0.39
# nontreated_nontarget_rpu: 28.42
# nontreated_nontarget_nipu: 3.11
# --- with 59.99299056322123% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.2799677930526827
# --> in non-targeted users:
# cpit = 1.7241697513887384
# rpu_control: 26.61
# nipu_control: 2.89
# rpu_ft: 30.33
# nipu_ft: -2.24
# rpu_cohort: 29.52
# nipu_cohort: -0.84
# lift targeted cohort vs control: 0.11
# lift random vs control: 0.14
# cpit cohort vs control: 1.28
# lift targeted-treated vs control: 0.14
# cpit cohort: 1.279953
# ---------------------------->>>>>>
# perc - target: 0.70
# treated_target_rpu: 30.20
# treated_target_nipu: -2.97
# nontreated_target_rpu: 25.71
# nontreated_target_nipu: 2.77
# treated_nontarget_rpu: 30.65
# treated_nontarget_nipu: -0.52
# nontreated_nontarget_rpu: 28.71
# nontreated_nontarget_nipu: 3.16
# --- with 69.9918223237581% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.2778994586678947
# --> in non-targeted users:
# cpit = 1.9013663354760262
# rpu_control: 26.61
# nipu_control: 2.89
# rpu_ft: 30.33
# nipu_ft: -2.24
# rpu_cohort: 29.75
# nipu_cohort: -1.13
# lift targeted cohort vs control: 0.12
# lift random vs control: 0.14
# cpit cohort vs control: 1.28
# lift targeted-treated vs control: 0.13
# cpit cohort: 1.278443
# ---------------------------->>>>>>
# perc - target: 0.80
# treated_target_rpu: 30.34
# treated_target_nipu: -2.69
# nontreated_target_rpu: 25.96
# nontreated_target_nipu: 2.74
# treated_nontarget_rpu: 30.31
# treated_nontarget_nipu: -0.44
# nontreated_nontarget_rpu: 29.19
# nontreated_nontarget_nipu: 3.48
# --- with 79.99065408429496% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.2415439660160674
# --> in non-targeted users:
# cpit = 3.504211951486467
# rpu_control: 26.61
# nipu_control: 2.89
# rpu_ft: 30.33
# nipu_ft: -2.24
# rpu_cohort: 30.11
# nipu_cohort: -1.46
# lift targeted cohort vs control: 0.13
# lift random vs control: 0.14
# cpit cohort vs control: 1.24
# lift targeted-treated vs control: 0.14
# cpit cohort: 1.241339
# ---------------------------->>>>>>
# perc - target: 0.90
# treated_target_rpu: 30.53
# treated_target_nipu: -2.40
# nontreated_target_rpu: 26.28
# nontreated_target_nipu: 2.83
# treated_nontarget_rpu: 28.54
# treated_nontarget_nipu: -0.83
# nontreated_nontarget_rpu: 29.61
# nontreated_nontarget_nipu: 3.42
# --- with 89.98948584483185% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.2273838407155482
# --> in non-targeted users:
# cpit = -3.9303308526671676
# rpu_control: 26.61
# nipu_control: 2.89
# rpu_ft: 30.33
# nipu_ft: -2.24
# rpu_cohort: 30.44
# nipu_cohort: -1.82
# lift targeted cohort vs control: 0.14
# lift random vs control: 0.14
# cpit cohort vs control: 1.23
# lift targeted-treated vs control: 0.15
# cpit cohort: 1.227375
# rpu_cohort
# 30.440506019416638
# treated_target_rpu
# 30.3367782693373
# ---------------------------->>>>>>
# perc - target: 1.00
# treated_target_rpu: 30.34
# treated_target_nipu: -2.24
# nontreated_target_rpu: 26.61
# nontreated_target_nipu: 2.89
# treated_nontarget_rpu: 0.00
# treated_nontarget_nipu: 0.00
# nontreated_nontarget_rpu: 10.05
# nontreated_nontarget_nipu: 1.85
# --- with 99.9883176053687% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.3762494811760453
# --> in non-targeted users:
# cpit = -0.18386576769974408
# rpu_control: 26.61
# nipu_control: 2.89
# rpu_ft: 30.33
# nipu_ft: -2.24
# rpu_cohort: 30.34
# nipu_cohort: -2.24
# lift targeted cohort vs control: 0.14
# lift random vs control: 0.14
# cpit cohort vs control: 1.38
# lift targeted-treated vs control: 0.14
# cpit cohort: 1.375540
# temp:
# 2.530116884855698
# p_quantile:
# 0.4
# AUCC results:
# random: [0.5]
# rlearner: [0.44382805]
# duality rlearner 1 with lambda = 0.1:[0.43621483]
# drm: [0.46578618]
# tqr: [0.46309274]
