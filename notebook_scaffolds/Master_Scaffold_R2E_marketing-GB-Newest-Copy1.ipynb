# %%
import pandas as pd, numpy as np, cPickle as pkl 
import sys, os 
sys.path.append('../dataprep/') 
sys.path.append('../models/') 
from QueryFunctions import * 
import tensorflow as tf

# %%
use_query = 0 ### turn this switch on (to 1.0/True vs 0.0/False) to run query using QueryRunner 

if use_query: 
    from queryrunner_client import Client 
    qr = Client(user_email='will.zou@uber.com') 
    
    predFrame2 = qr.execute('presto', r2e_data_sapphire_presto()) 
    predFrame2 = pd.DataFrame(predFrame2.load_data()) 
else: 
    predFrame2 = pd.read_csv('../data/r2e_data_marketing_kdd_paper_gb_data.csv') 

""" 
label_dates_weekly = "'2019-07-07','2019-06-30','2019-06-23','2019-06-16'"
city_ids = '1,5,6,8,10,12,20,23,198' 
feature_dates="'2019-06-02'" 
proposal_start_date = '2019-06-10' 

predFrame = qr.execute('presto', rxgy_data_sapphire_presto_featuremod2(label_dates_weekly, feature_dates,  city_ids)) 
predFrame = pd.DataFrame(predFrame.load_data()) 
""" 

""" 
label_dates_weekly = "'2019-08-11', '2019-08-18', '2019-08-25', '2019-09-01'" 
city_ids = '1,5,6,8,10,12,20,23,198' 
feature_dates="'2019-07-28'" 
proposal_start_date = '2019-08-05' 

predFrame3 = qr.execute('presto', rxgy_data_sapphire_presto_featuremod2(label_dates_weekly, feature_dates,  city_ids)) 
predFrame3 = pd.DataFrame(predFrame3.load_data()) 
""" 

"""
label_dates_weekly = "'2019-10-06', '2019-10-13', '2019-10-20', '2019-10-27'" 
city_ids = '1,5,6,8,10,12,20,23,198' 
feature_dates="'2019-09-22'" 
proposal_start_date = '2019-09-30' 

predFrame4 = qr.execute('presto', rxgy_data_sapphire_presto_featuremod2(label_dates_weekly, feature_dates,  city_ids)) 
predFrame4 = pd.DataFrame(predFrame4.load_data()) 
"""
# Out:
# '\nlabel_dates_weekly = "\'2019-10-06\', \'2019-10-13\', \'2019-10-20\', \'2019-10-27\'" \ncity_ids = \'1,5,6,8,10,12,20,23,198\' \nfeature_dates="\'2019-09-22\'" \nproposal_start_date = \'2019-09-30\' \n\npredFrame4 = qr.execute(\'presto\', rxgy_data_sapphire_presto_featuremod2(label_dates_weekly, feature_dates,  city_ids)) \npredFrame4 = pd.DataFrame(predFrame4.load_data()) \n'

# %%
cohort_column_name = 'cohort' 
treatment_indicator_value = 'treatment' 
control_indicator_value = 'control' 

print(len(predFrame2))
print(sum(predFrame2[cohort_column_name] == control_indicator_value))
predFrame2.to_csv('../data/r2e_data_marketing_kdd_paper_gb_data.csv')
# Out:
# 1068726
# 368384

# %%
predFrame2
# Out:
#          Unnamed: 0  Unnamed: 0.1  ata_trip_max_avg_84d  churns_hard_lifetime  \
# 0                 0             0            113.000000                   1.0
# 1                 1             1            272.500000                   3.0
# 2                 2             2            198.214286                   2.0
# 3                 3             3            173.450000                   0.0
# 4                 4             4            166.083333                   1.0
# 5                 5             5            260.500000                   1.0
# 6                 6             6            231.666667                   1.0
# 7                 7             7            161.000000                   1.0
# 8                 8             8            208.666667                   5.0
# 9                 9             9            273.250000                   1.0
# 23                        5.0  treatment              4.0
# 24                        7.0  treatment              8.0
# 25                        4.0  treatment             27.0
# 26                        6.0  treatment              5.0
# 27                        6.0  treatment             13.0
# 28                        NaN  treatment              NaN
# 29                        1.0  treatment              7.0
# ...                       ...        ...              ...
# 1068696                   3.0    control             21.0
# 1068697                   0.0    control              4.0
# 1068698                   6.0    control              4.0
# 1068699                   NaN    control              NaN
# 1068700                   0.0    control              1.0
# 1068701                   0.0    control              6.0
# 1068702                   4.0    control              1.0
# 1068703                   8.0    control              2.0
# 1068704                   7.0    control              3.0
# 1068705                   3.0    control              2.0
# 1068706                   0.0    control             53.0
# 1068707                   3.0    control              1.0
# 1068708                   0.0    control              2.0
# 1068709                   8.0    control              6.0
# 1068710                   1.0    control              1.0
# 1068711                   9.0    control              2.0
# 1068712                   6.0    control              3.0
# 1068713                   6.0    control              1.0
# 1068714                   1.0    control              2.0
# 1068715                   8.0    control              4.0
# 1068716                   2.0    control              2.0
# 1068717                   3.0    control              8.0
# 1068718                  18.0    control              4.0
# 1068719                   2.0    control              4.0
# 1068720                   2.0    control              1.0
# 1068721                   1.0    control             11.0
# 1068722                   0.0    control              1.0
# 1068723                   0.0    control              1.0
# 1068724                   0.0    control              5.0
# 1068725                   1.0    control              1.0
#
#          days_since_last_hard_churn_lifetime  \
# 0                                      641.0
# 1                                      196.0
# 2                                      899.0
# 3                                      918.0
# 4                                      953.0
# 5                                      293.0
# 6                                      503.0
# 7                                      997.0
# 8                                      239.0
# 9                                      377.0
# 10                                     296.0
# 11                                     184.0
# 12                                      60.0
# 13                                      89.0
# 14                                     357.0
# 15                                     647.0
# 16                                     524.0
# 17                                     555.0
# 18                                     295.0
# 19                                     567.0
# 20                                      74.0
# 21                                     122.0
# 22                                      51.0
# 23                                     382.0
# 24                                     540.0
# 25                                     919.0
# 26                                     578.0
# 27                                    1037.0
# 28                                       NaN
# 29                                     127.0
# ...                                      ...
# 1068696                                202.0
# 1068697                                 26.0
# 1068698                                618.0
# 1068699                                  NaN
# 1068700                                 10.0
# 1068701                                909.0
# 1068702                                 78.0
# 1068703                                318.0
# 1068704                                802.0
# 1068705                                279.0
# 1068706                                244.0
# 1068707                                 28.0
# 1068708                                  8.0
# 1068709                                 60.0
# 1068710                                100.0
# 1068711                                126.0
# 1068712                                529.0
# 1068713                                327.0
# 1068714                                 99.0
# 1068715                                153.0
# 1068716                                 58.0
# 1068717                                762.0
# 1068718                               1175.0
# 1068719                                115.0
# 1068720                                236.0
# 1068721                                 85.0
# 1068722                                178.0
# 1068723                                 13.0
# 1068724                                 35.0
# 1068725                                217.0
#
#          days_since_last_soft_churn_lifetime  days_since_trip_first_lifetime  \
# 0                                       40.0                           725.0
# 1                                       17.0                          1021.0
# 2                                      224.0                          1440.0
# 3                                      405.0                           918.0
# 4                                     1047.0                          1047.0
# 5                                        0.0                           797.0
# 6                                       41.0                           672.0
# 7                                       50.0                          1100.0
# 8                                       46.0                          1011.0
# 9                                        0.0                          1016.0
# 10                                      36.0                           493.0
# 1068704  4391eead-bae6-45c8-9307-137742f5e101
# 1068705  20202959-8005-469c-8c72-adf24bf87356
# 1068706  fbebc154-7165-4b15-8376-d61766d46828
# 1068707  023b1f83-909e-4520-b7ff-f242ebf57c65
# 1068708  478ddd49-750b-4ab2-b778-b7dffb0000be
# 1068709  c9124fc2-0348-463b-a20d-b394a6ab11f7
# 1068710  8fa3a74d-d9aa-447c-960a-072fe44d32bb
# 1068711  4165f41d-fa37-4b93-aedf-dbbf564cde7c
# 1068712  b4e75f35-2762-4b2b-a584-2f313672562c
# 1068713  64496eee-2eb5-4065-a682-94a28ddedc5e
# 1068714  834d0145-08ae-4cf8-bf56-996010516632
# 1068715  0dbb7cb8-312b-4f20-bfb8-11ef36d055f4
# 1068716  dec851ab-d314-4ac2-a9ad-e89be964d851
# 1068717  68440cd4-f24a-47c8-ba52-bc362099bc2f
# 1068718  ee459d97-31d5-4104-9c8c-be6fdc1ba564
# 1068719  d79bc1b5-81e5-4fbe-938c-baef8b2e8006
# 1068720  28c2924a-48a0-4297-80a3-cc25e72cdced
# 1068721  590c538c-4ad0-4df4-8831-5fa3fa20d7f2
# 1068722  fe13ffcb-9661-4226-b893-debdb11bc67e
# 1068723  3c4b299a-751d-4894-b7d2-d17f23f2563c
# 1068724  16c1dbaa-4d22-42ea-b548-d1ababe0cae6
# 1068725  c0d0762b-ce1d-49e9-b1a7-c1045f9740e0
#
# [1068726 rows x 47 columns]

# %%
### preprocess the data 
### -- sample treatment to match control cohort 
### -- eliminate nulls, standard normalization 

D = predFrame2 
D = D.sample(frac=1.0) 

feature_list = [ 
    'rating_2driver_min_avg_84d'
    , 'trip_incomplete_total_84d'
    , 'days_active_84d'
    , 'days_since_trip_first_lifetime'
    , 'days_since_last_hard_churn_lifetime'
    , 'days_since_last_soft_churn_lifetime'
    , 'fare_max_sd_84d'
    , 'churns_hard_lifetime'
    , 'trips_lifetime'
    , 'fare_max_p50_84d'
    , 'duration_session_pre_request_max_p50_84d'
    , 'trip_pool_per_x_84d'
    , 'fare_total_win7d_sd_84d'
    , 'trip_complete_win7d_sd_84d'
    , 'session_per_days_active_84d'
    , 'churns_soft_lifetime'
    , 'trip_complete_per_days_active_84d'
    , 'trip_pool_prc_84d'
    , 'session_background_pre_request_prc_84d'
    , 'session_lt_1m_prc_84d'
    , 'session_request_prc_84d'
    , 'duration_session_outside_total_prc_84d'
    , 'trip_x_prc_84d'
    , 'days_since_trip_last_lifetime'
    , 'has_session_request_84d'
    , 'has_session_without_request_84d'
    , 'promo_used_84d' 
    , 'fare_promo_total_avg_84d', 
    'fare_total_avg_84d', 
    'surge_trip_avg_84d', 
    'fare_total_win7d_potential_84d', 
    'fare_total_win28d_potential_84d', 
    'fare_lifetime', 
    'time_to_first_message_minutes_mean_lifetime', 
    'ata_trip_max_avg_84d', 
    'eta_trip_max_avg_84d', 
    'trip_pool_matched_avg_84d', 
    'payment_cash_trip_total_84d', 
    'duration_trip_total_p50_84d' 
] 

label_list = [ 
    'manual_apply_gb', 
    'manual_apply_ni' 
] 

for l in feature_list: 
    print('number of nans: ' + str(sum(D[l] == '\N'))) 
    D[l] = pd.to_numeric(D[l], errors='coerce') 
    D[l] = D[l] - D[l].mean() 
    D[l] = D[l] / D[l].std() 
    D[l][pd.isnull(D[l])] = 0.0 ## at zero mean due to standard normalization 

for l in label_list: 
    D[l] = pd.to_numeric(D[l], errors='coerce') 
    D[l][pd.isnull(D[l])] = 0.0 ## at zero mean due to standard normalization 

### -- compute simple statistics 
### compute cpit 
treated_entries = D[D[cohort_column_name] == treatment_indicator_value] 
untreated_entries = D[D[cohort_column_name] == control_indicator_value] 

rpu_treated = float(treated_entries[label_list[0]].sum()) / len(treated_entries) 
nipu_treated = float(treated_entries[label_list[1]].sum()) / len(treated_entries) 

rpu_untreated = float(untreated_entries[label_list[0]].sum()) / len(untreated_entries) 
nipu_untreated = float(untreated_entries[label_list[1]].sum()) / len(untreated_entries) 

cpit = -1.0 * (nipu_treated - nipu_untreated) / (rpu_treated - rpu_untreated) 

print('rpu_treated : ' + str(rpu_treated)) 
print('nipu_treated : ' + str(nipu_treated)) 
print('rpu_untreated : ' + str(rpu_untreated)) 
print('nipu_untreated : ' + str(nipu_untreated)) 
print('cpit : ' + str(cpit)) 

### split the data into 3/1/1 train/val/test 
len_tr = len(D) / 5 * 3 
len_va = len(D) / 5 

nX = D[feature_list].as_matrix() 
w = D[cohort_column_name].apply(lambda x: 1.0 if x == treatment_indicator_value else 0.0) 
w = w.as_matrix() 
values = D[label_list[0]] 
values = values.as_matrix() * 1.0 
negcost = D[label_list[1]] 
negcost = negcost.as_matrix() * 1.0 

## split train/val/test sets 

nX_tr = nX[0:len_tr, :] 
nX_va = nX[len_tr:len_tr + len_va, :] 
nX_te = nX[len_tr + len_va:, :] 

w_tr = w[0:len_tr]
w_va = w[len_tr:len_tr + len_va] 
w_te = w[len_tr + len_va:] 

values_tr = values[0:len_tr] 
values_va = values[len_tr:len_tr + len_va] 
values_te = values[len_tr + len_va:] 

negcost_tr = negcost[0:len_tr] 

negcost_va = negcost[len_tr:len_tr + len_va] 

negcost_te = negcost[len_tr + len_va:] 

## saving data using cPickel and naming the dictionaries 
saveD = {'nX_tr':nX_tr, 
         'w_tr':w_tr, 
         'values_tr':values_tr, 
         'nX_va':nX_va, 
         'w_va':w_va, 
         'values_va':values_va, 
         'nX_te':nX_te, 
         'w_te':w_te, 
         'values_te':values_te, 
         'feature_list':feature_list, 
         #'avg_ni_usd_tr':avg_ni_usd_tr, 
         'negcost_tr': negcost_tr, 
         #'avg_ni_usd_va':avg_ni_usd_va, 
         'negcost_va': negcost_va, 
         #'avg_ni_usd_te':avg_ni_usd_te, 
         'negcost_te': negcost_te 
         } 

pkl.dump(saveD, open('../data/r2e_ma_training_data_v5_2019_07_08_vc_tr_featuremod3', 'w'))
# Out:
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# /usr/local/lib/python2.7/site-packages/ipykernel_launcher.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# number of nans: 0
# number of nans: 0
# number of nans: 0
# number of nans: 0
# number of nans: 0
# number of nans: 0
# number of nans: 0
# number of nans: 0
# number of nans: 0
# number of nans: 0
# number of nans: 0
# number of nans: 0
# number of nans: 0
# number of nans: 0
# number of nans: 0
# number of nans: 0
# number of nans: 0
# number of nans: 0
# number of nans: 0
# number of nans: 0
# number of nans: 0
# number of nans: 0
# number of nans: 0
# number of nans: 0
# number of nans: 0
# number of nans: 0
# number of nans: 0
# number of nans: 0
# number of nans: 0
# number of nans: 0
# number of nans: 0
# number of nans: 0
# number of nans: 0
# number of nans: 0
# number of nans: 0
# number of nans: 0
# number of nans: 0
# number of nans: 0
# number of nans: 0
# /usr/local/lib/python2.7/site-packages/ipykernel_launcher.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# rpu_treated : 0.26086751875
# nipu_treated : -0.186934646608
# rpu_untreated : 0.167524995575
# nipu_untreated : -0.0599816763466
# cpit : 1.360076479
# /usr/local/lib/python2.7/site-packages/ipykernel_launcher.py:89: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# /usr/local/lib/python2.7/site-packages/ipykernel_launcher.py:91: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# /usr/local/lib/python2.7/site-packages/ipykernel_launcher.py:93: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# /usr/local/lib/python2.7/site-packages/ipykernel_launcher.py:95: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.

# %%
sum(predFrame2['manual_apply_orders'] > 0)
# Out:
# 37209

# %%
### code implements ranking model for treatment effect 
### for optimizing with respect to direct marketplace objectives 
### using tensorflow 

import numpy as np, tensorflow as tf, pandas as pd, pickle as pkl 
sys.path.append('../')  
from ModelDefinitions import * 
from DataProcFunctions import * 

### RxGy TQR setting: 
p_quantile = 0.3 ## percentage of quantile to aim for 
num_optimize_iterations = 2500 ## number of optimization iterations 
num_modeling_inits = 3 ## number of random initializations 
num_hidden = 0 ## number of hidden units in DNN 
use_schedule = True ## option to use a constraint annealing schedule 
temp = 0.5 ## initial temperature for constraints 
inc_temp = 0.1 ## increment of temperature per 100 iterations 
save_cf_data = False ### whether to save data for causal forest training 

## set a random seed to reproduce results 
seed = 1234; tf.compat.v2.random.set_seed(seed); np.random.seed(seed) 

sample_frac = 1.0 ## option to sample data by a fraction \in (0, 1) 
data_filename =  '../data/r2e_ma_training_data_v5_2019_07_08_vc_tr_featuremod3' 
prefix = 'r2e_v5_07_08_featuremod3_tr_iter100_run4' 

D_tre, D_unt, Dv_tre, Dv_unt, Dt_tre, Dt_unt, o_tre, o_unt, ov_tre, ov_unt, ot_tre, ot_unt, c_tre, c_unt, cv_tre, cv_unt, ct_tre, ct_unt, D, w, o, c, Dv, wv, ov, cv, Dt, wt, ot, ct = LoadDataFromPkl(data_filename, frac = sample_frac, save_cf_data=save_cf_data) 

print('### ----- start the training of deep learning models ------ ') 
gs_tqr = [] 
gs_drm = [] 
for i in range(num_modeling_inits): 
    gs_tqr.append(tf.Graph()) 
for i in range(num_modeling_inits): 
    gs_drm.append(tf.Graph()) 

print('------> Training TQR ranking model .... ') 
val_results = [] 
sess_list = [] 
for i in range(num_modeling_inits): 
    print('---> running cross validation, iteration: ' + str(i)) 
    obj, opt, dumh, dumhu, vtemp, p_quantile = TunableTQRankingModelDNN(gs_tqr[i], D_tre, D_unt, o_tre, o_unt, c_tre, c_unt, 'train-first', temp, p_quantile, num_hidden, use_schedule) 
    ### session definitions and variable initialization 
    sess = tf.Session(graph = gs_tqr[i]) 
    sess_list.append(sess) 
    
    ### initialize variables and run optimization 
    with gs_tqr[i].as_default() as g: 
        init = tf.global_variables_initializer() 
    sess.run(init) 
    cur_temp = temp 
    for step in range(num_optimize_iterations): 
        _, objres = sess.run([opt, obj]) 
        if step % 100 == 0: 
            cur_temp = cur_temp + inc_temp 
            print('opt. step : ' + str(step) + ' obj: ' + str(objres)) 
            if use_schedule: 
                sess.run(vtemp.assign(cur_temp))
                print('setting temperature to :' + str(sess.run(vtemp))) 
    
    print('---> optimization finished ... ') 
    tempvalue = sess.run(vtemp)
    p_quantilevalue = p_quantile
    print('temp:') 
    print(tempvalue)
    print('p_quantile:')
    print(p_quantilevalue) 
    
    ### evaluate CPIT metric on validation set 
    objv, dumo, dumh, dumhu, dvtemp, dp_quantile = TunableTQRankingModelDNN(gs_tqr[i], Dv_tre, Dv_unt, ov_tre, ov_unt, cv_tre, cv_unt, 'eval', temp, p_quantile, num_hidden, use_schedule) 
    
    val_result = sess.run(objv) 
    print('validation CPIT:') 
    print(val_result) 
    val_results.append(val_result) 

from operator import itemgetter 
best_index = min(enumerate(val_results), key=itemgetter(1))[0] 

print('best performing model: iteration ' + str(best_index)) 

### run scoring on whole test set 
with gs_tqr[best_index].as_default() as g: 
    if num_hidden > 0: 
        with tf.variable_scope("tqrhidden") as scope: 
            h1_test = tf.contrib.layers.fully_connected(Dt, num_hidden, activation_fn=tf.nn.tanh, reuse=tf.AUTO_REUSE, scope=scope, weights_initializer=tf.contrib.layers.xavier_initializer()) 
        with tf.variable_scope("tqranker") as scope: 
            h_test = tf.contrib.layers.fully_connected(h1_test, 1, activation_fn=None, reuse=tf.AUTO_REUSE, scope=scope) 
    else: 
        with tf.variable_scope("tqranker") as scope: 
            h_test = tf.contrib.layers.fully_connected(Dt, 1, activation_fn=None, reuse=tf.AUTO_REUSE, scope=scope) 
    tqrscore = sess_list[best_index].run(h_test) 

print('------> Training DRM ranking model .... ') 
sess_list = [] 
val_results = [] 
for i in range(num_modeling_inits): 
    print('---> running cross validation, iteration: ' + str(i)) 
    ### ---- train cpit ranking model for comparison --- 
    dobjc, doptc, ddumh, ddumu = DirectRankingModelDNN(gs_drm[i], D_tre, D_unt, o_tre, o_unt, c_tre, c_unt, 'train-first-drm', num_hidden) 
    
    dsess = tf.Session(graph = gs_drm[i]) 
    sess_list.append(dsess) 
    
    ### initialize variables and run optimization 
    with gs_drm[i].as_default() as g: 
        dinit = tf.global_variables_initializer() 
    dsess.run(dinit) 
    for step in range(num_optimize_iterations): 
        _, dobjres = dsess.run([doptc, dobjc]) 
        if step % 100 == 0: 
            print('opt. step : ' + str(step) + ' obj: ' + str(dobjres)) 
    
    print('---> optimization finished ... ') 
    
    ### evaluate CPIT metric on validation set 
    dobjv, ddumo, dumh, dumhu = DirectRankingModelDNN(gs_drm[i], Dv_tre, Dv_unt, ov_tre, ov_unt, cv_tre, cv_unt, 'eval', num_hidden)
    val_result = dsess.run(dobjv) 
    print('validation CPIT:') 
    print(val_result) 
    val_results.append(val_result) 

best_index = min(enumerate(val_results), key=itemgetter(1))[0] 

print('best performing model: iteration ' + str(best_index)) 

### run scoring on whole test set 
with gs_drm[best_index].as_default() as g: 
    if num_hidden > 0: 
        with tf.variable_scope("drmhidden") as scope: 
            h1_test = tf.contrib.layers.fully_connected(Dt, num_hidden, activation_fn=tf.nn.tanh, reuse=tf.AUTO_REUSE, scope=scope, weights_initializer=tf.contrib.layers.xavier_initializer()) 
        with tf.variable_scope("drmranker") as scope: 
            h_test = tf.contrib.layers.fully_connected(h1_test, 1, activation_fn=tf.nn.tanh, reuse=tf.AUTO_REUSE, scope=scope) 
    else: 
        with tf.variable_scope("drmranker") as scope: 
            h_test = tf.contrib.layers.fully_connected(Dt, 1, activation_fn=tf.nn.tanh, reuse=tf.AUTO_REUSE, scope=scope) 
    drmscore = sess_list[best_index].run(h_test) 

### ---- train hte model for comparison ---- 
### we could utimize the original HTE functions 
from LinearHTEModels import * 
from PromotionModels import PromotionModels 

pmodels = PromotionModels() 

## set-up RLearner 
rl_ridge_model_O, rl_ridge_model_C = pmodels.fit_rlearner(D, o, c, w) 

## one model for order lift and one model for cost drop 
pred_values_va_rlearner_O = rl_ridge_model_O.predict(Dt) 
pred_values_va_rlearner_C = rl_ridge_model_C.predict(Dt) 

#if ranking_model == 'effectiveness-ratio': ## if we use the effectiveness ratio model, compute effectiveness ratio 
pred_values_va_rlearner = np.divide(np.maximum(pred_values_va_rlearner_O, 0), pred_values_va_rlearner_C + 1e-7) 

lhmodels = LinearHTEModels() 

""" 
### this section is to load the results trained by grf R code 
### 

ot_cf = pd.read_csv('../results/causal_forest_grf_test_set_results_O_finalsize_numtrees1002.csv') 
ct_cf = pd.read_csv('../results/causal_forest_grf_test_set_results_C_finalsize_numtrees1002.csv') 

ot_cf = ot_cf.as_matrix() 
Ocfscores = ot_cf[0] 

ct_cf = ct_cf.as_matrix() 
Ccfscores = ct_cf[0] 

cfscore = np.divide(Ocfscores, Ccfscores) 
"""
# Out:
# load data from ../data/r2e_ma_training_data_v5_2019_07_08_vc_tr_featuremod3
# printing averages of c_tr, c_unt, o_tre, o_unt ... :
# 0.18647950139733474
# 0.059344417733917056
# 0.26350167250553574
# 0.16672571985957996
# ### ----- start the training of deep learning models ------
# ------> Training TQR ranking model ....
# ---> running cross validation, iteration: 0
# WARNING:tensorflow:From ../models/ModelDefinitions.py:37: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From ../models/ModelDefinitions.py:37: The name tf.AUTO_REUSE is deprecated. Please use tf.compat.v1.AUTO_REUSE instead.
#
# WARNING:tensorflow:From ../models/ModelDefinitions.py:38: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x18ce25e90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x18ce25e90>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x18ce25e90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x18ce25e90>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x18ce25d90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x18ce25d90>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x18ce25d90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x18ce25d90>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:From ../models/ModelDefinitions.py:74: The name tf.ceil is deprecated. Please use tf.math.ceil instead.
#
# WARNING:tensorflow:From ../models/ModelDefinitions.py:115: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# opt. step : 0 obj: 1.3203600579677166
# setting temperature to :0.6
# opt. step : 100 obj: 1.2620279668513266
# setting temperature to :0.7
# opt. step : 200 obj: 1.2099494382869171
# setting temperature to :0.7999999999999999
# opt. step : 300 obj: 1.1774790783038385
# setting temperature to :0.8999999999999999
# opt. step : 400 obj: 1.1524747754136944
# setting temperature to :0.9999999999999999
# opt. step : 500 obj: 1.1329240414840736
# setting temperature to :1.0999999999999999
# opt. step : 600 obj: 1.1177510713199053
# setting temperature to :1.2
# opt. step : 700 obj: 1.1062922341224324
# setting temperature to :1.3
# opt. step : 800 obj: 1.0963501017446013
# setting temperature to :1.4000000000000001
# opt. step : 900 obj: 1.0875791209822177
# setting temperature to :1.5000000000000002
# opt. step : 1000 obj: 1.079586501263121
# setting temperature to :1.6000000000000003
# opt. step : 1100 obj: 1.0731437727441742
# setting temperature to :1.7000000000000004
# opt. step : 1200 obj: 1.067681166623892
# setting temperature to :1.8000000000000005
# opt. step : 1300 obj: 1.0626513365385575
# setting temperature to :1.9000000000000006
# opt. step : 1400 obj: 1.0580572315012158
# setting temperature to :2.0000000000000004
# opt. step : 1500 obj: 1.0538406122236843
# setting temperature to :2.1000000000000005
# opt. step : 1600 obj: 1.0498868719980314
# setting temperature to :2.2000000000000006
# opt. step : 1700 obj: 1.046241155851533
# setting temperature to :2.3000000000000007
# opt. step : 1800 obj: 1.0429113066429254
# setting temperature to :2.400000000000001
# opt. step : 1900 obj: 1.0399198845817557
# setting temperature to :2.500000000000001
# opt. step : 2000 obj: 1.0372283974359917
# setting temperature to :2.600000000000001
# opt. step : 2100 obj: 1.0346628571570675
# setting temperature to :2.700000000000001
# opt. step : 2200 obj: 1.0322261783248432
# setting temperature to :2.800000000000001
# opt. step : 2300 obj: 1.0300014429807536
# setting temperature to :2.9000000000000012
# opt. step : 2400 obj: 1.0279933060882798
# setting temperature to :3.0000000000000013
# ---> optimization finished ...
# temp:
# 3.042706930748449
# p_quantile:
# 0.3
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14ca18b50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14ca18b50>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14ca18b50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14ca18b50>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14ca18ad0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14ca18ad0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14ca18ad0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14ca18ad0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# validation CPIT:
# 1.7441854252125808
# ---> running cross validation, iteration: 1
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14cadf510>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14cadf510>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14cadf510>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14cadf510>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14cadf690>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14cadf690>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14cadf690>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14cadf690>>: AssertionError: Bad argument number for Name: 3, expecting 4
# opt. step : 0 obj: 1.3029328241750808
# setting temperature to :0.6
# opt. step : 100 obj: 1.246395813274495
# setting temperature to :0.7
# opt. step : 200 obj: 1.1983857806405642
# setting temperature to :0.7999999999999999
# opt. step : 300 obj: 1.1629377910963505
# setting temperature to :0.8999999999999999
# opt. step : 400 obj: 1.140465335260101
# setting temperature to :0.9999999999999999
# opt. step : 500 obj: 1.1236574023419477
# setting temperature to :1.0999999999999999
# opt. step : 600 obj: 1.11012245806746
# setting temperature to :1.2
# opt. step : 700 obj: 1.09931599732117
# setting temperature to :1.3
# opt. step : 800 obj: 1.0907307175794534
# setting temperature to :1.4000000000000001
# opt. step : 900 obj: 1.08296801961767
# setting temperature to :1.5000000000000002
# opt. step : 1000 obj: 1.0759924041726503
# setting temperature to :1.6000000000000003
# opt. step : 1100 obj: 1.0703120343514834
# setting temperature to :1.7000000000000004
# opt. step : 1200 obj: 1.065310740772281
# setting temperature to :1.8000000000000005
# opt. step : 1300 obj: 1.0606508503739898
# setting temperature to :1.9000000000000006
# opt. step : 1400 obj: 1.0562922923657194
# setting temperature to :2.0000000000000004
# opt. step : 1500 obj: 1.0522431451888354
# setting temperature to :2.1000000000000005
# opt. step : 1600 obj: 1.048536312599061
# setting temperature to :2.2000000000000006
# opt. step : 1700 obj: 1.0450679072041078
# setting temperature to :2.3000000000000007
# opt. step : 1800 obj: 1.0417338658151123
# setting temperature to :2.400000000000001
# opt. step : 1900 obj: 1.0384887650531418
# setting temperature to :2.500000000000001
# opt. step : 2000 obj: 1.035326397986949
# setting temperature to :2.600000000000001
# opt. step : 2100 obj: 1.032329123216505
# setting temperature to :2.700000000000001
# opt. step : 2200 obj: 1.0295110323007548
# setting temperature to :2.800000000000001
# opt. step : 2300 obj: 1.0268783043996
# setting temperature to :2.9000000000000012
# opt. step : 2400 obj: 1.0244200800111893
# setting temperature to :3.0000000000000013
# ---> optimization finished ...
# temp:
# 3.043392334315571
# p_quantile:
# 0.3
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14b3f2c90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14b3f2c90>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14b3f2c90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14b3f2c90>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14b3f2e50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14b3f2e50>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14b3f2e50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14b3f2e50>>: AssertionError: Bad argument number for Name: 3, expecting 4
# validation CPIT:
# 1.886654979862324
# ---> running cross validation, iteration: 2
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14b4b8450>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14b4b8450>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14b4b8450>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14b4b8450>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14b5c48d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14b5c48d0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14b5c48d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14b5c48d0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# opt. step : 0 obj: 1.2794023257272444
# setting temperature to :0.6
# opt. step : 100 obj: 1.2240152207693773
# setting temperature to :0.7
# opt. step : 200 obj: 1.1869532489798902
# setting temperature to :0.7999999999999999
# opt. step : 300 obj: 1.1598370429275446
# setting temperature to :0.8999999999999999
# opt. step : 400 obj: 1.1387223594844489
# setting temperature to :0.9999999999999999
# opt. step : 500 obj: 1.1200277784153332
# setting temperature to :1.0999999999999999
# opt. step : 600 obj: 1.1051862920167428
# setting temperature to :1.2
# opt. step : 700 obj: 1.0950831768123843
# setting temperature to :1.3
# opt. step : 800 obj: 1.0874655316186503
# setting temperature to :1.4000000000000001
# opt. step : 900 obj: 1.0811314307694417
# setting temperature to :1.5000000000000002
# opt. step : 1000 obj: 1.0756484473237888
# setting temperature to :1.6000000000000003
# opt. step : 1100 obj: 1.0708575778499516
# setting temperature to :1.7000000000000004
# opt. step : 1200 obj: 1.0665420245830728
# setting temperature to :1.8000000000000005
# opt. step : 1300 obj: 1.0625317269777868
# setting temperature to :1.9000000000000006
# opt. step : 1400 obj: 1.0587439375301073
# setting temperature to :2.0000000000000004
# opt. step : 1500 obj: 1.0551313115125547
# setting temperature to :2.1000000000000005
# opt. step : 1600 obj: 1.0512345950348525
# setting temperature to :2.2000000000000006
# opt. step : 1700 obj: 1.0470845767970411
# setting temperature to :2.3000000000000007
# opt. step : 1800 obj: 1.0433071355275407
# setting temperature to :2.400000000000001
# opt. step : 1900 obj: 1.0401247545784134
# setting temperature to :2.500000000000001
# opt. step : 2000 obj: 1.0373716052486521
# setting temperature to :2.600000000000001
# opt. step : 2100 obj: 1.0349304565884083
# setting temperature to :2.700000000000001
# opt. step : 2200 obj: 1.0326832528123082
# setting temperature to :2.800000000000001
# opt. step : 2300 obj: 1.0304522657582913
# setting temperature to :2.9000000000000012
# opt. step : 2400 obj: 1.027809649395413
# setting temperature to :3.0000000000000013
# ---> optimization finished ...
# temp:
# 3.0411041098351954
# p_quantile:
# 0.3
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14c3f5c90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14c3f5c90>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14c3f5c90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14c3f5c90>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14c3f5e50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14c3f5e50>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14c3f5e50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14c3f5e50>>: AssertionError: Bad argument number for Name: 3, expecting 4
# validation CPIT:
# 1.831373401855738
# best performing model: iteration 0
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14c623e90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14c623e90>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14c623e90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14c623e90>>: AssertionError: Bad argument number for Name: 3, expecting 4
# ------> Training DRM ranking model ....
# ---> running cross validation, iteration: 0
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14c4be710>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14c4be710>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14c4be710>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14c4be710>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14c5eb210>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14c5eb210>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14c5eb210>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14c5eb210>>: AssertionError: Bad argument number for Name: 3, expecting 4
# opt. step : 0 obj: 1.3804365948055235
# opt. step : 100 obj: 1.1883224548958131
# opt. step : 200 obj: 1.0502560268078895
# opt. step : 300 obj: 0.9923348461966255
# opt. step : 400 obj: 0.9568422542776316
# opt. step : 500 obj: 0.9323315496503363
# opt. step : 600 obj: 0.9151295377583054
# opt. step : 700 obj: 0.9026704269051823
# opt. step : 800 obj: 0.8926103231624896
# opt. step : 900 obj: 0.8835944789252
# opt. step : 1000 obj: 0.8758202080923485
# opt. step : 1100 obj: 0.869017321924823
# opt. step : 1200 obj: 0.8629654343850117
# opt. step : 1300 obj: 0.8574281129449159
# opt. step : 1400 obj: 0.8522321610839317
# opt. step : 1500 obj: 0.8473346371776302
# opt. step : 1600 obj: 0.8428887309255494
# opt. step : 1700 obj: 0.8388345251393943
# opt. step : 1800 obj: 0.8350927660868795
# opt. step : 1900 obj: 0.8317262717013044
# opt. step : 2000 obj: 0.8287184950856491
# opt. step : 2100 obj: 0.8259966130165162
# opt. step : 2200 obj: 0.8235054417616452
# opt. step : 2300 obj: 0.8212031684495967
# opt. step : 2400 obj: 0.8190577883532274
# ---> optimization finished ...
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14b6c99d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14b6c99d0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14b6c99d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14b6c99d0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14b785a10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14b785a10>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14b785a10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14b785a10>>: AssertionError: Bad argument number for Name: 3, expecting 4
# validation CPIT:
# 1.8674779524874672
# ---> running cross validation, iteration: 1
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14b871d50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14b871d50>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14b871d50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14b871d50>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14b8719d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14b8719d0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14b8719d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14b8719d0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# opt. step : 0 obj: 1.2398486066569867
# opt. step : 100 obj: 1.0720350872293472
# opt. step : 200 obj: 0.9914600126097175
# opt. step : 300 obj: 0.9435382985271553
# opt. step : 400 obj: 0.9147062141742033
# opt. step : 500 obj: 0.8959819462006827
# opt. step : 600 obj: 0.8825205996310693
# opt. step : 700 obj: 0.8719573273598358
# opt. step : 800 obj: 0.8632035899659877
# opt. step : 900 obj: 0.8557042631732973
# opt. step : 1000 obj: 0.8491201307754423
# opt. step : 1100 obj: 0.8432195882708813
# opt. step : 1200 obj: 0.8378288312624264
# opt. step : 1300 obj: 0.8328440626177742
# opt. step : 1400 obj: 0.8282904599230998
# opt. step : 1500 obj: 0.8241841079391431
# opt. step : 1600 obj: 0.8204559686560152
# opt. step : 1700 obj: 0.8170295313137895
# opt. step : 1800 obj: 0.8138451486053043
# opt. step : 1900 obj: 0.8108667165360163
# opt. step : 2000 obj: 0.8080663785979886
# opt. step : 2100 obj: 0.8054254111116341
# opt. step : 2200 obj: 0.8029242023410266
# opt. step : 2300 obj: 0.8005451731236131
# opt. step : 2400 obj: 0.7982760528054639
# ---> optimization finished ...
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14b9df4d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14b9df4d0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14b9df4d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14b9df4d0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14bb57dd0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14bb57dd0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14bb57dd0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14bb57dd0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# validation CPIT:
# 2.2840107034431405
# ---> running cross validation, iteration: 2
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14bbedd10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14bbedd10>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14bbedd10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14bbedd10>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14bcabe50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14bcabe50>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14bcabe50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14bcabe50>>: AssertionError: Bad argument number for Name: 3, expecting 4
# opt. step : 0 obj: 1.2442740412345517
# opt. step : 100 obj: 1.112948883772672
# opt. step : 200 obj: 1.0207796685356254
# opt. step : 300 obj: 0.9758746187688123
# opt. step : 400 obj: 0.9496499474127357
# opt. step : 500 obj: 0.9288257783668227
# opt. step : 600 obj: 0.912247658612295
# opt. step : 700 obj: 0.8998146141576171
# opt. step : 800 obj: 0.8833063176464223
# opt. step : 900 obj: 0.8709971817084374
# opt. step : 1000 obj: 0.8618494902003824
# opt. step : 1100 obj: 0.8551021687810786
# opt. step : 1200 obj: 0.8494118053849584
# opt. step : 1300 obj: 0.8444204159581163
# opt. step : 1400 obj: 0.8398525092090815
# opt. step : 1500 obj: 0.8355619649412553
# opt. step : 1600 obj: 0.8313989149314289
# opt. step : 1700 obj: 0.827068543608392
# opt. step : 1800 obj: 0.8223129578022306
# opt. step : 1900 obj: 0.8183020087566666
# opt. step : 2000 obj: 0.8150692727217527
# opt. step : 2100 obj: 0.8121200611984233
# opt. step : 2200 obj: 0.8093079689741193
# opt. step : 2300 obj: 0.806635026242765
# opt. step : 2400 obj: 0.8041060917001515
# ---> optimization finished ...
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14be7ee90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14be7ee90>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14be7ee90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14be7ee90>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14be7eb10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14be7eb10>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14be7eb10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14be7eb10>>: AssertionError: Bad argument number for Name: 3, expecting 4
# validation CPIT:
# 1.9689578689522858
# best performing model: iteration 0
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14bf62a50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14bf62a50>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14bf62a50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14bf62a50>>: AssertionError: Bad argument number for Name: 3, expecting 4
# " \n### this section is to load the results trained by grf R code \n### \n\not_cf = pd.read_csv('../results/causal_forest_grf_test_set_results_O_finalsize_numtrees1002.csv') \nct_cf = pd.read_csv('../results/causal_forest_grf_test_set_results_C_finalsize_numtrees1002.csv') \n\not_cf = ot_cf.as_matrix() \nOcfscores = ot_cf[0] \n\nct_cf = ct_cf.as_matrix() \nCcfscores = ct_cf[0] \n\ncfscore = np.divide(Ocfscores, Ccfscores) \n"

# %%
predFrame2
# Out:
#          Unnamed: 0  Unnamed: 0.1  ata_trip_max_avg_84d  churns_hard_lifetime  \
# 0                 0             0            113.000000                   1.0
# 1                 1             1            272.500000                   3.0
# 2                 2             2            198.214286                   2.0
# 3                 3             3            173.450000                   0.0
# 4                 4             4            166.083333                   1.0
# 5                 5             5            260.500000                   1.0
# 6                 6             6            231.666667                   1.0
# 7                 7             7            161.000000                   1.0
# 8                 8             8            208.666667                   5.0
# 9                 9             9            273.250000                   1.0
# 10               10            10            304.600000                   1.0
# 11               11            11            247.000000                   2.0
# 12               12            12            418.500000                   0.0
# 13               13            13            349.333333                   2.0
# 14               14            14            287.282051                   2.0
# 15               15            15            244.800000                   1.0
# 16               16            16            464.000000                   2.0
# 17               17            17            320.900000                   3.0
# 18               18            18            236.937500                   1.0
# 19               19            19            276.000000                   0.0
# 20               20            20            108.000000                   3.0
# 21               21            21            203.000000                   1.0
# 22               22            22            525.000000                   4.0
# 23               23            23            172.500000                   2.0
# 24               24            24            151.250000                   3.0
# 25               25            25            336.111111                   1.0
# 26               26            26            206.200000                   0.0
# 27               27            27            346.538462                   0.0
# 28               28            28                   NaN                   NaN
# 29               29            29            227.714286                   0.0
# ...             ...           ...                   ...                   ...
# 1068696     1068696       1068696            309.857143                   1.0
# 1068697     1068697       1068697            545.250000                   0.0
# 1068698     1068698       1068698            218.750000                   1.0
# 1068699     1068699       1068699                   NaN                   NaN
# 1068700     1068700       1068700            139.000000                   0.0
# 1068701     1068701       1068701            260.166667                   1.0
# 1068702     1068702       1068702            171.000000                   3.0
# 1068703     1068703       1068703             61.500000                   3.0
# 1068704     1068704       1068704            216.666667                   0.0
# 1068705     1068705       1068705            420.000000                   0.0
# 1068706     1068706       1068706            271.037736                   0.0
# 1068707     1068707       1068707            110.000000                   3.0
# 1068708     1068708       1068708            356.000000                   0.0
# 1068709     1068709       1068709            266.166667                   5.0
# 1068710     1068710       1068710            192.000000                   1.0
# 1068711     1068711       1068711            143.000000                   1.0
# 1068712     1068712       1068712            282.333333                   0.0
# 1068713     1068713       1068713            488.000000                   1.0
# 1068714     1068714       1068714            131.500000                   1.0
# 1068715     1068715       1068715            242.000000                   3.0
# 1068716     1068716       1068716            178.000000                   6.0
# 1068717     1068717       1068717            272.875000                   1.0
# 1068718     1068718       1068718            138.250000                   0.0
# 1068719     1068719       1068719            270.750000                   0.0
# 1068720     1068720       1068720             41.000000                   3.0
# 1068721     1068721       1068721            219.909091                   0.0
# 1068722     1068722       1068722             98.000000                   1.0
# 1068723     1068723       1068723            607.000000                   0.0
# 1068724     1068724       1068724            119.000000                   0.0
# 1068725     1068725       1068725            348.000000                   1.0
#
#          churns_soft_lifetime     cohort  days_active_84d  \
# 0                         1.0  treatment              1.0
# 1                         3.0  treatment              2.0
# 2                         7.0  treatment             29.0
# 3                         3.0  treatment             20.0
# 4                         0.0  treatment             12.0
# 5                         9.0  treatment              4.0
# 6                         3.0  treatment              3.0
# 7                         7.0  treatment              3.0
# 8                         4.0  treatment              6.0
# 9                         8.0  treatment              4.0
# 10                        3.0  treatment              5.0
# 11                        1.0  treatment              4.0
# 12                        1.0  treatment              2.0
# 13                       12.0  treatment              3.0
# 14                        5.0  treatment             39.0
# 15                        5.0  treatment             10.0
# 16                        7.0  treatment              2.0
# 17                        9.0  treatment             10.0
# 18                        6.0  treatment             32.0
# 19                        5.0  treatment              6.0
# 20                        6.0  treatment              2.0
# 21                        0.0  treatment              1.0
# 22                        0.0  treatment              1.0
# 23                        5.0  treatment              4.0
# 24                        7.0  treatment              8.0
# 25                        4.0  treatment             27.0
# 26                        6.0  treatment              5.0
# 27                        6.0  treatment             13.0
# 28                        NaN  treatment              NaN
# 29                        1.0  treatment              7.0
# ...                       ...        ...              ...
# 1068696                   3.0    control             21.0
# 1068697                   0.0    control              4.0
# 1068698                   6.0    control              4.0
# 1068699                   NaN    control              NaN
# 1068700                   0.0    control              1.0
# 1068701                   0.0    control              6.0
# 1068702                   4.0    control              1.0
# 1068703                   8.0    control              2.0
# 1068704                   7.0    control              3.0
# 1068705                   3.0    control              2.0
# 1068706                   0.0    control             53.0
# 1068707                   3.0    control              1.0
# 1068708                   0.0    control              2.0
# 1068709                   8.0    control              6.0
# 1068710                   1.0    control              1.0
# 1068711                   9.0    control              2.0
# 1068712                   6.0    control              3.0
# 1068713                   6.0    control              1.0
# 1068714                   1.0    control              2.0
# 1068715                   8.0    control              4.0
# 1068716                   2.0    control              2.0
# 1068717                   3.0    control              8.0
# 1068718                  18.0    control              4.0
# 1068719                   2.0    control              4.0
# 1068720                   2.0    control              1.0
# 1068721                   1.0    control             11.0
# 1068722                   0.0    control              1.0
# 1068723                   0.0    control              1.0
# 1068724                   0.0    control              5.0
# 1068725                   1.0    control              1.0
#
#          days_since_last_hard_churn_lifetime  \
# 0                                      641.0
# 1                                      196.0
# 2                                      899.0
# 3                                      918.0
# 4                                      953.0
# 5                                      293.0
# 6                                      503.0
# 7                                      997.0
# 8                                      239.0
# 9                                      377.0
# 10                                     296.0
# 11                                     184.0
# 12                                      60.0
# 13                                      89.0
# 14                                     357.0
# 15                                     647.0
# 16                                     524.0
# 17                                     555.0
# 18                                     295.0
# 19                                     567.0
# 20                                      74.0
# 21                                     122.0
# 22                                      51.0
rlearnerscores = [] 
rl_ridge_model_L_list = [] 
## set-up lagrangian rlearner 
for i in range(len(lambds)): 
    lambd = lambds[i] 
    rl_ridge_model_L = lhmodels.fit_rlearner_lagrangian(D, o, c, w, lambd) 
    rl_ridge_model_L_list.append(rl_ridge_model_L) 
    rlearnerscores.append(rl_ridge_model_L.predict(Dt)) 

### ---- experimentation and plotting cost-curves ----- 
from experimentation import * 
exp = Experimentation() 
ranscore = np.random.rand(ot.shape[0], ) 
colors = ['b', 'c', 'g', 'y', 'b', 'c', 'g', 'y', 'b', 'c', 'g', 'y', 'b', 'c', 'g', 'y'] 
plt.figure() 
rlearnerauccs = [] 
ranaucc = exp.AUC_cpit_cost_curve_deciles_cohort(ranscore, ot, wt, -1.0 * ct, 'k', plot_random=True) 
quasiaucc = exp.AUC_cpit_cost_curve_deciles_cohort(pred_values_va_rlearner_O, ot, wt, -1.0 * ct, 'c') 
for i in range(len(lambds)): 
    rlearnerauccs.append(exp.AUC_cpit_cost_curve_deciles_cohort(rlearnerscores[i], ot, wt, -1.0 * ct, colors[i] )) 
#cfaucc = exp.AUC_cpit_cost_curve_deciles_cohort(cfscore, ot, wt, -1.0 * ct, 'g') # causal forest aucc and plotting 
tqraucc = exp.AUC_cpit_cost_curve_deciles_cohort(tqrscore, ot, wt, -1.0 * ct, 'r' ) 
drmaucc = exp.AUC_cpit_cost_curve_deciles_cohort(drmscore, ot, wt, -1.0 * ct, 'm' ) 
plt.title('Causal learning cost curves using targeting models') 

### --- saving data to results folder ---- 
save_filename = '../results/benchmarkwithcv_tqr_drm_hte_'+prefix+'_main_results.pkl' 
saveD = {'tqrscore':tqrscore, 'drmscore':drmscore, 'quasiscore':pred_values_va_rlearner, 'quasiscore_O':pred_values_va_rlearner_O, 'rlearnerscore':rlearnerscores, 'ot':ot, 'wt':wt, 'ct':ct, 'tempvalue':tempvalue, 'p_quantilevalue':p_quantilevalue, 
         'tqraucc':tqraucc, 'drmaucc':drmaucc, 'rlearnerauccs':rlearnerauccs, 'ranaucc':ranaucc, 'quasiaucc':quasiaucc} 
#'cfscore':cfscore, causal forest scores 
pkl.dump(saveD, open(save_filename, 'w')) 

print('temp:') 
print(tempvalue) 
print('p_quantile:') 
print(p_quantilevalue) 

### --- add legeneds to plot ---- 
leg_str = ['Random'] 
leg_str.append('R-learner on Incremental Gain') 
for i in range(len(lambds)): 
    leg_str.append('Duality R-learner lambda='+str(lambds[i])) 
#leg_str.append('Causal Forest') # causal forest result 
leg_str.append('Top Quantile Ranking at ' + str(p_quantile*100) + '%') 
leg_str.append('Direct Ranking Model') 
plt.legend(leg_str) 

### --- print out aucc results for different models --- 
print('AUCC results: ') 
print('random: ' + str(ranaucc)) 
print('rlearner: ' + str(quasiaucc)) 
i = 0
for rlearneraucc in rlearnerauccs: 
    print('duality rlearner ' + str(i + 1) + ' with lambda = ' + str(lambds[i]) + ':' + str(rlearneraucc)) 
    i = i + 1
print('drm: ' + str(drmaucc)) 
print('tqr: ' + str(tqraucc)) 

plt.show()
# Out:
# rpu_control: 0.1723254239108353
# nipu_control: -0.06339283568481695
# rpu_ft: 0.25733028424779075
# nipu_ft: -0.18686004903846498
# ---------------------------->>>>>>
# perc - target: 0.10
# treated_target_rpu: 0.23
# treated_target_nipu: -0.18
# nontreated_target_rpu: 0.20
# nontreated_target_nipu: -0.05
# treated_nontarget_rpu: 0.26
# treated_nontarget_nipu: -0.19
# nontreated_nontarget_rpu: 0.17
# nontreated_nontarget_nipu: -0.06
# --- with 9.999625727492187% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 3.821995451169646
# --> in non-targeted users:
# cpit = 1.3500775626438772
# rpu_control: 0.17
# nipu_control: -0.06
# rpu_ft: 0.26
# nipu_ft: -0.19
# rpu_cohort: 0.18
# nipu_cohort: -0.08
# lift targeted cohort vs control: 0.02
# lift random vs control: 0.49
# cpit cohort vs control: 3.96
# lift targeted-treated vs control: 0.36
# cpit cohort: 3.963374
# ---------------------------->>>>>>
# perc - target: 0.20
# treated_target_rpu: 0.26
# treated_target_nipu: -0.18
# nontreated_target_rpu: 0.16
# nontreated_target_nipu: -0.06
# treated_nontarget_rpu: 0.26
# treated_nontarget_nipu: -0.19
# nontreated_nontarget_rpu: 0.17
# nontreated_nontarget_nipu: -0.06
# --- with 19.999251454984375% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.2862414416550376
# --> in non-targeted users:
# cpit = 1.5012215916195828
# rpu_control: 0.17
# nipu_control: -0.06
# rpu_ft: 0.26
# nipu_ft: -0.19
# rpu_cohort: 0.19
# nipu_cohort: -0.09
# lift targeted cohort vs control: 0.11
# lift random vs control: 0.49
# cpit cohort vs control: 1.29
# lift targeted-treated vs control: 0.52
# cpit cohort: 1.285288
# ---------------------------->>>>>>
# perc - target: 0.30
# treated_target_rpu: 0.27
# treated_target_nipu: -0.18
# nontreated_target_rpu: 0.17
# nontreated_target_nipu: -0.06
# treated_nontarget_rpu: 0.25
# treated_nontarget_nipu: -0.19
# nontreated_nontarget_rpu: 0.17
# nontreated_nontarget_nipu: -0.07
# --- with 29.998877182476562% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.2825811944250989
# --> in non-targeted users:
# cpit = 1.5451471413181461
# rpu_control: 0.17
# nipu_control: -0.06
# rpu_ft: 0.26
# nipu_ft: -0.19
# rpu_cohort: 0.20
# nipu_cohort: -0.10
# lift targeted cohort vs control: 0.17
# lift random vs control: 0.49
# cpit cohort vs control: 1.28
# lift targeted-treated vs control: 0.55
# cpit cohort: 1.282640
# ---------------------------->>>>>>
# perc - target: 0.40
# treated_target_rpu: 0.26
# treated_target_nipu: -0.18
# nontreated_target_rpu: 0.17
# nontreated_target_nipu: -0.06
# treated_nontarget_rpu: 0.25
# treated_nontarget_nipu: -0.19
# nontreated_nontarget_rpu: 0.17
# nontreated_nontarget_nipu: -0.07
# --- with 39.99850290996875% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.2956528865805084
# --> in non-targeted users:
# cpit = 1.574344041325152
# rpu_control: 0.17
# nipu_control: -0.06
# rpu_ft: 0.26
# nipu_ft: -0.19
# rpu_cohort: 0.21
# nipu_cohort: -0.11
# lift targeted cohort vs control: 0.22
# lift random vs control: 0.49
# cpit cohort vs control: 1.30
# lift targeted-treated vs control: 0.53
# cpit cohort: 1.295877
# ---------------------------->>>>>>
# perc - target: 0.50
# treated_target_rpu: 0.26
# treated_target_nipu: -0.18
# nontreated_target_rpu: 0.16
# nontreated_target_nipu: -0.06
# treated_nontarget_rpu: 0.25
# treated_nontarget_nipu: -0.19
# nontreated_nontarget_rpu: 0.19
# nontreated_nontarget_nipu: -0.07
# --- with 49.99812863746094% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.1416323154854344
# --> in non-targeted users:
# cpit = 1.9510875013568834
# rpu_control: 0.17
# nipu_control: -0.06
# rpu_ft: 0.26
# nipu_ft: -0.19
# rpu_cohort: 0.22
# nipu_cohort: -0.12
# lift targeted cohort vs control: 0.30
# lift random vs control: 0.49
# cpit cohort vs control: 1.14
# lift targeted-treated vs control: 0.53
# cpit cohort: 1.139809
# ---------------------------->>>>>>
# perc - target: 0.60
# treated_target_rpu: 0.26
# treated_target_nipu: -0.18
# nontreated_target_rpu: 0.17
# nontreated_target_nipu: -0.06
# treated_nontarget_rpu: 0.25
# treated_nontarget_nipu: -0.19
# nontreated_nontarget_rpu: 0.17
# nontreated_nontarget_nipu: -0.07
# --- with 59.997754364953124% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.343255344997219
# --> in non-targeted users:
# cpit = 1.643937585932148
# rpu_control: 0.17
# nipu_control: -0.06
# rpu_ft: 0.26
# nipu_ft: -0.19
# rpu_cohort: 0.23
# nipu_cohort: -0.14
# lift targeted cohort vs control: 0.32
# lift random vs control: 0.49
# cpit cohort vs control: 1.34
# lift targeted-treated vs control: 0.52
# cpit cohort: 1.343568
# ---------------------------->>>>>>
# perc - target: 0.70
# treated_target_rpu: 0.26
# treated_target_nipu: -0.19
# nontreated_target_rpu: 0.17
# nontreated_target_nipu: -0.06
# treated_nontarget_rpu: 0.25
# treated_nontarget_nipu: -0.18
# nontreated_nontarget_rpu: 0.17
# nontreated_nontarget_nipu: -0.07
# --- with 69.99738009244531% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.4242418266869892
# --> in non-targeted users:
# cpit = 1.528058137951355
# rpu_control: 0.17
# nipu_control: -0.06
# rpu_ft: 0.26
# nipu_ft: -0.19
# rpu_cohort: 0.23
# nipu_cohort: -0.15
# lift targeted cohort vs control: 0.36
# lift random vs control: 0.49
# cpit cohort vs control: 1.42
# lift targeted-treated vs control: 0.52
# cpit cohort: 1.424426
# ---------------------------->>>>>>
# perc - target: 0.80
# treated_target_rpu: 0.26
# treated_target_nipu: -0.19
# nontreated_target_rpu: 0.17
# nontreated_target_nipu: -0.06
# treated_nontarget_rpu: 0.24
# treated_nontarget_nipu: -0.18
# nontreated_nontarget_rpu: 0.19
# nontreated_nontarget_nipu: -0.06
# --- with 79.9970058199375% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.329050658093605
# --> in non-targeted users:
# cpit = 2.4382853422133994
# rpu_control: 0.17
# nipu_control: -0.06
# rpu_ft: 0.26
# nipu_ft: -0.19
# rpu_cohort: 0.25
# nipu_cohort: -0.16
# lift targeted cohort vs control: 0.44
# lift random vs control: 0.49
# cpit cohort vs control: 1.33
# lift targeted-treated vs control: 0.52
# cpit cohort: 1.328205
# ---------------------------->>>>>>
# perc - target: 0.90
# treated_target_rpu: 0.26
# treated_target_nipu: -0.19
# nontreated_target_rpu: 0.17
# nontreated_target_nipu: -0.06
# treated_nontarget_rpu: 0.23
# treated_nontarget_nipu: -0.18
# nontreated_nontarget_rpu: 0.17
# nontreated_nontarget_nipu: -0.06
# --- with 89.99663154742969% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.4075162745831242
# --> in non-targeted users:
# cpit = 2.107794181116905
# rpu_control: 0.17
# nipu_control: -0.06
# rpu_ft: 0.26
# nipu_ft: -0.19
# rpu_cohort: 0.25
# nipu_cohort: -0.18
# lift targeted cohort vs control: 0.46
# lift random vs control: 0.49
# cpit cohort vs control: 1.41
# lift targeted-treated vs control: 0.51
# cpit cohort: 1.407498
# rpu_cohort
# 0.2519232621333246
# treated_target_rpu
# 0.25723824250078997
# ---------------------------->>>>>>
# perc - target: 1.00
# treated_target_rpu: 0.26
# treated_target_nipu: -0.19
# nontreated_target_rpu: 0.17
# nontreated_target_nipu: -0.06
# treated_nontarget_rpu: 2.41
# treated_nontarget_nipu: -1.14
# nontreated_nontarget_rpu: 0.00
# nontreated_nontarget_nipu: 0.00
# --- with 99.99625727492187% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.4536251678288676
# --> in non-targeted users:
# cpit = 0.47450407020199853
# rpu_control: 0.17
# nipu_control: -0.06
# rpu_ft: 0.26
# nipu_ft: -0.19
# rpu_cohort: 0.26
# nipu_cohort: -0.19
# lift targeted cohort vs control: 0.49
# lift random vs control: 0.49
# cpit cohort vs control: 1.45
# lift targeted-treated vs control: 0.49
# cpit cohort: 1.453565
# rpu_control: 0.1723254239108353
# nipu_control: -0.06339283568481695
# rpu_ft: 0.25733028424779075
# nipu_ft: -0.18686004903846498
# ---------------------------->>>>>>
# perc - target: 0.10
# treated_target_rpu: 0.43
# treated_target_nipu: -0.34
# nontreated_target_rpu: 0.31
# nontreated_target_nipu: -0.10
# treated_nontarget_rpu: 0.24
# treated_nontarget_nipu: -0.17
# nontreated_nontarget_rpu: 0.16
# nontreated_nontarget_nipu: -0.06
# --- with 9.999625727492187% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.9708827101076722
# --> in non-targeted users:
# cpit = 1.3723325041664984
# rpu_control: 0.17
# nipu_control: -0.06
# rpu_ft: 0.26
# nipu_ft: -0.19
# rpu_cohort: 0.18
# nipu_cohort: -0.09
# lift targeted cohort vs control: 0.07
# lift random vs control: 0.49
# cpit cohort vs control: 1.93
# lift targeted-treated vs control: 1.52
# cpit cohort: 1.934719
# ---------------------------->>>>>>
# perc - target: 0.20
# treated_target_rpu: 0.37
# treated_target_nipu: -0.30
# nontreated_target_rpu: 0.25
# nontreated_target_nipu: -0.08
# treated_nontarget_rpu: 0.23
# treated_nontarget_nipu: -0.16
# nontreated_nontarget_rpu: 0.15
# nontreated_nontarget_nipu: -0.06
# --- with 19.999251454984375% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.7598218871028681
# --> in non-targeted users:
# cpit = 1.3332239904123149
# rpu_control: 0.17
# nipu_control: -0.06
# rpu_ft: 0.26
# nipu_ft: -0.19
# rpu_cohort: 0.20
# nipu_cohort: -0.11
# lift targeted cohort vs control: 0.14
# lift random vs control: 0.49
# cpit cohort vs control: 1.74
# lift targeted-treated vs control: 1.16
# cpit cohort: 1.742200
# ---------------------------->>>>>>
# perc - target: 0.30
# treated_target_rpu: 0.36
# treated_target_nipu: -0.28
# nontreated_target_rpu: 0.24
# nontreated_target_nipu: -0.08
# treated_nontarget_rpu: 0.21
# treated_nontarget_nipu: -0.15
# nontreated_nontarget_rpu: 0.14
# nontreated_nontarget_nipu: -0.06
# --- with 29.998877182476562% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.6590268051759327
# --> in non-targeted users:
# cpit = 1.317464935965861
# rpu_control: 0.17
# nipu_control: -0.06
# rpu_ft: 0.26
# nipu_ft: -0.19
# rpu_cohort: 0.21
# nipu_cohort: -0.12
# lift targeted cohort vs control: 0.20
# lift random vs control: 0.49
# cpit cohort vs control: 1.65
# lift targeted-treated vs control: 1.07
# cpit cohort: 1.647017
# ---------------------------->>>>>>
# perc - target: 0.40
# treated_target_rpu: 0.33
# treated_target_nipu: -0.26
# nontreated_target_rpu: 0.24
# nontreated_target_nipu: -0.08
# treated_nontarget_rpu: 0.21
# treated_nontarget_nipu: -0.14
# nontreated_nontarget_rpu: 0.13
# nontreated_nontarget_nipu: -0.05
# --- with 39.99850290996875% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.8035845760540257
# --> in non-targeted users:
# cpit = 1.1636088527623152
# rpu_control: 0.17
# nipu_control: -0.06
# rpu_ft: 0.26
# nipu_ft: -0.19
# rpu_cohort: 0.21
# nipu_cohort: -0.13
# lift targeted cohort vs control: 0.23
# lift random vs control: 0.49
# cpit cohort vs control: 1.79
# lift targeted-treated vs control: 0.93
# cpit cohort: 1.786173
# ---------------------------->>>>>>
# perc - target: 0.50
# treated_target_rpu: 0.31
# treated_target_nipu: -0.24
# nontreated_target_rpu: 0.21
# nontreated_target_nipu: -0.08
# treated_nontarget_rpu: 0.20
# treated_nontarget_nipu: -0.13
# nontreated_nontarget_rpu: 0.13
# nontreated_nontarget_nipu: -0.05
# --- with 49.99812863746094% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.6459724112977607
# --> in non-targeted users:
# cpit = 1.1955980477501542
# rpu_control: 0.17
# nipu_control: -0.06
# rpu_ft: 0.26
# nipu_ft: -0.19
# rpu_cohort: 0.22
# nipu_cohort: -0.14
# lift targeted cohort vs control: 0.29
# lift random vs control: 0.49
# cpit cohort vs control: 1.64
# lift targeted-treated vs control: 0.80
# cpit cohort: 1.640012
# ---------------------------->>>>>>
# perc - target: 0.60
# treated_target_rpu: 0.29
# treated_target_nipu: -0.23
# nontreated_target_rpu: 0.21
# nontreated_target_nipu: -0.07
# treated_nontarget_rpu: 0.20
# treated_nontarget_nipu: -0.12
# nontreated_nontarget_rpu: 0.12
# nontreated_nontarget_nipu: -0.05
# --- with 59.997754364953124% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.7581347735605266
# --> in non-targeted users:
# cpit = 0.9575974645836942
# rpu_control: 0.17
# nipu_control: -0.06
# rpu_ft: 0.26
# nipu_ft: -0.19
# rpu_cohort: 0.23
# nipu_cohort: -0.16
# lift targeted cohort vs control: 0.31
# lift random vs control: 0.49
# cpit cohort vs control: 1.75
# lift targeted-treated vs control: 0.71
# cpit cohort: 1.754675
# ---------------------------->>>>>>
# perc - target: 0.70
# treated_target_rpu: 0.29
# treated_target_nipu: -0.22
# nontreated_target_rpu: 0.20
# nontreated_target_nipu: -0.07
# treated_nontarget_rpu: 0.19
# treated_nontarget_nipu: -0.11
# nontreated_nontarget_rpu: 0.12
# nontreated_nontarget_nipu: -0.04
# --- with 69.99738009244531% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.6115030888838222
# --> in non-targeted users:
# cpit = 0.9875697108113508
# rpu_control: 0.17
# nipu_control: -0.06
# rpu_ft: 0.26
# nipu_ft: -0.19
# rpu_cohort: 0.24
# nipu_cohort: -0.17
# lift targeted cohort vs control: 0.37
# lift random vs control: 0.49
# cpit cohort vs control: 1.61
# lift targeted-treated vs control: 0.66
# cpit cohort: 1.607640
# ---------------------------->>>>>>
# perc - target: 0.80
# treated_target_rpu: 0.28
# treated_target_nipu: -0.21
# nontreated_target_rpu: 0.19
# nontreated_target_nipu: -0.07
# treated_nontarget_rpu: 0.18
# treated_nontarget_nipu: -0.10
# nontreated_nontarget_rpu: 0.10
# nontreated_nontarget_nipu: -0.04
# --- with 79.9970058199375% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.628380817787513
# --> in non-targeted users:
# cpit = 0.7119854927552708
# rpu_control: 0.17
# nipu_control: -0.06
# rpu_ft: 0.26
# nipu_ft: -0.19
# rpu_cohort: 0.24
# nipu_cohort: -0.18
# lift targeted cohort vs control: 0.40
# lift random vs control: 0.49
# cpit cohort vs control: 1.62
# lift targeted-treated vs control: 0.61
# cpit cohort: 1.622304
# ---------------------------->>>>>>
# perc - target: 0.90
# treated_target_rpu: 0.26
# treated_target_nipu: -0.20
# nontreated_target_rpu: 0.18
# nontreated_target_nipu: -0.07
# treated_nontarget_rpu: 0.20
# treated_nontarget_nipu: -0.09
# nontreated_nontarget_rpu: 0.08
# nontreated_nontarget_nipu: -0.04
# --- with 89.99663154742969% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.6193782236882497
# --> in non-targeted users:
# cpit = 0.4136166515557936
# rpu_control: 0.17
# nipu_control: -0.06
# rpu_ft: 0.26
# nipu_ft: -0.19
# rpu_cohort: 0.25
# nipu_cohort: -0.18
# lift targeted cohort vs control: 0.43
# lift random vs control: 0.49
# cpit cohort vs control: 1.62
# lift targeted-treated vs control: 0.53
# cpit cohort: 1.615170
# rpu_cohort
# 0.24574318700980197
# treated_target_rpu
# 0.25680405678069407
# ---------------------------->>>>>>
# perc - target: 1.00
# treated_target_rpu: 0.26
# treated_target_nipu: -0.19
# nontreated_target_rpu: 0.17
# nontreated_target_nipu: -0.06
# treated_nontarget_rpu: 12.57
# treated_nontarget_nipu: 3.00
# nontreated_nontarget_rpu: 0.00
# nontreated_nontarget_nipu: 0.00
# --- with 99.99625727492187% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.4631928061760864
# --> in non-targeted users:
# cpit = -0.23860021208907742
# rpu_control: 0.17
# nipu_control: -0.06
# rpu_ft: 0.26
# nipu_ft: -0.19
# rpu_cohort: 0.26
# nipu_cohort: -0.19
# lift targeted cohort vs control: 0.49
# lift random vs control: 0.49
# cpit cohort vs control: 1.46
# lift targeted-treated vs control: 0.49
# cpit cohort: 1.463132
# rpu_control: 0.1723254239108353
# nipu_control: -0.06339283568481695
# rpu_ft: 0.25733028424779075
# nipu_ft: -0.18686004903846498
# ---------------------------->>>>>>
# perc - target: 0.10
# treated_target_rpu: 0.21
# treated_target_nipu: -0.06
# nontreated_target_rpu: 0.10
# nontreated_target_nipu: -0.03
# treated_nontarget_rpu: 0.26
# treated_nontarget_nipu: -0.20
# nontreated_nontarget_rpu: 0.18
# nontreated_nontarget_nipu: -0.07
# --- with 9.999625727492187% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 0.3029303589617522
# --> in non-targeted users:
# cpit = 1.6226386498613945
# rpu_control: 0.17
# nipu_control: -0.06
# rpu_ft: 0.26
# nipu_ft: -0.19
# rpu_cohort: 0.18
# nipu_cohort: -0.07
# lift targeted cohort vs control: 0.06
# lift random vs control: 0.49
# cpit cohort vs control: 0.30
# lift targeted-treated vs control: 0.19
# cpit cohort: 0.304965
# ---------------------------->>>>>>
# perc - target: 0.20
# treated_target_rpu: 0.21
# treated_target_nipu: -0.08
# nontreated_target_rpu: 0.11
# nontreated_target_nipu: -0.05
# treated_nontarget_rpu: 0.27
# treated_nontarget_nipu: -0.21
# nontreated_nontarget_rpu: 0.19
# nontreated_nontarget_nipu: -0.07
# --- with 19.999251454984375% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 0.2591948143109811
# --> in non-targeted users:
# cpit = 1.833560625874774
# rpu_control: 0.17
# nipu_control: -0.06
# rpu_ft: 0.26
# nipu_ft: -0.19
# rpu_cohort: 0.19
# nipu_cohort: -0.07
# lift targeted cohort vs control: 0.12
# lift random vs control: 0.49
# cpit cohort vs control: 0.26
# lift targeted-treated vs control: 0.21
# cpit cohort: 0.258353
# ---------------------------->>>>>>
# perc - target: 0.30
# treated_target_rpu: 0.21
# treated_target_nipu: -0.10
# nontreated_target_rpu: 0.12
# nontreated_target_nipu: -0.05
# treated_nontarget_rpu: 0.28
# treated_nontarget_nipu: -0.23
# nontreated_nontarget_rpu: 0.20
# nontreated_nontarget_nipu: -0.07
# --- with 29.998877182476562% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 0.4700030384241225
# --> in non-targeted users:
# cpit = 1.913502602213478
# rpu_control: 0.17
# nipu_control: -0.06
# rpu_ft: 0.26
# nipu_ft: -0.19
# rpu_cohort: 0.20
# nipu_cohort: -0.08
# lift targeted cohort vs control: 0.16
# lift random vs control: 0.49
# cpit cohort vs control: 0.47
# lift targeted-treated vs control: 0.22
# cpit cohort: 0.467399
# ---------------------------->>>>>>
# perc - target: 0.40
# treated_target_rpu: 0.21
# treated_target_nipu: -0.11
# nontreated_target_rpu: 0.13
# nontreated_target_nipu: -0.06
# treated_nontarget_rpu: 0.29
# treated_nontarget_nipu: -0.24
# nontreated_nontarget_rpu: 0.20
# nontreated_nontarget_nipu: -0.07
# --- with 39.99850290996875% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 0.6241462017270281
# --> in non-targeted users:
# cpit = 1.9756325426407546
# rpu_control: 0.17
# nipu_control: -0.06
# rpu_ft: 0.26
# nipu_ft: -0.19
# rpu_cohort: 0.21
# nipu_cohort: -0.08
# lift targeted cohort vs control: 0.19
# lift random vs control: 0.49
# cpit cohort vs control: 0.62
# lift targeted-treated vs control: 0.21
# cpit cohort: 0.621856
# ---------------------------->>>>>>
# perc - target: 0.50
# treated_target_rpu: 0.21
# treated_target_nipu: -0.12
# nontreated_target_rpu: 0.14
# nontreated_target_nipu: -0.05
# treated_nontarget_rpu: 0.30
# treated_nontarget_nipu: -0.25
# nontreated_nontarget_rpu: 0.20
# nontreated_nontarget_nipu: -0.07
# --- with 49.99812863746094% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 0.8995154680588026
# --> in non-targeted users:
# cpit = 1.8509793306191362
# rpu_control: 0.17
# nipu_control: -0.06
# rpu_ft: 0.26
# nipu_ft: -0.19
# rpu_cohort: 0.21
# nipu_cohort: -0.10
# lift targeted cohort vs control: 0.21
# lift random vs control: 0.49
# cpit cohort vs control: 0.90
# lift targeted-treated vs control: 0.23
# cpit cohort: 0.896006
# ---------------------------->>>>>>
# perc - target: 0.60
# treated_target_rpu: 0.22
# treated_target_nipu: -0.13
# nontreated_target_rpu: 0.15
# nontreated_target_nipu: -0.06
# treated_nontarget_rpu: 0.31
# treated_nontarget_nipu: -0.27
# nontreated_nontarget_rpu: 0.20
# nontreated_nontarget_nipu: -0.07
# --- with 59.997754364953124% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.1095515157793656
# --> in non-targeted users:
# cpit = 1.7419840119016465
# rpu_control: 0.17
# nipu_control: -0.06
# rpu_ft: 0.26
# nipu_ft: -0.19
# rpu_cohort: 0.21
# nipu_cohort: -0.11
# lift targeted cohort vs control: 0.23
# lift random vs control: 0.49
# cpit cohort vs control: 1.11
# lift targeted-treated vs control: 0.27
# cpit cohort: 1.109551
# ---------------------------->>>>>>
# perc - target: 0.70
# treated_target_rpu: 0.22
# treated_target_nipu: -0.14
# nontreated_target_rpu: 0.16
# nontreated_target_nipu: -0.06
# treated_nontarget_rpu: 0.33
# treated_nontarget_nipu: -0.30
# nontreated_nontarget_rpu: 0.20
# nontreated_nontarget_nipu: -0.07
# --- with 69.99738009244531% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.1442744449694588
# --> in non-targeted users:
# cpit = 1.811178222686972
# rpu_control: 0.17
# nipu_control: -0.06
# rpu_ft: 0.26
# nipu_ft: -0.19
# rpu_cohort: 0.22
# nipu_cohort: -0.12
# lift targeted cohort vs control: 0.27
# lift random vs control: 0.49
# cpit cohort vs control: 1.14
# lift targeted-treated vs control: 0.30
# cpit cohort: 1.144841
# ---------------------------->>>>>>
# perc - target: 0.80
# treated_target_rpu: 0.23
# treated_target_nipu: -0.15
# nontreated_target_rpu: 0.16
# nontreated_target_nipu: -0.06
# treated_nontarget_rpu: 0.36
# treated_nontarget_nipu: -0.33
# nontreated_nontarget_rpu: 0.21
# nontreated_nontarget_nipu: -0.06
# --- with 79.9970058199375% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.2399541628690238
# --> in non-targeted users:
# cpit = 1.8552955489117295
# rpu_control: 0.17
# nipu_control: -0.06
# rpu_ft: 0.26
# nipu_ft: -0.19
# rpu_cohort: 0.23
# nipu_cohort: -0.13
# lift targeted cohort vs control: 0.32
# lift random vs control: 0.49
# cpit cohort vs control: 1.24
# lift targeted-treated vs control: 0.34
# cpit cohort: 1.240410
# ---------------------------->>>>>>
# perc - target: 0.90
# treated_target_rpu: 0.24
# treated_target_nipu: -0.16
# nontreated_target_rpu: 0.16
# nontreated_target_nipu: -0.06
# treated_nontarget_rpu: 0.40
# treated_nontarget_nipu: -0.39
# nontreated_nontarget_rpu: 0.25
# nontreated_nontarget_nipu: -0.05
# --- with 89.99663154742969% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.288878308788218
# --> in non-targeted users:
# cpit = 2.2301377650640584
# rpu_control: 0.17
# nipu_control: -0.06
# rpu_ft: 0.26
# nipu_ft: -0.19
# rpu_cohort: 0.24
# nipu_cohort: -0.15
# lift targeted cohort vs control: 0.41
# lift random vs control: 0.49
# cpit cohort vs control: 1.29
# lift targeted-treated vs control: 0.40
# cpit cohort: 1.287059
# rpu_cohort
# 0.2423436748887427
# treated_target_rpu
# 0.2573412792323769
# ---------------------------->>>>>>
# perc - target: 1.00
# treated_target_rpu: 0.26
# treated_target_nipu: -0.19
# nontreated_target_rpu: 0.17
# nontreated_target_nipu: -0.06
# treated_nontarget_rpu: 0.00
# treated_nontarget_nipu: 0.00
# nontreated_nontarget_rpu: 0.00
# nontreated_nontarget_nipu: 0.00
# --- with 99.99625727492187% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.452438436057485
# --> in non-targeted users:
# cpit = nan
# rpu_control: 0.17
# nipu_control: -0.06
# rpu_ft: 0.26
# nipu_ft: -0.19
# rpu_cohort: 0.26
# nipu_cohort: -0.19
# lift targeted cohort vs control: 0.49
# lift random vs control: 0.49
# cpit cohort vs control: 1.45
# lift targeted-treated vs control: 0.49
# cpit cohort: 1.452378
# rpu_control: 0.1723254239108353
# nipu_control: -0.06339283568481695
# rpu_ft: 0.25733028424779075
# nipu_ft: -0.18686004903846498
# ../experimentation.py:154: RuntimeWarning: invalid value encountered in double_scalars
#   cpit_nontargeted = -1.0 * (treated_untarget_nipu - untreated_untarget_nipu) / (treated_untarget_rpu - untreated_untarget_rpu)
# ---------------------------->>>>>>
# perc - target: 0.10
# treated_target_rpu: 0.32
# treated_target_nipu: -0.14
# nontreated_target_rpu: 0.19
# nontreated_target_nipu: -0.08
# treated_nontarget_rpu: 0.25
# treated_nontarget_nipu: -0.19
# nontreated_nontarget_rpu: 0.17
# nontreated_nontarget_nipu: -0.06
# --- with 9.999625727492187% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 0.530066683056127
# --> in non-targeted users:
# cpit = 1.608484934334047
# rpu_control: 0.17
# nipu_control: -0.06
# rpu_ft: 0.26
# nipu_ft: -0.19
# rpu_cohort: 0.18
# nipu_cohort: -0.07
# lift targeted cohort vs control: 0.07
# lift random vs control: 0.49
# cpit cohort vs control: 0.53
# lift targeted-treated vs control: 0.83
# cpit cohort: 0.530177
# ---------------------------->>>>>>
# perc - target: 0.20
# treated_target_rpu: 0.29
# treated_target_nipu: -0.14
# nontreated_target_rpu: 0.21
# nontreated_target_nipu: -0.07
# treated_nontarget_rpu: 0.25
# treated_nontarget_nipu: -0.20
# nontreated_nontarget_rpu: 0.16
# nontreated_nontarget_nipu: -0.06
# --- with 19.999251454984375% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 0.9296105773520588
# --> in non-targeted users:
# cpit = 1.5657753073032847
# rpu_control: 0.17
# nipu_control: -0.06
# rpu_ft: 0.26
# nipu_ft: -0.19
# rpu_cohort: 0.19
# nipu_cohort: -0.08
# lift targeted cohort vs control: 0.09
# lift random vs control: 0.49
# cpit cohort vs control: 0.93
# lift targeted-treated vs control: 0.68
# cpit cohort: 0.928792
# ---------------------------->>>>>>
# perc - target: 0.30
# treated_target_rpu: 0.28
# treated_target_nipu: -0.14
# nontreated_target_rpu: 0.19
# nontreated_target_nipu: -0.07
# treated_nontarget_rpu: 0.25
# treated_nontarget_nipu: -0.21
# nontreated_nontarget_rpu: 0.16
# nontreated_nontarget_nipu: -0.06
# --- with 29.998877182476562% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 0.8783786200885932
# --> in non-targeted users:
# cpit = 1.696249261044571
# rpu_control: 0.17
# nipu_control: -0.06
# rpu_ft: 0.26
# nipu_ft: -0.19
# rpu_cohort: 0.20
# nipu_cohort: -0.09
# lift targeted cohort vs control: 0.15
# lift random vs control: 0.49
# cpit cohort vs control: 0.88
# lift targeted-treated vs control: 0.60
# cpit cohort: 0.878795
# ---------------------------->>>>>>
# perc - target: 0.40
# treated_target_rpu: 0.26
# treated_target_nipu: -0.15
# nontreated_target_rpu: 0.18
# nontreated_target_nipu: -0.07
# treated_nontarget_rpu: 0.25
# treated_nontarget_nipu: -0.21
# nontreated_nontarget_rpu: 0.16
# nontreated_nontarget_nipu: -0.06
# --- with 39.99850290996875% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.0333303835239191
# --> in non-targeted users:
# cpit = 1.697042797421555
# rpu_control: 0.17
# nipu_control: -0.06
# rpu_ft: 0.26
# nipu_ft: -0.19
# rpu_cohort: 0.20
# nipu_cohort: -0.10
# lift targeted cohort vs control: 0.18
# lift random vs control: 0.49
# cpit cohort vs control: 1.03
# lift targeted-treated vs control: 0.53
# cpit cohort: 1.033254
# ---------------------------->>>>>>
# perc - target: 0.50
# treated_target_rpu: 0.26
# treated_target_nipu: -0.16
# nontreated_target_rpu: 0.18
# nontreated_target_nipu: -0.06
# treated_nontarget_rpu: 0.25
# treated_nontarget_nipu: -0.22
# nontreated_nontarget_rpu: 0.16
# nontreated_nontarget_nipu: -0.06
# --- with 49.99812863746094% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.1087026236907225
# --> in non-targeted users:
# cpit = 1.7767084011388916
# rpu_control: 0.17
# nipu_control: -0.06
# rpu_ft: 0.26
# nipu_ft: -0.19
# rpu_cohort: 0.21
# nipu_cohort: -0.11
# lift targeted cohort vs control: 0.24
# lift random vs control: 0.49
# cpit cohort vs control: 1.11
# lift targeted-treated vs control: 0.53
# cpit cohort: 1.107917
# ---------------------------->>>>>>
# perc - target: 0.60
# treated_target_rpu: 0.26
# treated_target_nipu: -0.16
# nontreated_target_rpu: 0.18
# nontreated_target_nipu: -0.06
# treated_nontarget_rpu: 0.25
# treated_nontarget_nipu: -0.23
# nontreated_nontarget_rpu: 0.16
# nontreated_nontarget_nipu: -0.06
# --- with 59.997754364953124% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.212090683227976
# --> in non-targeted users:
# cpit = 1.7490109854921527
# rpu_control: 0.17
# nipu_control: -0.06
# rpu_ft: 0.26
# nipu_ft: -0.19
# rpu_cohort: 0.22
# nipu_cohort: -0.12
# lift targeted cohort vs control: 0.27
# lift random vs control: 0.49
# cpit cohort vs control: 1.21
# lift targeted-treated vs control: 0.51
# cpit cohort: 1.211332
# ---------------------------->>>>>>
# perc - target: 0.70
# treated_target_rpu: 0.26
# treated_target_nipu: -0.17
# nontreated_target_rpu: 0.18
# nontreated_target_nipu: -0.07
# treated_nontarget_rpu: 0.25
# treated_nontarget_nipu: -0.23
# nontreated_nontarget_rpu: 0.15
# nontreated_nontarget_nipu: -0.06
# --- with 69.99738009244531% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.2675900058968559
# --> in non-targeted users:
# cpit = 1.7970082739871853
# rpu_control: 0.17
# nipu_control: -0.06
# rpu_ft: 0.26
# nipu_ft: -0.19
# rpu_cohort: 0.23
# nipu_cohort: -0.13
# lift targeted cohort vs control: 0.32
# lift random vs control: 0.49
# cpit cohort vs control: 1.27
# lift targeted-treated vs control: 0.51
# cpit cohort: 1.266762
# ---------------------------->>>>>>
# perc - target: 0.80
# treated_target_rpu: 0.26
# treated_target_nipu: -0.17
# nontreated_target_rpu: 0.18
# nontreated_target_nipu: -0.07
# treated_nontarget_rpu: 0.24
# treated_nontarget_nipu: -0.25
# nontreated_nontarget_rpu: 0.13
# nontreated_nontarget_nipu: -0.05
# --- with 79.9970058199375% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.33405362903793
# --> in non-targeted users:
# cpit = 1.7890773178610295
# rpu_control: 0.17
# nipu_control: -0.06
# rpu_ft: 0.26
# nipu_ft: -0.19
# rpu_cohort: 0.24
# nipu_cohort: -0.15
# lift targeted cohort vs control: 0.36
# lift random vs control: 0.49
# cpit cohort vs control: 1.33
# lift targeted-treated vs control: 0.51
# cpit cohort: 1.333755
# ---------------------------->>>>>>
# perc - target: 0.90
# treated_target_rpu: 0.26
# treated_target_nipu: -0.18
# nontreated_target_rpu: 0.18
# nontreated_target_nipu: -0.06
# treated_nontarget_rpu: 0.23
# treated_nontarget_nipu: -0.27
# nontreated_nontarget_rpu: 0.11
# nontreated_nontarget_nipu: -0.05
# --- with 89.99663154742969% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.4022940622359719
# --> in non-targeted users:
# cpit = 1.7356625245579909
# rpu_control: 0.17
# nipu_control: -0.06
# rpu_ft: 0.26
# nipu_ft: -0.19
# rpu_cohort: 0.24
# nipu_cohort: -0.16
# lift targeted cohort vs control: 0.42
# lift random vs control: 0.49
# cpit cohort vs control: 1.40
# lift targeted-treated vs control: 0.51
# cpit cohort: 1.402556
# ../experimentation.py:112: RuntimeWarning: divide by zero encountered in long_scalars
#   untreated_untarget_rpu = sum(1.0 * values[untreated_untargeted_filter]) / sum(untreated_untargeted_filter)
# ../experimentation.py:113: RuntimeWarning: divide by zero encountered in long_scalars
#   untreated_untarget_nipu = sum(1.0 * n9d_ni_usd[untreated_untargeted_filter]) / sum(untreated_untargeted_filter)
# rpu_cohort
# 0.24463921165665053
# treated_target_rpu
# 0.25734494443603484
# ---------------------------->>>>>>
# perc - target: 1.00
# treated_target_rpu: 0.26
# treated_target_nipu: -0.19
# nontreated_target_rpu: 0.17
# nontreated_target_nipu: -0.06
# treated_nontarget_rpu: 0.00
# treated_nontarget_nipu: 0.00
# nontreated_nontarget_rpu: 0.00
# nontreated_nontarget_nipu: 0.00
# --- with 99.99625727492187% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.4523471558928696
# --> in non-targeted users:
# cpit = nan
# rpu_control: 0.17
# nipu_control: -0.06
# rpu_ft: 0.26
# nipu_ft: -0.19
# rpu_cohort: 0.26
# nipu_cohort: -0.19
# lift targeted cohort vs control: 0.49
# lift random vs control: 0.49
# cpit cohort vs control: 1.45
# lift targeted-treated vs control: 0.49
# cpit cohort: 1.452347
# rpu_control: 0.1723254239108353
# nipu_control: -0.06339283568481695
# rpu_ft: 0.25733028424779075
# nipu_ft: -0.18686004903846498
# ---------------------------->>>>>>
# perc - target: 0.10
# treated_target_rpu: 0.25
# treated_target_nipu: -0.09
# nontreated_target_rpu: 0.14
# nontreated_target_nipu: -0.06
# treated_nontarget_rpu: 0.26
# treated_nontarget_nipu: -0.20
# nontreated_nontarget_rpu: 0.18
# nontreated_nontarget_nipu: -0.06
# --- with 9.999625727492187% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 0.22942411190042686
# --> in non-targeted users:
# cpit = 1.6426679091335286
# rpu_control: 0.17
# nipu_control: -0.06
# rpu_ft: 0.26
# nipu_ft: -0.19
# rpu_cohort: 0.18
# nipu_cohort: -0.07
# lift targeted cohort vs control: 0.07
# lift random vs control: 0.49
# cpit cohort vs control: 0.23
# lift targeted-treated vs control: 0.45
# cpit cohort: 0.230544
# ---------------------------->>>>>>
# perc - target: 0.20
# treated_target_rpu: 0.27
# treated_target_nipu: -0.12
# nontreated_target_rpu: 0.16
# nontreated_target_nipu: -0.06
# treated_nontarget_rpu: 0.25
# treated_nontarget_nipu: -0.20
# nontreated_nontarget_rpu: 0.17
# nontreated_nontarget_nipu: -0.06
# --- with 19.999251454984375% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 0.5494691638260647
# --> in non-targeted users:
# cpit = 1.7635894359322157
# rpu_control: 0.17
# nipu_control: -0.06
# rpu_ft: 0.26
# nipu_ft: -0.19
# rpu_cohort: 0.19
# nipu_cohort: -0.08
# lift targeted cohort vs control: 0.13
# lift random vs control: 0.49
# cpit cohort vs control: 0.55
# lift targeted-treated vs control: 0.58
# cpit cohort: 0.549451
# ---------------------------->>>>>>
# perc - target: 0.30
# treated_target_rpu: 0.28
# treated_target_nipu: -0.13
# nontreated_target_rpu: 0.20
# nontreated_target_nipu: -0.07
# treated_nontarget_rpu: 0.25
# treated_nontarget_nipu: -0.21
# nontreated_nontarget_rpu: 0.16
# nontreated_nontarget_nipu: -0.06
# --- with 29.998877182476562% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 0.7378448172459393
# --> in non-targeted users:
# cpit = 1.7418551865570506
# rpu_control: 0.17
# nipu_control: -0.06
# rpu_ft: 0.26
# nipu_ft: -0.19
# rpu_cohort: 0.20
# nipu_cohort: -0.08
# lift targeted cohort vs control: 0.14
# lift random vs control: 0.49
# cpit cohort vs control: 0.74
# lift targeted-treated vs control: 0.63
# cpit cohort: 0.737671
# ---------------------------->>>>>>
# perc - target: 0.40
# treated_target_rpu: 0.28
# treated_target_nipu: -0.14
# nontreated_target_rpu: 0.19
# nontreated_target_nipu: -0.07
# treated_nontarget_rpu: 0.24
# treated_nontarget_nipu: -0.22
# nontreated_nontarget_rpu: 0.16
# nontreated_nontarget_nipu: -0.06
# --- with 39.99850290996875% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 0.7749485017862763
# --> in non-targeted users:
# cpit = 1.9925932312922456
# rpu_control: 0.17
# nipu_control: -0.06
# rpu_ft: 0.26
# nipu_ft: -0.19
# rpu_cohort: 0.21
# nipu_cohort: -0.09
# lift targeted cohort vs control: 0.22
# lift random vs control: 0.49
# cpit cohort vs control: 0.77
# lift targeted-treated vs control: 0.64
# cpit cohort: 0.774807
# ---------------------------->>>>>>
# perc - target: 0.50
# treated_target_rpu: 0.28
# treated_target_nipu: -0.15
# nontreated_target_rpu: 0.19
# nontreated_target_nipu: -0.07
# treated_nontarget_rpu: 0.23
# treated_nontarget_nipu: -0.23
# nontreated_nontarget_rpu: 0.16
# nontreated_nontarget_nipu: -0.06
# --- with 49.99812863746094% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 0.8433897247029203
# --> in non-targeted users:
# cpit = 2.2043321441074637
# rpu_control: 0.17
# nipu_control: -0.06
# rpu_ft: 0.26
# nipu_ft: -0.19
# rpu_cohort: 0.22
# nipu_cohort: -0.10
# lift targeted cohort vs control: 0.27
# lift random vs control: 0.49
# cpit cohort vs control: 0.84
# lift targeted-treated vs control: 0.62
# cpit cohort: 0.843244
# ---------------------------->>>>>>
# perc - target: 0.60
# treated_target_rpu: 0.28
# treated_target_nipu: -0.16
# nontreated_target_rpu: 0.19
# nontreated_target_nipu: -0.06
# treated_nontarget_rpu: 0.23
# treated_nontarget_nipu: -0.23
# nontreated_nontarget_rpu: 0.14
# nontreated_nontarget_nipu: -0.06
# --- with 59.997754364953124% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.132945431105403
# --> in non-targeted users:
# cpit = 1.9029341632147128
# rpu_control: 0.17
# nipu_control: -0.06
# rpu_ft: 0.26
# nipu_ft: -0.19
# rpu_cohort: 0.22
# nipu_cohort: -0.12
# lift targeted cohort vs control: 0.29
# lift random vs control: 0.49
# cpit cohort vs control: 1.14
# lift targeted-treated vs control: 0.60
# cpit cohort: 1.135344
# ---------------------------->>>>>>
# perc - target: 0.70
# treated_target_rpu: 0.27
# treated_target_nipu: -0.16
# nontreated_target_rpu: 0.18
# nontreated_target_nipu: -0.07
# treated_nontarget_rpu: 0.24
# treated_nontarget_nipu: -0.24
# nontreated_nontarget_rpu: 0.14
# nontreated_nontarget_nipu: -0.06
# --- with 69.99738009244531% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.1867071845174728
# --> in non-targeted users:
# cpit = 2.0075921986182803
# rpu_control: 0.17
# nipu_control: -0.06
# rpu_ft: 0.26
# nipu_ft: -0.19
# rpu_cohort: 0.23
# nipu_cohort: -0.13
# lift targeted cohort vs control: 0.33
# lift random vs control: 0.49
# cpit cohort vs control: 1.19
# lift targeted-treated vs control: 0.55
# cpit cohort: 1.187237
# ---------------------------->>>>>>
# perc - target: 0.80
# treated_target_rpu: 0.27
# treated_target_nipu: -0.17
# nontreated_target_rpu: 0.18
# nontreated_target_nipu: -0.07
# treated_nontarget_rpu: 0.23
# treated_nontarget_nipu: -0.25
# nontreated_nontarget_rpu: 0.13
# nontreated_nontarget_nipu: -0.05
# --- with 79.9970058199375% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.2719940422923435
# --> in non-targeted users:
# cpit = 2.084092977463041
# rpu_control: 0.17
# nipu_control: -0.06
# rpu_ft: 0.26
# nipu_ft: -0.19
# rpu_cohort: 0.24
# nipu_cohort: -0.15
# lift targeted cohort vs control: 0.38
# lift random vs control: 0.49
# cpit cohort vs control: 1.27
# lift targeted-treated vs control: 0.54
# cpit cohort: 1.272662
# ---------------------------->>>>>>
# perc - target: 0.90
# treated_target_rpu: 0.26
# treated_target_nipu: -0.18
# nontreated_target_rpu: 0.18
# nontreated_target_nipu: -0.07
# treated_nontarget_rpu: 0.22
# treated_nontarget_nipu: -0.26
# nontreated_nontarget_rpu: 0.10
# nontreated_nontarget_nipu: -0.05
# --- with 89.99663154742969% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.390011697557158
# --> in non-targeted users:
# cpit = 1.8514148458448096
# rpu_control: 0.17
# nipu_control: -0.06
# rpu_ft: 0.26
# nipu_ft: -0.19
# rpu_cohort: 0.25
# nipu_cohort: -0.17
# lift targeted cohort vs control: 0.43
# lift random vs control: 0.49
# cpit cohort vs control: 1.39
# lift targeted-treated vs control: 0.52
# cpit cohort: 1.390358
# rpu_cohort
# 0.24593005684507055
# treated_target_rpu
# 0.25733761413311984
# ---------------------------->>>>>>
# perc - target: 1.00
# treated_target_rpu: 0.26
# treated_target_nipu: -0.19
# nontreated_target_rpu: 0.17
# nontreated_target_nipu: -0.06
# treated_nontarget_rpu: 0.00
# treated_nontarget_nipu: 0.00
# nontreated_nontarget_rpu: 4.68
# nontreated_nontarget_nipu: -1.00
# --- with 99.99625727492187% targeting, print cpits to treat users and create incrementality in users ---
# --> in targeted users:
# cpit = 1.448819411523416
# --> in non-targeted users:
# cpit = 0.2137138746857418
# rpu_control: 0.17
# nipu_control: -0.06
# rpu_ft: 0.26
# nipu_ft: -0.19
# rpu_cohort: 0.26
# nipu_cohort: -0.19
# lift targeted cohort vs control: 0.49
# lift random vs control: 0.49
# cpit cohort vs control: 1.45
# lift targeted-treated vs control: 0.49
# cpit cohort: 1.452410
# temp:
# 3.0411041098351954
# p_quantile:
# 0.3
# AUCC results:
# random: [0.5]
# rlearner: [0.43560717]
# duality rlearner 1 with lambda = 10:[0.61093895]
# drm: [0.61717435]
# tqr: [0.56979184]
